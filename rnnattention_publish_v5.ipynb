# %%
import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy
import numpy as np
import matplotlib

import random
import math
import time
import random
from yellowbrick.text import TSNEVisualizer
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import seaborn as sns
import os.path

# %%
# %matplotlib inline

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#---------- Attention Types
#according to these values i create attention vectors and change the 
#work flow of network
ATTENTION_DEFAULT = 1
ATTENTION_EQUAL_DISTRIBUTED = 2
ATTENTION_AT_BEGINNING = 3
ATTENTION_AT_END = 4

# %%
#utility class to log all intermediate steps
#here saving all tensors send to add_info
#then we can query these tensors. When we want to have a seperate logger, create new instance.

class StepLogger():
    def __init__(self,capacity):
        self.tensor_datas = {}        
        self.capacity = capacity
        self.added_labels = []
        
    
    def add_info(self,tensor_data,tensor_label):
        if tensor_label not in self.added_labels:
            self.added_labels.append( tensor_label )
        
        if tensor_label in self.tensor_datas.keys():
            current_arr = self.tensor_datas.get(tensor_label)
            if len(current_arr) < self.capacity:
                current_arr = self.tensor_datas.get(tensor_label, [])
                current_arr.append(tensor_data)
        else:
            self.tensor_datas[tensor_label] = [tensor_data]
    
    def get_default_summary(self,show_data=False,summary_count=1):
        self.get_summary(self.added_labels,show_data,show_info=True,summary_count=summary_count)
        
    def get_summary(self,labels,show_data=False,show_info=False,summary_count=1):
        if show_info:
            print("summary_count",summary_count,"   self.capacity ",self.capacity)
        count = 0
        values = []
        for i in range(summary_count):
            #print(i," ------------------------------------------------")
            for l in labels:
                if i < len(self.tensor_datas.get(l)):
                    label_data = self.tensor_datas.get(l)[i]
                    values.append(label_data)
                    if show_info:
                        print(l)
                    if torch.is_tensor(label_data):
                        if show_info:
                            print( list(label_data.size() ) )
                    if not show_data and not torch.is_tensor(label_data):
                        if show_info:
                            print(label_data)
                    if show_data:    
                        print(label_data)
        return values              
                    
loggers = {}                    
current_logger = StepLogger(100)   
def add_new_logger(logger_label):
    global current_logger
    if logger_label in loggers.keys() :
        #print("using existing logger")
        current_logger = loggers[logger_label]
    else:    
        loggers[logger_label]  = StepLogger(50)
        current_logger = loggers[logger_label]
    

def add_infos(datas,labels,labels_prefix=""):
    #print( id(current_logger))
    for i in range(len(datas)):
        final_label = labels_prefix+"@"+labels[i]
        current_logger.add_info(datas[i],final_label.strip())
    
#add_info   tensor_data,tensor_label                  currentLogger.get_default_summary(show_data=False)

data_pipeline = []
pipeline_enabled = True
#do no want to log during eval mode
def disable_pipeline():
    global pipeline_enabled
    pipeline_enabled = False

def enable_pipeline():
    global pipeline_enabled
    pipeline_enabled = True

#sometimes i want to log some values selectively by enable/disable
#u can check how do i do use this at code, my intention is to collect
#some intermediate values
def add_pipeline_info(label,data):
    if pipeline_enabled:
        data_pipeline.append( (label,data) )

# %%
def tokenize(text):
    return [tok for tok in text.split(" ")]

SRC = Field(tokenize = tokenize, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

TRG = Field(tokenize = tokenize, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

#read csv file
tabular_set = torchtext.data.TabularDataset(
path='D:/nnmedium/eng_de.csv', format='csv',
fields=[('src', SRC),('trg', TRG)])

# %%
SRC.build_vocab(tabular_set, min_freq = 2)
TRG.build_vocab(tabular_set, min_freq = 2)

# %%
#print(tabular_set[0].src)
#print(tabular_set[0].trg)

pairs = []
for i in range(len(tabular_set)):
    pairs.append( [ " ".join(tabular_set[i].src), " ".join(tabular_set[i].trg) ])
pairs
# Out:
# [['i want to eat bread', 'ich mochten brot essen'],
#  ['i want to eat apple', 'ich mochten apfel essen'],
#  ['i want to drink water', 'ich mochten wasser trinken'],
#  ['i want to drink beer', 'ich mochten bier trinken'],
#  ['i want to read book', 'ich mochten buch lesen'],
#  ['i want to read newspaper', 'ich mochten zeitung lesen'],
#  ['i can eat bread', 'ich konnen brot essen'],
#  ['i can eat apple', 'ich konnen apfel essen'],
#  ['i can drink water', 'ich konnen wasser trinken'],
#  ['i can drink beer', 'ich konnen bier trinken'],
#  ['i can read book', 'ich konnen buch lesen'],
#  ['i can read newspaper', 'ich konnen zeitung lesen'],
#  ['we want to eat bread', 'wir mochten brot essen'],
#  ['we want to eat apple', 'wir mochten apfel essen'],
#  ['we want to drink water', 'wir mochten wasser trinken'],
#  ['we want to drink beer', 'wir mochten bier trinken'],
#  ['we want to read book', 'wir mochten buch lesen'],
#  ['we want to read newspaper', 'wir mochten zeitung lesen'],
#  ['we can eat bread', 'wir konnen brot essen'],
#  ['we can eat apple', 'wir konnen apfel essen'],
#  ['we can drink water', 'wir konnen wasser trinken'],
#  ['we can drink beer', 'wir konnen bier trinken'],
#  ['we can read book', 'wir konnen buch lesen'],
#  ['we can read newspaper', 'wir konnen zeitung lesen'],
#  ['i eat bread', 'ich essen brot'],
#  ['i eat apple', 'ich essen apfel'],
#  ['i drink water', 'ich trinken wasser'],
#  ['i drink beer', 'ich trinken bier'],
#  ['i read book', 'ich lesen buch'],
#  ['i read newspaper', 'ich lesen zeitung'],
#  ['we eat bread', 'wir essen brot'],
#  ['we eat apple', 'wir essen apfel'],
#  ['we drink water', 'wir trinken wasser'],
#  ['we drink beer', 'wir trinken bier'],
#  ['we read book', 'wir lesen buch'],
#  ['we read newspaper', 'wir lesen zeitung']]

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang = Lang(lang1)
    output_lang = Lang(lang2)
    
    
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'ger', False)
print(random.choice(pairs))
# Out:
# Trimmed to 36 sentence pairs
# Counting words...
# Counted words:
# eng 16
# ger 15
# ['we want to eat apple', 'wir mochten apfel essen']

# %%
input_lang

# %%
MAX_LENGTH = 8

# %%
print(random.choice(pairs))
# Out:
# ['we drink beer', 'wir trinken bier']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        add_infos([input,output,hidden],["input","output","hidden"],"EncoderRNN") 
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    
    def forward(self, input, hidden, encoder_outputs,attention_type):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),encoder_outputs.unsqueeze(0))
        
        if attention_type == ATTENTION_EQUAL_DISTRIBUTED:
            equal_attention = torch.tensor(np.ones(attn_weights.shape).astype(np.float32) )
            attn_applied = torch.bmm(equal_attention.unsqueeze(0),encoder_outputs.unsqueeze(0))
        
        if attention_type == ATTENTION_AT_END:
            equal_at_end = torch.tensor(np.ones(attn_weights.shape).astype(np.float32) )
            equal_at_end[0][equal_at_end.shape[1]-1] = 1
            print("equal_at_end",equal_at_end)
            attn_applied = torch.bmm(equal_at_end.unsqueeze(0),encoder_outputs.unsqueeze(0))
            

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        
        add_infos([output,attn_weights,attn_applied],["output","attn_weights","attn_applied"],"AttnDecoderRNN") 
        
        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights
    
    
    

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    if isinstance(sentence,list):
        return [lang.word2index[word] for word in sentence]
    else:    
        return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, 
          criterion,attention_type, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = False

    for di in range(target_length):
        
        decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs, attention_type)
        topv, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze().detach()  # detach from history as input

        loss += criterion(decoder_output, target_tensor[di])
        if decoder_input.item() == EOS_token:
            break
            

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
import gc

def trainIters(encoder, decoder, n_iters,attention_type, print_every=1000, plot_every=100, learning_rate=0.01):
    gc.collect()
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion,attention_type)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
def translate_sentence(attention_type,encoder, decoder, sentence, max_length=MAX_LENGTH):
    return evaluate(attention_type,encoder, decoder, sentence, max_length)

def evaluate(attention_type,encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()        

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],encoder_hidden)            
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        all_outputs = []
        for di in range(max_length):
            #print("attention_type",attention_type)
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, 
                                                                        encoder_outputs,attention_type)
            
            decoder_attentions[di] = decoder_attention.data
            
            topv, topi = decoder_output.data.topk(1)
            
            all_outputs.append(decoder_output)
            
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()            

        return decoded_words, decoder_attentions[:di + 1],all_outputs

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('input     ->', pair[0])
        print('expected  ->', pair[1])
        output_words, attentions,all_outputs = evaluate(ATTENTION_DEFAULT,encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('predicted ->', output_sentence)
        print('')

def indexes_to_word(lang,indexes):
    return " ".join( [lang.index2word[i]  for i in torch.flatten(indexes).numpy() ] )

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

#trainIters(encoder1, attn_decoder1, 1000, print_every=500)

# %%
print( encoder1)
# Out:
# EncoderRNN(
#   (embedding): Embedding(16, 256)
#   (gru): GRU(256, 256)
# )

# %%
print( attn_decoder1)
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(15, 256)
#   (attn): Linear(in_features=512, out_features=8, bias=True)
#   (attn_combine): Linear(in_features=512, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (gru): GRU(256, 256)
#   (out): Linear(in_features=256, out_features=15, bias=True)
# )

# %%
import os.path
decoder_path = "D:/data6/20iter_decoder"
encoder_path = "D:/data6/20iter_encoder"

for i in range(1):
    gc.collect()
    encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
    attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
    
    #if os.path.isfile(decoder_path) :
    #    encoder1.load_state_dict(torch.load(encoder_path))
    #    attn_decoder1.load_state_dict(torch.load(decoder_path))
        
    trainIters(encoder1, attn_decoder1, n_iters=1000,attention_type=ATTENTION_DEFAULT, print_every=100)
    torch.save(attn_decoder1.state_dict(), decoder_path)
    torch.save(encoder1.state_dict(), encoder_path)
# Out:
# 0m 2s (- 0m 20s) (100 10%) 1.7963
# 0m 4s (- 0m 18s) (200 20%) 1.4124
# 0m 7s (- 0m 17s) (300 30%) 1.0265
# 0m 9s (- 0m 14s) (400 40%) 0.5569
# 0m 12s (- 0m 12s) (500 50%) 0.2641
# 0m 15s (- 0m 10s) (600 60%) 0.1293
# 0m 17s (- 0m 7s) (700 70%) 0.0687
# 0m 20s (- 0m 5s) (800 80%) 0.0449
# 0m 23s (- 0m 2s) (900 90%) 0.0314
# 0m 26s (- 0m 0s) (1000 100%) 0.0227

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# input     -> i can drink water
# expected  -> ich konnen wasser trinken
# predicted -> ich konnen wasser trinken <EOS>
#
# input     -> i want to drink water
# expected  -> ich mochten wasser trinken
# predicted -> ich mochten wasser trinken <EOS>
#
# input     -> i want to read newspaper
# expected  -> ich mochten zeitung lesen
# predicted -> ich mochten zeitung lesen <EOS>
#
# input     -> i drink beer
# expected  -> ich trinken bier
# predicted -> ich trinken bier <EOS>
#
# input     -> we want to drink water
# expected  -> wir mochten wasser trinken
# predicted -> wir mochten wasser trinken <EOS>
#
# input     -> we want to drink beer
# expected  -> wir mochten bier trinken
# predicted -> wir mochten bier trinken <EOS>
#
# input     -> i can read newspaper
# expected  -> ich konnen zeitung lesen
# predicted -> ich konnen zeitung lesen <EOS>
#
# input     -> we can eat bread
# expected  -> wir konnen brot essen
# predicted -> wir konnen brot essen <EOS>
#
# input     -> we can drink beer
# expected  -> wir konnen bier trinken
# predicted -> wir konnen bier trinken <EOS>
#
# input     -> i can read newspaper
# expected  -> ich konnen zeitung lesen
# predicted -> ich konnen zeitung lesen <EOS>

# %%
iter = 1
encoder = encoder1
decoder = attn_decoder1

training_pairs = [tensorsFromPair(random.choice(pairs))for i in range(5000)]

training_pair = training_pairs[iter - 1]
input_tensor = training_pair[0]
target_tensor = training_pair[1]
print("input_tensor : ",indexes_to_word(input_lang,input_tensor) )
print("target_tensor : ",indexes_to_word(output_lang,target_tensor))

input_length = input_tensor.size(0)
target_length = target_tensor.size(0)

training_pair = training_pairs[iter - 1]
input_tensor = training_pair[0]
print("training_pair[0]",training_pair[0])

encoder_outputs = torch.zeros(MAX_LENGTH, encoder.hidden_size, device=device)
encoder_hidden = encoder.initHidden()
for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)                
            
        encoder_outputs[ei] = encoder_output[0, 0]
decoder_input = torch.tensor([[SOS_token]], device=device)
decoder_hidden = encoder_hidden

decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, 
                                                            decoder_hidden, encoder_outputs,ATTENTION_DEFAULT)
topv, topi = decoder_output.topk(1)
print("topv",topv)
print("topi",topi)
print("decoder_output shape",decoder_output.shape)
print("decoder_output",decoder_output)

print(" generated word", indexes_to_word(output_lang,topi.squeeze()) )
# Out:
# input_tensor :  i want to eat bread EOS
# target_tensor :  ich mochten brot essen EOS
# training_pair[0] tensor([[2],
#         [3],
#         [4],
#         [5],
#         [6],
#         [1]])
# topv tensor([[-0.0059]], grad_fn=<TopkBackward>)
# topi tensor([[2]])
# decoder_output shape torch.Size([1, 15])
# decoder_output tensor([[-1.1187e+01, -1.7745e+01, -5.9111e-03, -6.0859e+00, -9.1259e+00,
#          -8.6474e+00, -1.1737e+01, -1.3384e+01, -1.1906e+01, -1.2486e+01,
#          -1.3181e+01, -1.2601e+01, -1.3790e+01, -9.0806e+00, -5.7507e+00]],
#        grad_fn=<LogSoftmaxBackward>)
#  generated word ich

# %%
output_words, attentions,all_outputs = evaluate(ATTENTION_DEFAULT,
    encoder1, attn_decoder1, "i eat apple")
plt.matshow(attentions.numpy())
display(plt.figure())
plt.figure().show()

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions, all_outputs = evaluate(ATTENTION_DEFAULT,
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions)

# %%
evaluateAndShowAttention("i can eat apple")
# Out:
# input = i can eat apple
# output = ich konnen apfel essen <EOS>

# %%
evaluateAndShowAttention("i can eat apple")
# Out:
# input = i can eat apple
# output = ich konnen apfel essen <EOS>

# %%
training_pairs = [tensorsFromPair(random.choice(pairs))for i in range(5000)]
iter = 1

training_pair = training_pairs[iter - 1]
input_tensor = training_pair[0]
target_tensor = training_pair[1]
print("input_tensor : ",indexes_to_word(input_lang,input_tensor) )
print("target_tensor : ",indexes_to_word(output_lang,target_tensor))
# Out:
# input_tensor :  we want to drink water EOS
# target_tensor :  wir mochten wasser trinken EOS

# %%
input_length = input_tensor.size(0)
target_length = target_tensor.size(0)
print("input_length",input_length)
print("target_length",target_length)
# Out:
# input_length 6
# target_length 5

# %%
print(attn_decoder1)
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(15, 256)
#   (attn): Linear(in_features=512, out_features=8, bias=True)
#   (attn_combine): Linear(in_features=512, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (gru): GRU(256, 256)
#   (out): Linear(in_features=256, out_features=15, bias=True)
# )

# %%
def display_attention(sentence, translation, attention, n_heads = 1, n_rows = 1, n_cols = 1):
    
    assert n_rows * n_cols == n_heads
    figsize = (5,5) if n_cols == 1 else (15,15)
    fig = plt.figure(figsize=figsize) 
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.cpu().detach().numpy()        

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        xticklabels = ['']+['<sos>']+[t.lower() for t in sentence.split(" ")]+['<eos>']
        ax.set_xticklabels(xticklabels,  rotation=45)
        
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close() 

def translate_info(src,draw_charts,attention_type,dump_result=True,flow_type=1):
    
    
    logger_name = "".join(src)+str( random.randint(1,180001) )
    add_new_logger(logger_name)
    if dump_result:
        print(f'source = {src}')

    translation, attention,all_outputs = evaluate(attention_type,encoder, decoder, src)
    #translate_sentence(src, model, device,attention_type=attention_type,flow_type=flow_type)

    if dump_result:
        print(f'predicted target = {translation}')
    output_words = translation
    
    
    indexes = []
    for index_w,w in enumerate(translation):
        if index_w == 0:
            indexes.append("sos->"+w.replace("<","").replace(">",""))
        else:    
            indexes.append(translation[index_w -1 ]+"->"+w.replace("<","").replace(">",""))        
    
    indexes = [ str(i+1)+")"+index for i,index in enumerate(indexes) ]
    #for better display i do not include "unk","pad",    
    all_outputs = np.array( torch.cat( all_outputs ) )
    #print("all_outputs shape",all_outputs.shape)
    df2 = pd.DataFrame(all_outputs,columns=output_lang.index2word.values(),index=indexes)
    
    pd.options.display.float_format = '{:,.2f}'.format
    cm = sns.light_palette("blue", as_cmap=True)
    
    df2.style.format("{:.2%}")
    
    df2.style.set_table_attributes("style='display:inline'").set_caption('Logits for translation')
    styled_df = df2.style.background_gradient(cmap=cm).set_precision(2)     
    
    pd.options.display.float_format = '{:,.2f}'.format
    if draw_charts:
        print("Logits")
        display(styled_df)    
        display_attention(src, indexes, attention,n_heads=1,n_rows = 1, n_cols = 1)
    return loggers[logger_name],all_outputs,translation

# %%
_ = translate_info("we can eat apple",attention_type=ATTENTION_EQUAL_DISTRIBUTED,draw_charts=True)
# Out:
# source = we can eat apple
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<EOS>']
# Logits
# <style  type="text/css" >
# #T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col0{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col1,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col4,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col5,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col8,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col11,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col7,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col9,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col10,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col12,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col0,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col2,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col6,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col14,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col3,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col13{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col2,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col14,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col3,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col13,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col0,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col4,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col6,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col7,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col9,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col10,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col12,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col5,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col8,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col11,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col3{
#             background-color:  #3030fd;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col6{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col7{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col9{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col10{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col12{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row0_col13,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col4{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col0,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col4{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col1,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col2{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col2{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col5,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col5{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col6{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col8,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col11{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row1_col14{
#             background-color:  #a8a8f6;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col1,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col11{
#             background-color:  #7575f9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col2{
#             background-color:  #5656fb;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col3{
#             background-color:  #6969fa;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col8{
#             background-color:  #1818fe;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col11{
#             background-color:  #3434fc;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col13,#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col7{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row2_col14{
#             background-color:  #5858fb;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col1{
#             background-color:  #4646fb;
#             color:  #f1f1f1;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col3{
#             background-color:  #c2c2f5;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col4{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col7{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col9{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col10{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col12{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row3_col13{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col0{
#             background-color:  #9b9bf7;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col5{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col6{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col8{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col9{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col10{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col12{
#             background-color:  #7070f9;
#             color:  #000000;
#         }#T_091d678c_4b78_11eb_aff1_c49ded8dff66row4_col14{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }</style><table id="T_091d678c_4b78_11eb_aff1_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOS</th>        <th class="col_heading level0 col1" >EOS</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >mochten</th>        <th class="col_heading level0 col4" >brot</th>        <th class="col_heading level0 col5" >essen</th>        <th class="col_heading level0 col6" >apfel</th>        <th class="col_heading level0 col7" >wasser</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >bier</th>        <th class="col_heading level0 col10" >buch</th>        <th class="col_heading level0 col11" >lesen</th>        <th class="col_heading level0 col12" >zeitung</th>        <th class="col_heading level0 col13" >konnen</th>        <th class="col_heading level0 col14" >wir</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_091d678c_4b78_11eb_aff1_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)sos->wir<

# %%
_ = translate_info("we can eat apple",attention_type=ATTENTION_DEFAULT,draw_charts=True)
# Out:
# source = we can eat apple
# predicted target = ['wir', 'konnen', 'apfel', 'essen', '<EOS>']
# Logits
# <style  type="text/css" >
# #T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col0{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col1{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col2,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col14,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col3,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col13,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col0,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col4,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col6,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col7,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col9,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col10,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col12,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col5,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col8,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col11,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col1{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col3,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col12{
#             background-color:  #6262fa;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col4,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col5,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col6,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col7,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col8,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col9,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col10,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col11,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col12,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col0,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col1,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col2,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col3,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col13,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col14{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row0_col13{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col2,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col14,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col8{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col4{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col5{
#             background-color:  #7f7ff9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col6{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col7{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col8{
#             background-color:  #7e7ef9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col9{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col10{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col11{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row1_col12{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col1{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col2{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col3{
#             background-color:  #7575f9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col5,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col8{
#             background-color:  #9f9ff7;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col11{
#             background-color:  #9696f7;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col13{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row2_col14{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col0,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col6{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col1{
#             background-color:  #3d3dfc;
#             color:  #f1f1f1;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col2{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col3{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col4{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col6{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col7{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col9{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col10,#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col14{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col12{
#             background-color:  #aeaef6;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row3_col13{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col0{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col4{
#             background-color:  #6464fa;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col5{
#             background-color:  #b7b7f6;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col7{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col9{
#             background-color:  #7c7cf9;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col10{
#             background-color:  #8b8bf8;
#             color:  #000000;
#         }#T_094305a8_4b78_11eb_8ca9_c49ded8dff66row4_col11{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }</style><table id="T_094305a8_4b78_11eb_8ca9_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOS</th>        <th class="col_heading level0 col1" >EOS</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >mochten</th>        <th class="col_heading level0 col4" >brot</th>        <th class="col_heading level0 col5" >essen</th>        <th class="col_heading level0 col6" >apfel</th>        <th class="col_heading level0 col7" >wasser</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >bier</th>        <th class="col_heading level0 col10" >buch</th>        <th class="col_heading level0 col11" >lesen</th>        <th class="col_heading level0 col12" >zeitung</th>        <th class="col_heading level0 col13" >konnen</th>        <th class="col_heading level0 col14" >wir</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_094305a8_4b78_

# %%
def get_translate_trg_vector(index,attention_type,filter_words):
    sentences = [ " ".join( tabular_set[i].src) for i in range(len(tabular_set)) ]
    filtered_sentences = []    
    sentences_embeddings = []
    step_output_words = []
    for i in range(len(tabular_set)):
        test_logger,all_outputs,output_words = translate_info(tabular_set[i].src,attention_type=attention_type,draw_charts=False,dump_result=False)
        trg4 = test_logger.get_summary(labels=["AttnDecoderRNN@output"],show_data=False,summary_count=10)
        
        if len( trg4 ) > index : #because of length of sentence,positions do no match just do this for same size items
            #trg_all = trg4[len(trg4) -1 ].squeeze()
            if output_words[index] in filter_words:
                sentences_embeddings.append(trg4[index].numpy().flatten())
                filtered_sentences.append( sentences[i] )            
                step_output_words.append(output_words[index])
            
    return sentences_embeddings,filtered_sentences,step_output_words

# %%
attention_type = ATTENTION_DEFAULT
test_logger,all_outputs,output_words = translate_info(tabular_set[i].src,attention_type=attention_type,draw_charts=False,dump_result=False)
trg4 = test_logger.get_summary(labels=["AttnDecoderRNN@output"],show_data=False,summary_count=10)
#trg4[4].squeeze().shape
len(trg4)
# Out:
# 5

# %%
word_index_target = 0
filter_words = ["ich","wir"]
v_embeddings,v_sentences,v_outputs= get_translate_trg_vector( 
    word_index_target,ATTENTION_DEFAULT,filter_words)
len(v_embeddings)
# Out:
# 36

# %%
def show_embeddings(invalid_embeddings,invalid_sentences,valid_sentences_embeddings,valid_sentences,fig_size=[18,8]):    
    Xs = valid_sentences_embeddings
    Ys = valid_sentences
   
    #I want to mark sentences 
    if len(invalid_sentences)> 0 :
        invalid_sentences = [ "<<<"+s+">>>" for s in invalid_sentences]
        Xs = Xs+ [embed for embed in invalid_embeddings]
        Ys = Ys + invalid_sentences 
            
    pca = PCA(n_components=2)
    result = pca.fit_transform(np.array(Xs))

    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    #scatter result words
    plt.scatter(result[:, 0], result[:, 1])
    words = list(Ys)
    #put an annotation on x,y cordinates for words, color according to verb
    for i, word in enumerate(words):
        if word in invalid_sentences:
            if "eat" in word:
                plt.annotate(word.replace("<<<","").replace(">>>","!!!"), xy=(result[i, 0], result[i, 1]),color='#dd00dd')
            elif "drink" in word:
                plt.annotate(word.replace("<<<","").replace(">>>","]]]"), xy=(result[i, 0], result[i, 1]),color='#dd44dd')
            else:
                plt.annotate(word.replace("<<<",""), xy=(result[i, 0], result[i, 1]),color='#dd88dd')
        elif "eat" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff0000')     
        else:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00dd')
    plt.show()

# %%
word_index_target = 0
filter_words = ["ich","wir"]
v_embeddings,v_sentences,v_outputs= get_translate_trg_vector( 
    word_index_target,ATTENTION_DEFAULT,filter_words)
show_embeddings([],[],v_embeddings,v_sentences,fig_size=[12,6])
inv_embeddings,inv_sentences,inv_outputs=get_translate_trg_vector( 
    word_index_target,ATTENTION_EQUAL_DISTRIBUTED,filter_words)
show_embeddings(inv_embeddings,inv_sentences,v_embeddings,v_sentences,fig_size=[12,6])

# %%
word_index_target = 1
filter_words = ["konnen","mochten"]
v_embeddings,v_sentences,v_outputs= get_translate_trg_vector( 
    word_index_target,ATTENTION_DEFAULT,filter_words)
show_embeddings([],[],v_embeddings,v_sentences,fig_size=[12,6])
inv_embeddings,inv_sentences,inv_outputs=get_translate_trg_vector( 
    word_index_target,ATTENTION_EQUAL_DISTRIBUTED,filter_words)
show_embeddings(inv_embeddings,inv_sentences,v_embeddings,v_sentences,fig_size=[12,6])

# %%
word_index_target = 2
filter_words = ["apfel","brot","buch","zeitung","wasser","bier"]
v_embeddings,v_sentences,v_outputs= get_translate_trg_vector( 
    word_index_target,ATTENTION_DEFAULT,filter_words)
show_embeddings([],[],v_embeddings,v_sentences,fig_size=[12,6])
inv_embeddings,inv_sentences,inv_outputs=get_translate_trg_vector( 
    word_index_target,ATTENTION_EQUAL_DISTRIBUTED,filter_words)
show_embeddings(inv_embeddings,inv_sentences,v_embeddings,v_sentences,fig_size=[12,6])

# %%
word_index_target = 3
filter_words = ["essen","lesen","trinken"]
v_embeddings,v_sentences,v_outputs= get_translate_trg_vector( 
    word_index_target,ATTENTION_DEFAULT,filter_words)
show_embeddings([],[],v_embeddings,v_sentences,fig_size=[12,6])
inv_embeddings,inv_sentences,inv_outputs=get_translate_trg_vector( 
    word_index_target,ATTENTION_EQUAL_DISTRIBUTED,filter_words)
show_embeddings(inv_embeddings,inv_sentences,v_embeddings,v_sentences,fig_size=[12,6])

# %%
for i in range(1):    
    encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
    attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)    
    trainIters(encoder1, attn_decoder1, n_iters=1000,attention_type=ATTENTION_EQUAL_DISTRIBUTED, print_every=100)    
    
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# 0m 2s (- 0m 25s) (100 10%) 1.4967
# 0m 6s (- 0m 25s) (200 20%) 0.7118
# 0m 9s (- 0m 22s) (300 30%) 0.3379
# 0m 12s (- 0m 18s) (400 40%) 0.0828
# 0m 15s (- 0m 15s) (500 50%) 0.0396
# 0m 19s (- 0m 12s) (600 60%) 0.0267
# 0m 22s (- 0m 9s) (700 70%) 0.0180
# 0m 24s (- 0m 6s) (800 80%) 0.0141
# 0m 27s (- 0m 3s) (900 90%) 0.0113
# 0m 30s (- 0m 0s) (1000 100%) 0.0097
# input     -> we can drink beer
# expected  -> wir konnen bier trinken
# predicted -> wir konnen bier trinken <EOS>
#
# input     -> i read book
# expected  -> ich lesen buch
# predicted -> ich konnen bier trinken <EOS>
#
# input     -> i can drink water
# expected  -> ich konnen wasser trinken
# predicted -> ich konnen bier trinken <EOS>
#
# input     -> we want to eat apple
# expected  -> wir mochten apfel essen
# predicted -> wir mochten bier trinken <EOS>
#
# input     -> i want to read newspaper
# expected  -> ich mochten zeitung lesen
# predicted -> ich mochten zeitung lesen <EOS>
#
# input     -> we can drink water
# expected  -> wir konnen wasser trinken
# predicted -> wir konnen bier trinken <EOS>
#
# input     -> we want to read book
# expected  -> wir mochten buch lesen
# predicted -> wir mochten zeitung lesen <EOS>
#
# input     -> we can read newspaper
# expected  -> wir konnen zeitung lesen
# predicted -> wir konnen zeitung lesen <EOS>
#
# input     -> i want to drink water
# expected  -> ich mochten wasser trinken
# predicted -> ich mochten bier trinken <EOS>
#
# input     -> we eat bread
# expected  -> wir essen brot
# predicted -> wir konnen bier trinken <EOS>
