# %%
import warnings
warnings.filterwarnings("ignore")

import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy
import numpy as np
import matplotlib

import random
import math
import time
import random
from yellowbrick.text import TSNEVisualizer
from sklearn.decomposition import PCA

#TODO try TSNE instead of PCA

# %%
HID_DIM = 64
ENC_LAYERS = 1
DEC_LAYERS = 1
ENC_HEADS = 2
DEC_HEADS = 2
ENC_PF_DIM = 128
DEC_PF_DIM = 128
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1

def get_head_count():
    return ENC_HEADS

def get_row_count():
    return 1

def get_col_count():
    return 2

# %%
class StepLogger():
    def __init__(self,capacity):
        self.tensor_datas = {}        
        self.capacity = capacity
        self.added_labels = []
        
    
    def add_info(self,tensor_data,tensor_label):
        if tensor_label not in self.added_labels:
            self.added_labels.append( tensor_label )
        
        if tensor_label in self.tensor_datas.keys():
            current_arr = self.tensor_datas.get(tensor_label)
            if len(current_arr) < self.capacity:
                current_arr = self.tensor_datas.get(tensor_label, [])
                current_arr.append(tensor_data)
        else:
            self.tensor_datas[tensor_label] = [tensor_data]
    
    def get_default_summary(self,show_data=False,summary_count=1):
        self.get_summary(self.added_labels,show_data,summary_count)
        
    def get_summary(self,labels,show_data=False,summary_count=1):
        print("summary_count",summary_count,"   self.capacity ",self.capacity)
        count = 0
        values = []
        for i in range(summary_count):
            #print(i," ------------------------------------------------")
            for l in labels:
                if i < len(self.tensor_datas.get(l)):
                    label_data = self.tensor_datas.get(l)[i]
                    values.append(label_data)
                    print(l)
                    if torch.is_tensor(label_data):
                        print( list(label_data.size() ) )
                    if not show_data and not torch.is_tensor(label_data):
                        print(label_data)
                    if show_data:    
                        print(label_data)
        return values              
                    
loggers = {}                    
current_logger = StepLogger(100)   
def add_new_logger(logger_label):
    global current_logger
    if logger_label in loggers.keys() :
        print("using existing logger")
        current_logger = loggers[logger_label]
    else:    
        loggers[logger_label]  = StepLogger(20)
        current_logger = loggers[logger_label]
    

def add_infos(datas,labels,labels_prefix=""):
    #print( id(current_logger))
    for i in range(len(datas)):
        final_label = labels_prefix+"@"+labels[i]
        current_logger.add_info(datas[i],final_label.strip())
    
#add_info   tensor_data,tensor_label                  currentLogger.get_default_summary(show_data=False)

data_pipeline = []
pipeline_enabled = True
def disable_pipeline():
    global pipeline_enabled
    pipeline_enabled = False

def enable_pipeline():
    global pipeline_enabled
    pipeline_enabled = True
    
def add_pipeline_info(label,data):
    if pipeline_enabled:
        data_pipeline.append( (label,data) )

# %%
a = 2
def seta():
    global a
    a = 3
print(a)
seta()
print(a)
# Out:
# 2
# 3

# %%
#!pip install torchtext
#!pip install spacy

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
#spacy_en = spacy.load('en')
spacy_en = spacy.load("en_core_web_sm")

# %%
#tok = spacy.load("en_core_web_sm")
#tokde = spacy.load("de_core_news_sm")
import de_core_news_sm
spacy_de = de_core_news_sm.load()

# %%
spacy_de.tokenizer("i mochte lesen")
# Out:
# i mochte lesen

# %%
#!python -m spacy download de

# %%
#spacy_de = spacy.load('de')

# %%
def tokenize_de(text):
    """
    Tokenizes German text from a string into a list of strings
    """
    return [tok.text for tok in spacy_de.tokenizer(text)]

def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
SRC = Field(tokenize = tokenize_de, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

TRG = Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

# %%
tabular_set = torchtext.data.TabularDataset(
path='D:/data8/eng_de3.csv', format='csv',
fields=[('src', SRC),
        ('trg', TRG)])

# %%
#dump a sample
print(tabular_set[0].src)
print(tabular_set[0].trg)
# Out:
# ['i', 'want', 'to', 'eat', 'bread']
# ['ich', 'mochten', 'brot', 'essen']

# %%
#TODO can generate different items for each
#Real line in tutorial
#train_data, valid_data, test_data = Multi30k.splits(exts = ('.de', '.en'), fields = (SRC, TRG))
train_data, valid_data, test_data = tabular_set ,tabular_set, tabular_set

# %%
#all of our vocublary is used at least 2 times
SRC.build_vocab(train_data, min_freq = 2)
TRG.build_vocab(train_data, min_freq = 2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
#our tranining size is so small so batch size will also be small
BATCH_SIZE = 8

# %%
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
     batch_size = BATCH_SIZE,
     sort_key = lambda x:  len(x.src),
     device = device)

# %%
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim,
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()

        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim,
                                                  dropout, 
                                                  device) 
                                     for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, src, src_mask,is_appy_attention):
    
        add_infos([src],["src_source"],"Encoder")
        add_pipeline_info(label="Encoder->attention",data=src)
        #src = [batch size, src len]
        #src_mask = [batch size, src len]
        #print("Encoder src",src)
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        
        #pos = [batch size, src len]
        add_infos([src,pos],["src","pos"],"Encoder")   
        src = self.dropout((self.tok_embedding(src) * self.scale) + self.pos_embedding(pos))
        
        #src = [batch size, src len, hid dim]
        
        for layer in self.layers:
            src = layer(src, src_mask,is_appy_attention)
            
        
        add_infos([src],["src_final"],"Encoder")    
        #src = [batch size, src len, hid dim]
            
        return src

# %%
class EncoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim,  
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"encoder")
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask,is_appy_attention):
        
        #src = [batch size, src len, hid dim]
        #src_mask = [batch size, src len]
                
           
        #self attention
        _src, sattention = self.self_attention(src, src, src,is_appy_attention, src_mask) #return x, attention
        
        #dropout, residual connection and layer norm
        src2 = self.self_attn_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        #positionwise feedforward
        _src2 = self.positionwise_feedforward(src2)
        
        #dropout, residual and layer norm
        src3 = self.ff_layer_norm(src + self.dropout(_src2))
        
        add_infos([_src,src2,_src2,src3,src_mask,sattention],["_src","src2","_src2","src3","src_mask","sattention"],"EncoderLayer")
        #src = [batch size, src len, hid dim]
        
        return src3

# %%
class MultiHeadAttentionLayer(nn.Module):
    #since this layer is common while logging there must be a label to differantiate labels
    def __init__(self, hid_dim, n_heads, dropout, device,layer_label):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        #TODO head_dim is encoding per head so ,hid_dim must divide n_heads
        self.head_dim = hid_dim // n_heads
        self.layer_label = layer_label
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        add_infos([self.hid_dim,self.n_heads,self.head_dim],["hid_dim","n_heads","head_dim"],self.layer_label)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value,is_appy_attention, mask = None):
        
        batch_size = query.shape[0]
        
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        
        add_pipeline_info(label=self.layer_label+"@QKV",data=[Q,K,V,mask])   
        add_infos([Q,K,V],["Q","K","V"],self.layer_label)
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
        
        ### attention is a weight over dimensions
        if not is_appy_attention:
            #print("old attention",attention.shape)
            #print("old attention",attention)
        
            #normally distributed literally means no attention
            #attention = torch.tensor(np.full(attention.shape, 1/attention.shape[3]),dtype=torch.float32 )
            #just pay attention to beginning
            #at last dimension shape is flat 1, 2, 1, 1
            if attention.shape[3] > 2: 
                real_shape = attention.shape
                att1 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], 3), 1/3) ,dtype=torch.float32 )
                att2 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], real_shape[3] - 3), 1/7) ,dtype=torch.float32 )
                att3 = torch.cat( (att1,att2),3 )
                attention = torch.softmax(att3, dim = -1)
            
            
            #print("new attention",attention)
                
        #attention = [batch size, n heads, query len, key len]
                
        x1 = torch.matmul(self.dropout(attention), V)
        
        #x = [batch size, n heads, query len, head dim]
        
        x2 = x1.permute(0, 2, 1, 3).contiguous()
        
        #x = [batch size, query len, n heads, head dim]
        
        x3 = x2.view(batch_size, -1, self.hid_dim)
        
        #x = [batch size, query len, hid dim]
        
        x4 = self.fc_o(x3)
        
        #x = [batch size, query len, hid dim]
        
        add_infos([energy,mask,attention],["energy","mask","attention"],self.layer_label)
        add_infos([x1,x2,x3,x4],["x1","x2","x3","x4"],self.layer_label)
        
        return x4, attention

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x1 = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x2 = self.fc_2(x1)
        
        #x = [batch size, seq len, hid dim]
        add_infos([x1,x2],["x1","x2"],"PositionwiseFeedforwardLayer")
        
        return x2

# %%
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask,is_appy_attention=False):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, trg len]
        #src_mask = [batch size, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                            
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
                
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask,is_appy_attention)
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        
        add_infos([pos,trg,output,attention],["pos","trg","output","attention"],"Decoder")
        #output = [batch size, trg len, output dim]
            
        return output, attention

# %%
class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"decoder_self")
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"decoder_encoder_attention")
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask,is_appy_attention):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, trg len]
        #src_mask = [batch size, src len]
        
        #self attention
        _trg1, _ = self.self_attention(trg, trg, trg,is_appy_attention, trg_mask)
        
        #dropout, residual connection and layer norm
        trg2 = self.self_attn_layer_norm(trg + self.dropout(_trg1))
            
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        _trg2, attention = self.encoder_attention(trg2, enc_src, enc_src,is_appy_attention, src_mask)
        
        #dropout, residual connection and layer norm
        trg3 = self.enc_attn_layer_norm(trg2 + self.dropout(_trg2))
                    
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg3 = self.positionwise_feedforward(trg3)
        
        #dropout, residual and layer norm
        trg4 = self.ff_layer_norm(trg3 + self.dropout(_trg3))
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        add_infos([_trg1,trg2,_trg2,trg3,_trg3,trg4,attention,trg_mask, src_mask],["_trg1","trg2","_trg2","trg3","_trg3","trg4","attention","trg_mask", "src_mask"],"DecoderLayer")
        
        return trg4, attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, 
                 encoder, 
                 decoder, 
                 src_pad_idx, 
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device
        
    def make_src_mask(self, src):
        
        #src = [batch size, src len]
        
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)

        #src_mask = [batch size, 1, 1, src len]

        return src_mask
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = self.device)).bool()
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        return trg_mask

    def forward(self, src, trg,is_appy_attention):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len]
                
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]
        #print("Seq2Seq src",src)
        enc_src = self.encoder(src, src_mask,is_appy_attention)
        
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask,is_appy_attention)
        
        add_infos([src_mask,trg_mask,enc_src,output,attention],["src_mask","trg_mask","enc_src","output","attention"],"Seq2Seq")
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return output, attention

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)


enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)

# %%
SRC_PAD_IDX = SRC.vocab.stoi[SRC.pad_token]
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]

model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

# %%
print("SRC_PAD_IDX",SRC_PAD_IDX)
print("TRG_PAD_IDX",TRG_PAD_IDX)
print(SRC.vocab.itos[10])
print(SRC.vocab.stoi[SRC.vocab.itos[10]])
# Out:
# SRC_PAD_IDX 1
# TRG_PAD_IDX 1
# to
# 10

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 99,857 trainable parameters

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

# %%
model.apply(initialize_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (tok_embedding): Embedding(18, 64)
#     (pos_embedding): Embedding(100, 64)
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=64, out_features=128, bias=True)
#           (fc_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): Decoder(
#     (tok_embedding): Embedding(17, 64)
#     (pos_embedding): Embedding(100, 64)
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=64, out_features=128, bias=True)
#           (fc_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=64, out_features=17, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
LEARNING_RATE = 0.0005

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

# %%
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

# %%
def train(model, iterator, optimizer, criterion, clip,is_appy_attention):
    
    model.train()
    
    epoch_loss = 0
    
    print("train1")
    
    for i, batch in enumerate(iterator):
        #print("train2",i,batch)
        
        
        src = batch.src
        trg = batch.trg
        
        #print("train src",src)
        
        optimizer.zero_grad()
        
        output, _ = model(src, trg[:,:-1],is_appy_attention)
        
        
                
        #output = [batch size, trg len - 1, output dim]
        #trg = [batch size, trg len]
            
        output_dim = output.shape[-1]
        
        
            
        output = output.contiguous().view(-1, output_dim)
        trg = trg[:,1:].contiguous().view(-1)
                
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
            
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion,is_appy_attention):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output, _ = model(src, trg[:,:-1],is_appy_attention)
            
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]
            
            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)
            
            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import os
import gc
N_EPOCHS = 20
CLIP = 1
best_valid_loss = float('inf')

add_new_logger("training")


model_save_path = "D:/data8/tut6-model_en_de.pt"
model_to_train = model
for epoch in range(N_EPOCHS):
    gc.collect()
    if os.path.isfile(model_save_path) :
        print("loading model",model_save_path)
        #TODO
        #model_to_train.load_state_dict(torch.load(model_save_path))
    
    start_time = time.time()
    
    enable_pipeline()
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP,is_appy_attention=True)
    
    disable_pipeline()
    valid_loss = evaluate(model, valid_iterator, criterion,is_appy_attention=True)    
    
    end_time = time.time()
    
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    
    if valid_loss < best_valid_loss:
        print("saving model",model_save_path," with loss ",valid_loss)
        best_valid_loss = valid_loss
        torch.save(model_to_train.state_dict(), model_save_path)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  2.7262842655181885
# Epoch: 01 | Time: 0m 0s
# 	Train Loss: 3.354 | Train PPL:  28.631
# 	 Val. Loss: 2.726 |  Val. PPL:  15.276
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  2.2391144275665282
# Epoch: 02 | Time: 0m 0s
# 	Train Loss: 2.727 | Train PPL:  15.286
# 	 Val. Loss: 2.239 |  Val. PPL:   9.385
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.9826491832733155
# Epoch: 03 | Time: 0m 0s
# 	Train Loss: 2.389 | Train PPL:  10.902
# 	 Val. Loss: 1.983 |  Val. PPL:   7.262
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.7823195934295655
# Epoch: 04 | Time: 0m 0s
# 	Train Loss: 2.199 | Train PPL:   9.015
# 	 Val. Loss: 1.782 |  Val. PPL:   5.944
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.5933279275894165
# Epoch: 05 | Time: 0m 0s
# 	Train Loss: 1.895 | Train PPL:   6.650
# 	 Val. Loss: 1.593 |  Val. PPL:   4.920
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.3901340007781982
# Epoch: 06 | Time: 0m 0s
# 	Train Loss: 1.790 | Train PPL:   5.987
# 	 Val. Loss: 1.390 |  Val. PPL:   4.015
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.1984021425247193
# Epoch: 07 | Time: 0m 0s
# 	Train Loss: 1.610 | Train PPL:   5.003
# 	 Val. Loss: 1.198 |  Val. PPL:   3.315
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.0253158688545227
# Epoch: 08 | Time: 0m 0s
# 	Train Loss: 1.402 | Train PPL:   4.064
# 	 Val. Loss: 1.025 |  Val. PPL:   2.788
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.872138237953186
# Epoch: 09 | Time: 0m 0s
# 	Train Loss: 1.282 | Train PPL:   3.605
# 	 Val. Loss: 0.872 |  Val. PPL:   2.392
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.7460641860961914
# Epoch: 10 | Time: 0m 0s
# 	Train Loss: 1.080 | Train PPL:   2.946
# 	 Val. Loss: 0.746 |  Val. PPL:   2.109
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.6458744704723358
# Epoch: 11 | Time: 0m 0s
# 	Train Loss: 1.038 | Train PPL:   2.823
# 	 Val. Loss: 0.646 |  Val. PPL:   1.908
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.5616242825984955
# Epoch: 12 | Time: 0m 0s
# 	Train Loss: 0.859 | Train PPL:   2.361
# 	 Val. Loss: 0.562 |  Val. PPL:   1.754
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.4996889352798462
# Epoch: 13 | Time: 0m 0s
# 	Train Loss: 0.840 | Train PPL:   2.316
# 	 Val. Loss: 0.500 |  Val. PPL:   1.648
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.43392428755760193
# Epoch: 14 | Time: 0m 0s
# 	Train Loss: 0.686 | Train PPL:   1.985
# 	 Val. Loss: 0.434 |  Val. PPL:   1.543
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.372295743227005
# Epoch: 15 | Time: 0m 0s
# 	Train Loss: 0.688 | Train PPL:   1.989
# 	 Val. Loss: 0.372 |  Val. PPL:   1.451
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.3157933682203293
# Epoch: 16 | Time: 0m 0s
# 	Train Loss: 0.587 | Train PPL:   1.799
# 	 Val. Loss: 0.316 |  Val. PPL:   1.371
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.27247534692287445
# Epoch: 17 | Time: 0m 0s
# 	Train Loss: 0.602 | Train PPL:   1.826
# 	 Val. Loss: 0.272 |  Val. PPL:   1.313
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.23857665359973906
# Epoch: 18 | Time: 0m 0s
# 	Train Loss: 0.471 | Train PPL:   1.601
# 	 Val. Loss: 0.239 |  Val. PPL:   1.269
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.20981165170669555
# Epoch: 19 | Time: 0m 0s
# 	Train Loss: 0.445 | Train PPL:   1.561
# 	 Val. Loss: 0.210 |  Val. PPL:   1.233
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.18330961167812349
# Epoch: 20 | Time: 0m 0s
# 	Train Loss: 0.384 | Train PPL:   1.467
# 	 Val. Loss: 0.183 |  Val. PPL:   1.201

# %%
import pandas as pd
import seaborn as sns

def test_sentence(src,draw_charts,is_appy_attention=True):
    
    if isinstance(src,str):
        src = src.split(" ")
    logger_name = "".join(src)+str( random.randint(1,180001) )
    add_new_logger(logger_name)
    print(f'src = {src}')

    translation, attention,all_outputs = translate_sentence(src, SRC, TRG, model, device,is_appy_attention=is_appy_attention)

    print(f'predicted trg = {translation}')
    output_words = translation
    output_words[len(output_words)-1] = "EOS"
    output_words = [ str(index+1)+")"+ word for index,word in enumerate(output_words)]
    df2 = pd.DataFrame(all_outputs,columns=["unk","pad","sos","eos"]+TRG.vocab.itos[4:],index=output_words)
    cm = sns.light_palette("blue", as_cmap=True)

    styled_df = df2.style.background_gradient(cmap=cm)
    if draw_charts:
        display(styled_df)    
        display_attention(src, translation, attention,n_heads=get_head_count(),n_rows = get_row_count(), n_cols = get_col_count())
    return loggers[logger_name],all_outputs




def show_on_vis_multi(new_input_embeddings,input_sentences,valid_sentences_embeddings,valid_sentences):
    #print("new_input_embedding",new_input_embedding)
    Xs = valid_sentences_embeddings
    Ys = valid_sentences
   
    if len(input_sentences)> 0 :
        input_sentences = [ "<<<"+s+">>>" for s in input_sentences]
        Xs = Xs+ [embed for embed in new_input_embeddings]
        Ys = Ys + input_sentences 
        
    #tsne = TSNEVisualizer(labels=Ys,title="How output of encoder looks",random_state=42)
    #result = tsne.fit_transform(np.array(Xs),Ys)
    #tsne = TSNEVisualizer()
    #result =tsne.fit_transform(np.array(Xs),Ys)
    
    pca = PCA(n_components=2)
    result = pca.fit_transform(np.array(Xs))

    #result = fitted.transformer_.fit_transform(np.array(Xs))
    #print("input_sentences",input_sentences)

    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 10.5)

    #scatter result words
    plt.scatter(result[:, 0], result[:, 1])
    words = list(Ys)
    #put an annotation on x,y cordinates for words
    #print("input_sentences",input_sentences)
    for i, word in enumerate(words):
        #print("wordi",word,i,type(word))
        if word in input_sentences:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00ff')
        elif "eat" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff0000')     
        else:
            #print("else",word)
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00dd')
    plt.show()    
    

def get_color(word):
    cmap = plt.get_cmap('viridis')
    distinct_words = SRC.vocab.itos[4:]
    #print("distinct_words",len(distinct_words))
    colors = cmap(np.linspace(0, 1, len(distinct_words)))
    color_map = { w:colors[i] for i,w in enumerate(distinct_words) }
    #print("color_map",color_map)
    for distinct_word in distinct_words:
        if  word.find(distinct_word) == 0: #if starstwith
            #print("word color",word," --> ", color_map[distinct_word])
            return color_map[distinct_word]
    #print("colors",colors)
    return color_map[distinct_words[0]]
    
                
def map_on_2d(data_2d,words,exceptional_words=[],use_word_colors=False,fig_size=[19,11]):
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(fig_size[0], fig_size[1])

    #scatter result words
    plt.scatter(data_2d[:, 0], data_2d[:, 1])
    
    
    
    #put an annotation on x,y cordinates for words
    #print("input_sentences",input_sentences)
    for i, word in enumerate(words):
        #print("wordi",word,i,type(word))
        if word in exceptional_words:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff' )
        elif use_word_colors:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color=get_color(word))
        elif "eat" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff0000')     
        else:
            #print("else",word)
            #plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00dd')
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00dd')
    plt.show()

# %%
"abcde".find("ab")
# Out:
# 0

# %%
cnt = 0
#count is 300 20 iterations so 15 per iteration
#36 items, 8 batchsize = 5 batch
#15 / 5 = 3
#3 is number of AttentionLayer stack
Qs = []
Ks = []
Vs = []
Ss = [] #sentences
for i in range(len(data_pipeline)):
    #print( data_pipeline[i][0] )
    current_label = data_pipeline[i][0]
    if "encoder@QKV" == current_label:
         cnt += 1
         Qs.append(data_pipeline[i][1][0])
         Ks.append(data_pipeline[i][1][1])
         Vs.append(data_pipeline[i][1][2])
    if "Encoder->attention" == current_label:
         
         Ss.append(data_pipeline[i][1])

# %%
print(Qs[0].shape)
print(Ss[0].shape)
print(Qs[0][:,0,:,:].shape)
# Out:
# torch.Size([8, 2, 7, 32])
# torch.Size([8, 7])
# torch.Size([8, 7, 32])

# %%
attention_table = []
for index,subbatch in enumerate(Ss):
    for sub_index ,words in enumerate(subbatch) :
        for word_index, word in enumerate(words):
            #print("index sub_index word_index",index ,sub_index ,word_index)
            #print("qval = Qs[index]",Qs[index][sub_index].shape)
            qval = Qs[index][:,0,:,:][sub_index][word_index]
            kval = Qs[index][:,0,:,:][sub_index][word_index]
            vval = Qs[index][:,0,:,:][sub_index][word_index]
            #qval = Qs[index][sub_index][word_index]
            #print(word.numpy() ,"->",qval.shape)
            attention_table.append( ( word.numpy() ,qval.detach().numpy(),kval.detach().numpy(),vval.detach().numpy() ) )

# %%
SRC.vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x000002006BF22448>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              '<sos>': 2,
#              '<eos>': 3,
#              'i': 4,
#              'we': 5,
#              'can': 6,
#              'drink': 7,
#              'eat': 8,
#              'read': 9,
#              'to': 10,
#              'want': 11,
#              'apple': 12,
#              'beer': 13,
#              'book': 14,
#              'bread': 15,
#              'newspaper': 16,
#              'water': 17})

# %%
#lesen,trinken
filter_values = [SRC.vocab.stoi["drink"],SRC.vocab.stoi["eat"],SRC.vocab.stoi["read"],SRC.vocab.stoi["apple"]
                ,SRC.vocab.stoi["beer"],SRC.vocab.stoi["book"],SRC.vocab.stoi["bread"],SRC.vocab.stoi["water"]
                ,SRC.vocab.stoi["newspaper"],SRC.vocab.stoi["can"],SRC.vocab.stoi["must"]]
filtered_attention_map = {}
cnt = 1
for row in attention_table:    
    if row[0] in filter_values:
        label = SRC.vocab.itos[row[0]]
        if label in filtered_attention_map.keys():
            filtered_attention_map[label].append(row)
        else:
            filtered_attention_map[label] = [row]        
len(filtered_attention_map)
# Out:
# 10

# %%
Xs = []
Ys = []
for key in filtered_attention_map.keys():
    print(key)
    key_rows = filtered_attention_map[key]
    sample_attention_values = [ row  for index,row in enumerate(key_rows) if (index+1) % 20 == 0]
    Xs.extend( sample_attention_values )
    Ys.extend( [ key+"@"+str(index) for index in range(len(sample_attention_values))])
    
XQs = [row[2] for row in Xs ]
YQs = [row for row in Ys ]    

pca = PCA(n_components=2)
result = pca.fit_transform(np.array(XQs))

map_on_2d(result,YQs,use_word_colors=True,fig_size=[29,11])
# Out:
# can
# eat
# apple
# drink
# beer
# water
# read
# book
# newspaper
# bread

# %%
print( data_pipeline[2][1][0].shape)
print( data_pipeline[2][1][1].shape)
print( data_pipeline[2][1][2].shape)
print( data_pipeline[2][1][3].shape)
print( data_pipeline[2][1][3])
# Out:
# torch.Size([8, 2, 5, 32])
# torch.Size([8, 2, 5, 32])
# torch.Size([8, 2, 5, 32])
# torch.Size([8, 1, 5, 5])
# tensor([[[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]],
#
#
#         [[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]]])

# %%
add_new_logger("test_loss")

# %%
test_loss = evaluate(model, test_iterator, criterion,is_appy_attention=True)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')
# Out:
# | Test Loss: 0.183 | Test PPL:   1.201 |

# %%
def translate_sentence(sentence, src_field, trg_field, model, device,is_appy_attention, max_len = 50):
    
    model.eval()
        
    if isinstance(sentence, str):
        nlp = spacy.load('de')
        tokens = [token.text.lower() for token in nlp(sentence)]
    else:
        tokens = [token.lower() for token in sentence]

    tokens = [src_field.init_token] + tokens + [src_field.eos_token]
        
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]

    src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
    
    src_mask = model.make_src_mask(src_tensor)
    
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask,is_appy_attention)

    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]

    ### hold output of linear layer at everytime step
    all_outputs = []
    for i in range(max_len):

        trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)

        trg_mask = model.make_trg_mask(trg_tensor)
        
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask,is_appy_attention)
        
        # #print("trg_mask",trg_mask)
        #print("src_mask",src_mask)
        #print("output.argmax(2)->",output.argmax(2))
        #print("output->",output.shape)
        #print("attention->",attention.shape)
        all_outputs.append(output[:, -1:, :].numpy().flatten())
        pred_token = output.argmax(2)[:,-1].item()
        
        trg_indexes.append(pred_token)

        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
    
    
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]
    
    return trg_tokens[1:], attention,all_outputs

# %%
def display_attention(sentence, translation, attention, n_heads = get_head_count(), n_rows = get_row_count(), n_cols = get_col_count()):
    
    assert n_rows * n_cols == n_heads
    
    fig = plt.figure(figsize=(15,25))
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                           rotation=45)
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()
    
def encoding_to_sentence(encodings,language):
    return [language.vocab.itos[i] for i in encodings ]

# %%
current_logger.get_default_summary(show_data=False)
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [8, 5]
# Encoder@src
# [8, 5]
# Encoder@pos
# [8, 5]
# encoder@Q
# [8, 2, 5, 32]
# encoder@K
# [8, 2, 5, 32]
# encoder@V
# [8, 2, 5, 32]
# encoder@energy
# [8, 2, 5, 5]
# encoder@mask
# [8, 1, 1, 5]
# encoder@attention
# [8, 2, 5, 5]
# encoder@x1
# [8, 2, 5, 32]
# encoder@x2
# [8, 5, 2, 32]
# encoder@x3
# [8, 5, 64]
# encoder@x4
# [8, 5, 64]
# PositionwiseFeedforwardLayer@x1
# [8, 5, 128]
# PositionwiseFeedforwardLayer@x2
# [8, 5, 64]
# EncoderLayer@_src
# [8, 5, 64]
# EncoderLayer@src2
# [8, 5, 64]
# EncoderLayer@_src2
# [8, 5, 64]
# EncoderLayer@src3
# [8, 5, 64]
# EncoderLayer@src_mask
# [8, 1, 1, 5]
# EncoderLayer@sattention
# [8, 2, 5, 5]
# Encoder@src_final
# [8, 5, 64]
# decoder_self@Q
# [8, 2, 4, 32]
# decoder_self@K
# [8, 2, 4, 32]
# decoder_self@V
# [8, 2, 4, 32]
# decoder_self@energy
# [8, 2, 4, 4]
# decoder_self@mask
# [8, 1, 4, 4]
# decoder_self@attention
# [8, 2, 4, 4]
# decoder_self@x1
# [8, 2, 4, 32]
# decoder_self@x2
# [8, 4, 2, 32]
# decoder_self@x3
# [8, 4, 64]
# decoder_self@x4
# [8, 4, 64]
# decoder_encoder_attention@Q
# [8, 2, 4, 32]
# decoder_encoder_attention@K
# [8, 2, 5, 32]
# decoder_encoder_attention@V
# [8, 2, 5, 32]
# decoder_encoder_attention@energy
# [8, 2, 4, 5]
# decoder_encoder_attention@mask
# [8, 1, 1, 5]
# decoder_encoder_attention@attention
# [8, 2, 4, 5]
# decoder_encoder_attention@x1
# [8, 2, 4, 32]
# decoder_encoder_attention@x2
# [8, 4, 2, 32]
# decoder_encoder_attention@x3
# [8, 4, 64]
# decoder_encoder_attention@x4
# [8, 4, 64]
# DecoderLayer@_trg1
# [8, 4, 64]
# DecoderLayer@trg2
# [8, 4, 64]
# DecoderLayer@_trg2
# [8, 4, 64]
# DecoderLayer@trg3
# [8, 4, 64]
# DecoderLayer@_trg3
# [8, 4, 64]
# DecoderLayer@trg4
# [8, 4, 64]
# DecoderLayer@attention
# [8, 2, 4, 5]
# DecoderLayer@trg_mask
# [8, 1, 4, 4]
# DecoderLayer@src_mask
# [8, 1, 1, 5]
# Decoder@pos
# [8, 4]
# Decoder@trg
# [8, 4, 64]
# Decoder@output
# [8, 4, 17]
# Decoder@attention
# [8, 2, 4, 5]
# Seq2Seq@src_mask
# [8, 1, 1, 5]
# Seq2Seq@trg_mask
# [8, 1, 4, 4]
# Seq2Seq@enc_src
# [8, 5, 64]
# Seq2Seq@output
# [8, 4, 17]
# Seq2Seq@attention
# [8, 2, 4, 5]

# %%
valid_sentences = []
for i in range(len(tabular_set)):
    valid_sentences.append(" ".join( tabular_set[i].src) )
    
valid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs = test_sentence(tabular_set[i].src,draw_charts=False)
    #train_data.examples[example_idx].src
    #test_logger.get_default_summary()
    trg4 = test_logger.get_summary(labels=["DecoderLayer@trg4"],show_data=False)
    valid_sentences_embeddings.append(trg4[0].numpy().flatten())
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'eat', 'apple']
# predicted trg = ['ich', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'drink', 'water']
# predicted trg = ['ich', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'drink', 'beer']
# predicted trg = ['ich', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'read', 'book']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['ich', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'eat', 'bread']
# predicted trg = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'eat', 'apple']
# predicted trg = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'drink', 'water']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'drink', 'beer']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'read', 'book']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'read', 'newspaper']
# predicted trg = ['ich', 'konnen', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'eat', 'bread']
# predicted trg = ['wir', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'eat', 'apple']
# predicted trg = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'drink', 'water']
# predicted trg = ['wir', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'drink', 'beer']
# predicted trg = ['wir', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'read', 'book']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['wir', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'eat', 'bread']
# predicted trg = ['wir', 'konnen', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'eat', 'apple']
# predicted trg = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'drink', 'water']
# predicted trg = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'drink', 'beer']
# predicted trg = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'read', 'book']
# predicted trg = ['wir', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'read', 'newspaper']
# predicted trg = ['wir', 'konnen', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'eat', 'bread']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'eat', 'apple']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'drink', 'water']
# predicted trg = ['ich', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'drink', 'beer']
# predicted trg = ['ich', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'read', 'book']
# predicted trg = ['ich', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'read', 'newspaper']
# predicted trg = ['ich', 'lesen', 'zeitung', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'eat', 'bread']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'eat', 'apple']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'drink', 'water']
# predicted trg = ['wir', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'drink', 'beer']
# predicted trg = ['wir', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'read', 'book']
# predicted trg = ['wir', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'read', 'newspaper']
# predicted trg = ['wir', 'lesen', 'zeitung', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]

# %%
invalid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs = test_sentence(tabular_set[i].src,draw_charts=False,is_appy_attention=False)
    #train_data.examples[example_idx].src
    #test_logger.get_default_summary()
    trg4 = test_logger.get_summary(labels=["DecoderLayer@trg4"],show_data=False)

    invalid_sentences_embeddings.append(trg4[0].numpy().flatten())
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'eat', 'apple']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'drink', 'water']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'drink', 'beer']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'read', 'book']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'eat', 'bread']
# predicted trg = ['ich', 'essen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'eat', 'apple']
# predicted trg = ['ich', 'essen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'drink', 'water']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'drink', 'beer']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'read', 'book']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'can', 'read', 'newspaper']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'eat', 'bread']
# predicted trg = ['wir', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'eat', 'apple']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'drink', 'water']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'drink', 'beer']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'read', 'book']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'eat', 'bread']
# predicted trg = ['wir', 'konnen', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'eat', 'apple']
# predicted trg = ['wir', 'konnen', 'konnen', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'drink', 'water']
# predicted trg = ['wir', 'konnen', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'drink', 'beer']
# predicted trg = ['wir', 'konnen', 'konnen', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'read', 'book']
# predicted trg = ['wir', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'can', 'read', 'newspaper']
# predicted trg = ['wir', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'eat', 'bread']
# predicted trg = ['ich', 'essen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'eat', 'apple']
# predicted trg = ['ich', 'essen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'drink', 'water']
# predicted trg = ['ich', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'drink', 'beer']
# predicted trg = ['ich', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'read', 'book']
# predicted trg = ['ich', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['i', 'read', 'newspaper']
# predicted trg = ['ich', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'eat', 'bread']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'eat', 'apple']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'drink', 'water']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'drink', 'beer']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'read', 'book']
# predicted trg = ['wir', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# src = ['we', 'read', 'newspaper']
# predicted trg = ['wir', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]

# %%
invalid_sentences_embeddings[0].shape
# Out:
# (64,)

# %%
test_sentence("i can eat bread",is_appy_attention=True,draw_charts=True)
# Out:
# src = ['i', 'can', 'eat', 'bread']
# predicted trg = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# <style  type="text/css" >
# #T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col0,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col4{
#             background-color:  #9e9ef7;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col1{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col2,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col4,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col5,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col16,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col7,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col8,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col9,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col12,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col14,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col15,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col1,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col6,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col10,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col0,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col3,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col11,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col13{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col3{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col6,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col12{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col7,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col12,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col4,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col14,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col16,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col0,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col10,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col2,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col3,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col5,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col8,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col11,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col12,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col13,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col1,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col6,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col9,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col15{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col8{
#             background-color:  #0707ff;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col9{
#             background-color:  #8e8ef8;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col10{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col11{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col13{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col14{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row0_col15{
#             background-color:  #6f6ff9;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col0{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col1{
#             background-color:  #6a6afa;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col2,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col2{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col3{
#             background-color:  #cecef5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col5{
#             background-color:  #3333fc;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col6,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col1,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col3{
#             background-color:  #ccccf5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col10{
#             background-color:  #1212fe;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col11{
#             background-color:  #9999f7;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col12{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col13{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row1_col15{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col5{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col6{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col7,#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col14{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col8{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col9{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col11{
#             background-color:  #3131fd;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col13{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row2_col16{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col0{
#             background-color:  #7777f9;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col4{
#             background-color:  #b6b6f6;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col7{
#             background-color:  #5e5efa;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col9{
#             background-color:  #3232fc;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col15{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row3_col16{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col2{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col4{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col5{
#             background-color:  #3434fc;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col7{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col8{
#             background-color:  #9696f7;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col10{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col14{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_20ca4962_3893_11eb_bbfc_c49ded8dff66row4_col16{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }</style><table id="T_20ca4962_3893_11eb_bbfc_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_hea
# (<__main__.StepLogger at 0x20062c9ea88>,
#  [array([-1.3602608 , -1.6343083 ,  0.11118087, -1.516622  ,  6.6465693 ,
#          -0.71349835,  0.8069968 , -2.8162906 , -0.10786331, -2.061341  ,
#          -1.331779  ,  0.68654025, -1.6871077 , -1.2992742 ,  0.3978721 ,
#          -0.19630319, -0.65713507], dtype=float32),
#   array([-1.3310074 , -0.88752985, -0.49695897, -1.7359381 , -2.4982958 ,
#          -0.89736223,  0.62002164,  6.645561  , -0.04489356,  0.09960677,
#           0.38334462,  0.36858866, -1.1396482 , -1.2308925 , -0.51113766,
#          -0.41507807, -2.5474243 ], dtype=float32),
#   array([-1.8551494 , -1.8241261 , -0.4944245 , -1.6504889 ,  0.6151861 ,
#          -0.9127866 ,  1.0020787 , -0.87851447, -1.6932518 , -3.102165  ,
#          -2.2050123 ,  2.3030946 ,  0.7052513 , -0.32695976,  4.0867834 ,
#           0.81633765, -1.4976208 ], dtype=float32),
#   array([-1.1187618 ,  0.12769827, -2.0079262 , -2.9323294 , -0.25135267,
#          -1.5797937 ,  5.553172  ,  2.9378886 , -2.2961006 , -0.661994  ,
#           0.5909544 , -1.2639649 , -1.6791434 , -1.5167767 ,  0.4244502 ,
#          -0.53444463, -2.3745496 ], dtype=float32),
#   array([-0.40221155, -2.1797423 , -1.5844426 ,  5.28731   , -0.5022772 ,
#          -0.90119594, -0.2727063 , -1.2772009 , -1.4487107 , -3.5525186 ,
#           0.19157338,  3.2224655 , -1.2415496 ,  0.6707152 , -0.12217427,
#          -1.3775669 , -2.2857606 ], dtype=float32)])

# %%
test_sentence("i can eat bread",is_appy_attention=False,draw_charts=True)
# Out:
# src = ['i', 'can', 'eat', 'bread']
# predicted trg = ['ich', 'essen', 'apfel', 'essen', '<eos>']
# <style  type="text/css" >
# #T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col0,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col6,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col10,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col12,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col14,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col15,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col2,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col3,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col4,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col5,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col11,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col16,#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col1,#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col9,#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col13,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col7,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col8{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col1,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col2,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col4,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col5,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col7,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col8,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col9,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col10,#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col11,#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col14,#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col15,#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col6,#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col16,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col0,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col3,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col12,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col13{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col3,#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col0{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col7{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col8{
#             background-color:  #8282f8;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col9,#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col13,#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col14{
#             background-color:  #c4c4f5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col11{
#             background-color:  #3636fc;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row0_col16{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col0{
#             background-color:  #2323fd;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col1{
#             background-color:  #2e2efd;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col6{
#             background-color:  #1010fe;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col12{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col13,#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col6{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row1_col15{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col0{
#             background-color:  #3030fd;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col1{
#             background-color:  #c3c3f5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col2{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col3{
#             background-color:  #2d2dfd;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col4{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col5,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col5{
#             background-color:  #b5b5f6;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col7{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col8{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col9{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col10{
#             background-color:  #7676f9;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col12{
#             background-color:  #1e1efd;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col13{
#             background-color:  #3333fc;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row2_col16{
#             background-color:  #4a4afb;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col2,#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col14{
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col3{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col4{
#             background-color:  #9090f8;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col5{
#             background-color:  #c0c0f5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col7{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col8{
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col10{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col11{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col12{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col14{
#             background-color:  #9d9df7;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row3_col15{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col1{
#             background-color:  #b0b0f6;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col2{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col4{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col6{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col9{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col10{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col11{
#             background-color:  #0606ff;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col15{
#             background-color:  #1717fe;
#             color:  #f1f1f1;
#         }#T_20fbb980_3893_11eb_b157_c49ded8dff66row4_col16{
#             background-color:  #0e0efe;
#             color:  #f1f1f1;
#         }</style><table id="T_20fbb980_3893_11eb_b157_c49ded8dff66" ><
# (<__main__.StepLogger at 0x200774de308>,
#  [array([-2.5700293 , -1.7528191 , -0.31153324, -1.6031584 ,  3.4691808 ,
#           1.4571093 ,  0.83769184,  0.2764855 , -0.76865774, -3.6696224 ,
#          -1.5017236 ,  2.3597653 , -2.9090908 , -1.4086039 ,  0.4865157 ,
#          -1.3561443 , -3.7363553 ], dtype=float32),
#   array([-1.3693522 , -2.1879485 , -2.8583276 , -2.3648074 , -1.2964574 ,
#          -2.845172  ,  3.6633492 ,  2.0499587 , -0.28019315, -0.6381188 ,
#           0.9759069 ,  0.5710246 , -1.1885134 , -1.6128861 ,  0.87296873,
#          -0.96477383, -4.1787214 ], dtype=float32),
#   array([-1.445559  , -3.5711045 , -2.3924806 ,  2.686793  , -1.105846  ,
#          -1.7770578 ,  1.0524472 , -0.8193495 , -1.1135299 , -2.8219554 ,
#          -0.24081531,  2.8823788 ,  0.59667534, -0.3019252 ,  2.5661995 ,
#           0.41502663, -2.763597  ], dtype=float32),
#   array([-2.3966947 , -3.9940777 , -0.40754482,  2.067988  ,  0.6176901 ,
#          -1.9864722 ,  3.8676836 , -1.029174  , -0.28735486, -4.352176  ,
#          -0.57571775,  0.7539969 , -0.3447523 , -1.7486548 ,  1.2172    ,
#          -0.2865796 , -2.1229355 ], dtype=float32),
#   array([-1.1646624 , -3.3933918 , -2.3162415 ,  3.8703172 , -0.9926879 ,
#          -1.776568  ,  0.9750503 , -1.1396029 , -1.1834579 , -3.1955476 ,
#          -0.15615979,  2.8214447 ,  1.1047959 ,  0.08894391,  2.4891882 ,
#           0.24666592, -2.2454376 ], dtype=float32)])

# %%
Xs = []
Ys = []
for index,sentence in enumerate(valid_sentences):
    logger,all_outputs = test_sentence(sentence,draw_charts=False,is_appy_attention=True)
    labels = logger.get_summary(labels=["Encoder@src_source"],show_data=False)
    datas = logger.get_summary(labels=["Encoder@src_final"],show_data=False)
    words = encoding_to_sentence(labels[0].numpy().flatten(),SRC)
    for index_word,data in enumerate(datas[0].squeeze() ):
        print(data.shape)
        if words[index_word] != "<eos>" and words[index_word] != "<sos>":
            Xs.append( data.numpy() )
            Ys.append( words[index_word]+"@"+str(index) )
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'want', 'to', 'eat', 'apple']
# predicted trg = ['ich', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'want', 'to', 'drink', 'water']
# predicted trg = ['ich', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'want', 'to', 'drink', 'beer']
# predicted trg = ['ich', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'want', 'to', 'read', 'book']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['ich', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'can', 'eat', 'bread']
# predicted trg = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'can', 'eat', 'apple']
# predicted trg = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'can', 'drink', 'water']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'can', 'drink', 'beer']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'can', 'read', 'book']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'can', 'read', 'newspaper']
# predicted trg = ['ich', 'konnen', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'want', 'to', 'eat', 'bread']
# predicted trg = ['wir', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'want', 'to', 'eat', 'apple']
# predicted trg = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'want', 'to', 'drink', 'water']
# predicted trg = ['wir', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'want', 'to', 'drink', 'beer']
# predicted trg = ['wir', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'want', 'to', 'read', 'book']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['wir', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 7, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'can', 'eat', 'bread']
# predicted trg = ['wir', 'konnen', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'can', 'eat', 'apple']
# predicted trg = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'can', 'drink', 'water']
# predicted trg = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'can', 'drink', 'beer']
# predicted trg = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'can', 'read', 'book']
# predicted trg = ['wir', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'can', 'read', 'newspaper']
# predicted trg = ['wir', 'konnen', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 6, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'eat', 'bread']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'eat', 'apple']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'drink', 'water']
# predicted trg = ['ich', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'drink', 'beer']
# predicted trg = ['ich', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'read', 'book']
# predicted trg = ['ich', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['i', 'read', 'newspaper']
# predicted trg = ['ich', 'lesen', 'zeitung', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'eat', 'bread']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'eat', 'apple']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'drink', 'water']
# predicted trg = ['wir', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'drink', 'beer']
# predicted trg = ['wir', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'read', 'book']
# predicted trg = ['wir', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# src = ['we', 'read', 'newspaper']
# predicted trg = ['wir', 'lesen', 'zeitung', '<eos>']
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(np.array(Xs))

map_on_2d(result,Ys,use_word_colors=True,fig_size=[29,20])

# %%
labels = logger.get_summary(labels=["Encoder@src_source"],show_data=False)
datas = logger.get_summary(labels=["Encoder@src_final"],show_data=False)
words = encoding_to_sentence(labels[0].numpy().flatten(),SRC)
#TRG.vocab.itos
#[SRC.vocab.itos[i] for i in datas[0].numpy().flatten() ]
Xs = []

for data in datas[0].squeeze():
    print(data.shape)
    Xs.append( data.numpy() )

pca = PCA(n_components=2)
result = pca.fit_transform(np.array(Xs))

map_on_2d(result,words)
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 5]
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64])

# %%
logger.get_summary(labels=["Encoder@src_final"],show_data=False)
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_final
# [1, 5, 64]
# [tensor([[[-1.9337e-01, -7.8900e-01, -8.7230e-01,  1.2577e+00,  3.4360e-01,
#             8.3445e-02, -4.0788e-01,  1.6345e+00,  1.6095e+00, -1.3308e+00,
#            -4.2792e-01, -2.1580e-02,  1.5845e+00, -1.4013e+00,  3.9967e-01,
#            -6.4281e-02, -1.4281e+00, -8.6014e-01, -1.6537e+00, -1.4083e+00,
#            -1.0780e+00,  6.9341e-01,  1.2596e+00,  1.2786e+00,  1.6875e+00,
#             4.5158e-02,  1.5018e+00,  2.0980e-01, -8.7038e-01,  1.3835e+00,
#            -3.8380e-01, -1.5523e+00,  4.5800e-01,  1.0227e+00, -8.5590e-01,
#             2.5693e-01, -9.2125e-01, -4.9817e-01, -9.1549e-01, -7.3933e-01,
#            -1.4717e+00,  1.2331e+00, -2.9824e-01,  1.3245e+00,  7.1124e-01,
#             1.2697e+00,  6.5600e-01, -1.8847e+00, -2.7039e-01, -2.9948e-01,
#            -6.7006e-01,  1.2682e+00,  9.4268e-01,  4.6222e-01,  1.1112e+00,
#            -1.3980e+00,  2.0136e-01,  5.7736e-01, -1.6079e-01, -1.2311e+00,
#             3.7530e-01, -1.1719e+00, -5.3581e-03,  7.1634e-01],
#           [-7.9385e-01,  1.8135e+00,  1.9578e-01,  1.2440e+00, -1.3985e+00,
#            -3.6419e-02, -5.9032e-01,  4.0963e-01,  2.0264e+00,  4.6491e-01,
#             1.3592e+00,  9.3992e-01,  4.7255e-01, -5.2986e-01,  2.5491e-01,
#            -1.9865e-01,  5.0642e-01, -4.2432e-01,  7.5284e-02,  1.7312e+00,
#             1.0366e+00, -2.9989e-01,  9.3524e-01, -1.3464e+00, -1.4255e+00,
#             5.5305e-01, -5.1310e-01, -5.3534e-01,  9.2154e-01, -1.8469e+00,
#            -6.5238e-01, -3.5772e-01, -1.9754e+00, -8.7387e-01,  1.9990e-01,
#            -3.5659e-01, -1.5607e-01, -1.7910e+00,  8.1695e-01, -1.1143e+00,
#             2.0898e-01,  3.0479e-01, -1.4238e+00,  6.6849e-01,  1.3779e+00,
#             1.1340e+00, -6.8115e-02, -1.8959e-01, -4.6035e-01,  8.4703e-01,
#            -2.4401e-01, -1.4227e+00,  1.5446e-01,  6.6915e-01, -4.9378e-01,
#             6.9260e-01, -1.1369e+00,  1.6484e+00, -1.5344e+00, -1.7511e+00,
#            -3.9525e-01,  1.6896e+00,  1.4376e+00, -4.5730e-01],
#           [-9.2094e-01,  1.3941e+00, -1.7482e-01,  1.4169e+00, -1.3669e+00,
#             8.2122e-01,  4.8046e-01, -1.7932e-01,  4.4572e-01, -5.6836e-01,
#             1.1120e+00,  1.1928e+00, -8.2196e-01,  5.9876e-01, -4.0581e-01,
#            -3.6745e-01, -6.3964e-01,  5.8541e-01, -5.1473e-01,  2.7257e-01,
#            -3.8896e-01,  1.0859e+00,  8.1508e-01, -4.2108e-01, -1.8987e+00,
#             1.5576e+00, -1.0466e+00, -8.5702e-01, -1.9869e-01, -9.4525e-01,
#             8.8793e-02,  8.2193e-01, -5.2591e-01,  3.3327e-01, -1.7004e+00,
#             7.4618e-01, -1.7400e+00, -6.6329e-01,  1.0725e+00,  7.0717e-02,
#             1.1735e-01,  1.4786e-01, -4.3158e-01,  1.3900e+00, -8.1924e-01,
#             1.4640e+00,  7.7821e-01, -9.6391e-01, -4.8134e-01, -2.3005e+00,
#            -2.9028e-01,  3.8099e-01,  2.0013e+00,  1.5522e-01, -3.3765e-01,
#             2.5557e-01, -1.3759e+00,  2.9992e+00, -8.0001e-01, -4.9864e-01,
#            -5.0075e-01, -1.0538e+00,  1.6617e+00, -1.3162e-01],
#           [ 1.1986e+00, -9.2905e-01,  3.4824e-02,  1.0760e+00, -1.5044e+00,
#            -1.2721e+00, -1.2910e+00,  1.1792e+00,  6.4641e-01, -4.4673e-01,
#            -6.3890e-01, -5.4690e-01,  1.2672e+00,  1.1138e+00,  9.3068e-01,
#             8.5660e-01, -5.1087e-01,  1.5820e+00, -1.0422e+00, -1.4301e+00,
#             5.4910e-01,  7.4500e-01, -1.5170e+00,  6.8255e-01,  1.4356e+00,
#             8.9670e-01,  7.1704e-02, -4.7003e-01, -1.6705e+00, -1.1745e+00,
#            -1.2994e+00, -5.9674e-01,  1.2214e+00,  4.8083e-01, -1.6190e-01,
#             1.5832e+00, -1.0723e+00, -3.7497e-01,  5.4261e-02, -1.1432e-03,
#            -6.2935e-01, -5.4947e-01,  3.0351e-01,  4.3898e-01, -3.7486e-01,
#             6.7246e-01, -8.8182e-01, -3.4448e-01,  1.5110e+00, -5.1228e-01,
#             1.2114e+00,  1.5650e+00, -1.0790e+00, -2.6753e-01, -5.5839e-01,
#            -1.1901e-01, -2.1216e+00,  1.3445e+00, -1.1869e+00,  8.7547e-01,
#            -8.0499e-01,  7.9746e-01,  1.9525e+00, -8.8900e-01],
#           [ 7.4209e-01,  4.8696e-01, -1.2117e+00,  1.5967e+00, -2.7687e-01,
#            -8.7570e-01, -7.3973e-01,  6.5096e-01,  2.0579e-01, -1.0719e+00,
#            -2.5010e-01, -1.5462e+00, -9.0836e-01,  1.2033e+00, -8.9297e-01,
#            -8.6239e-01,  1.1913e+00,  1.0013e+00,  9.7189e-02, -1.6898e+00,
#            -3.6476e-01,  4.8559e-01,  1.2246e+00,  2.1638e-01,  4.0007e-01,
#             1.8795e+00, -1.2940e+00,  2.2034e-01,  1.3210e+00,  6.4141e-01,
#            -1.0177e+00, -1.8809e+00,  1.6921e+00,  9.3827e-01, -1.0163e+00,
#            -2.7414e+00,  3.8613e-01,  4.4361e-01, -4.2165e-01, -1.1760e+00,
#            -4.3501e-01, -9.5842e-01,  1.1379e+00,  1.0962e-02,  1.5469e+00,
#            -1.4879e-01, -3.4623e-01, -4.9521e-01,  3.2335e-01,  1.6304e-01,
#            -6.7335e-01, -1.2041e+00, -5.3882e-01, -2.8942e-02,  2.0942e+00,
#             5.8393e-02, -1.1881e+00, -1.2819e-01,  4.7749e-01,  5.9334e-01,
#             4.3357e-01,  5.9963e-01,  4.0054e-01,  1.5157e+00]]])]

# %%
show_on_vis_multi(invalid_sentences_embeddings,valid_sentences,valid_sentences_embeddings,valid_sentences)

# %%
show_on_vis_multi([],[],valid_sentences_embeddings,valid_sentences)

# %%
logger,all_outputs = test_sentence("we drink water",is_appy_attention=False,draw_charts=False)
# Out:
# src = ['we', 'drink', 'water']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']

# %%
test_logger,all_outputs = test_sentence(tabular_set[0].src,draw_charts=False,is_appy_attention=True)
print(tabular_set[0])
trg4 = test_logger.get_summary(labels=["EncoderLayer@src3"],show_data=False)
trg4[0].shape
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# <torchtext.data.example.Example object at 0x0000020066558BC8>
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# torch.Size([1, 7, 64])

# %%
valid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs = test_sentence(tabular_set[i].src,draw_charts=False,is_appy_attention=True)
    #train_data.examples[example_idx].src
    #test_logger.get_default_summary()
    trg4 = test_logger.get_summary(labels=["EncoderLayer@src3"],show_data=False)
    valid_sentences_embeddings.append(trg4[0].squeeze().numpy())
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['i', 'want', 'to', 'eat', 'apple']
# predicted trg = ['ich', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['i', 'want', 'to', 'drink', 'water']
# predicted trg = ['ich', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['i', 'want', 'to', 'drink', 'beer']
# predicted trg = ['ich', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['i', 'want', 'to', 'read', 'book']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['i', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['ich', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['i', 'can', 'eat', 'bread']
# predicted trg = ['ich', 'konnen', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['i', 'can', 'eat', 'apple']
# predicted trg = ['ich', 'konnen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['i', 'can', 'drink', 'water']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['i', 'can', 'drink', 'beer']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['i', 'can', 'read', 'book']
# predicted trg = ['ich', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['i', 'can', 'read', 'newspaper']
# predicted trg = ['ich', 'konnen', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['we', 'want', 'to', 'eat', 'bread']
# predicted trg = ['wir', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['we', 'want', 'to', 'eat', 'apple']
# predicted trg = ['wir', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['we', 'want', 'to', 'drink', 'water']
# predicted trg = ['wir', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['we', 'want', 'to', 'drink', 'beer']
# predicted trg = ['wir', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['we', 'want', 'to', 'read', 'book']
# predicted trg = ['wir', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['we', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['wir', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 7, 64]
# src = ['we', 'can', 'eat', 'bread']
# predicted trg = ['wir', 'konnen', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['we', 'can', 'eat', 'apple']
# predicted trg = ['wir', 'konnen', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['we', 'can', 'drink', 'water']
# predicted trg = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['we', 'can', 'drink', 'beer']
# predicted trg = ['wir', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['we', 'can', 'read', 'book']
# predicted trg = ['wir', 'konnen', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['we', 'can', 'read', 'newspaper']
# predicted trg = ['wir', 'konnen', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 6, 64]
# src = ['i', 'eat', 'bread']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['i', 'eat', 'apple']
# predicted trg = ['ich', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['i', 'drink', 'water']
# predicted trg = ['ich', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['i', 'drink', 'beer']
# predicted trg = ['ich', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['i', 'read', 'book']
# predicted trg = ['ich', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['i', 'read', 'newspaper']
# predicted trg = ['ich', 'lesen', 'zeitung', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['we', 'eat', 'bread']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['we', 'eat', 'apple']
# predicted trg = ['wir', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['we', 'drink', 'water']
# predicted trg = ['wir', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['we', 'drink', 'beer']
# predicted trg = ['wir', 'trinken', 'bier', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['we', 'read', 'book']
# predicted trg = ['wir', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]
# src = ['we', 'read', 'newspaper']
# predicted trg = ['wir', 'lesen', 'zeitung', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@src3
# [1, 5, 64]

# %%
#valid_sentences_embeddings_flat = []
#for embeddings in valid_sentences_embeddings:
#print(valid_sentences_embeddings[0] )
#np.mean(valid_sentences_embeddings[0],axis=0)

# %%
###NP MEAN IS NOT SO GOOD
##FIND ANOTHER WAY
#(7, 64) , (5, 64) all elements have different shape
#here sentence has embedding so must get a summary of these
valid_sentences_embedding_means = []
for embedding in valid_sentences_embeddings:
    #print("embedding",embedding.shape[0])
    valid_sentences_embedding_means.append( np.mean(embedding,axis=0)    )
show_on_vis_multi([],[],valid_sentences_embedding_means,valid_sentences)
print(valid_sentences_embeddings[0].shape)
np.array(valid_sentences_embeddings).shape
# Out:
# (7, 64)
# (36,)

# %%
add_new_logger("sample1")
example_idx = 8

src = vars(train_data.examples[example_idx])['src']
trg = vars(train_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')

currentLogger = StepLogger(100)  
translation, attention, all_outputs = translate_sentence(src, SRC, TRG, model, device,is_appy_attention=True)

print(f'predicted trg = {translation}')
 
display_attention(src, translation, attention,n_heads=get_head_count(),n_rows = get_row_count(), n_cols = get_col_count())
# Out:
# using existing logger
# src = ['i', 'can', 'drink', 'water']
# trg = ['ich', 'konnen', 'wasser', 'trinken']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']

# %%
def draw_df(data,columns,indexes):
    df2 = pd.DataFrame(data,columns=columns,index=indexes)
    cm = sns.light_palette("blue", as_cmap=True)
    styled_df = df2.style.background_gradient(cmap=cm)
    display(styled_df)

# %%
#test_logger.get_default_summary(show_data=True)
for index in range(1):
    
    test_logger,all_outputs = test_sentence(tabular_set[index].src,draw_charts=False,is_appy_attention=True)
    encoded_attention = test_logger.get_summary(["EncoderLayer@sattention"],show_data=False)
    
    src_masks = test_logger.get_summary(["EncoderLayer@src_mask"],show_data=False,summary_count=10)
    print("EncoderLayersrc_masks",src_masks)
    
    decodersrc_masks = test_logger.get_summary(["DecoderLayer@src_mask"],show_data=False,summary_count=10)
    print("decodersrc_masks",decodersrc_masks)
    
    
    decoder_attention = test_logger.get_summary(["Decoder@attention"],show_data=False,summary_count=10)
    print("decoder_attention",decoder_attention[0].shape)
    print("decoder_attention",decoder_attention[0])
    
    decodertrg_masks = test_logger.get_summary(["DecoderLayer@trg_mask"],show_data=False,summary_count=10)
    for index2,dm in enumerate(decodertrg_masks):
        print("decodertrg_masks",index2)
        print(dm)
    
    output_words = ["sos"]+tabular_set[index].src  +["eos"]
    for head_index in range(encoded_attention[0].shape[1]):
        all_outputs0 = encoded_attention[0][:,head_index,:,:]
        draw_df(all_outputs0.squeeze().numpy(),output_words,output_words)
    
    ### OPEN THIS COMMENT FOR MULTI HEAD all_outputs1 = encoded_attention[0][:,1,:,:]
    ###draw_df(all_outputs1.squeeze().numpy(),output_words,output_words)
#df2 = pd.DataFrame(all_outputs.squeeze().numpy(),columns=output_words,index=output_words)
#cm = sns.light_palette("blue", as_cmap=True)

#styled_df = df2.style.background_gradient(cmap=cm)
#styled_df
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# summary_count 10    self.capacity  20
# EncoderLayer@src_mask
# [1, 1, 1, 7]
# EncoderLayersrc_masks [tensor([[[[True, True, True, True, True, True, True]]]])]
# summary_count 10    self.capacity  20
# DecoderLayer@src_mask
# [1, 1, 1, 7]
# DecoderLayer@src_mask
# [1, 1, 1, 7]
# DecoderLayer@src_mask
# [1, 1, 1, 7]
# DecoderLayer@src_mask
# [1, 1, 1, 7]
# DecoderLayer@src_mask
# [1, 1, 1, 7]
# decodersrc_masks [tensor([[[[True, True, True, True, True, True, True]]]]), tensor([[[[True, True, True, True, True, True, True]]]]), tensor([[[[True, True, True, True, True, True, True]]]]), tensor([[[[True, True, True, True, True, True, True]]]]), tensor([[[[True, True, True, True, True, True, True]]]])]
# summary_count 10    self.capacity  20
# Decoder@attention
# [1, 2, 1, 7]
# Decoder@attention
# [1, 2, 2, 7]
# Decoder@attention
# [1, 2, 3, 7]
# Decoder@attention
# [1, 2, 4, 7]
# Decoder@attention
# [1, 2, 5, 7]
# decoder_attention torch.Size([1, 2, 1, 7])
# decoder_attention tensor([[[[1.6918e-02, 5.6569e-01, 2.5716e-01, 4.5474e-02, 1.3800e-02,
#            7.0645e-02, 3.0315e-02]],
#
#          [[4.6870e-04, 7.9518e-01, 2.1454e-02, 1.2384e-01, 3.8425e-02,
#            7.7674e-03, 1.2866e-02]]]])
# summary_count 10    self.capacity  20
# DecoderLayer@trg_mask
# [1, 1, 1, 1]
# DecoderLayer@trg_mask
# [1, 1, 2, 2]
# DecoderLayer@trg_mask
# [1, 1, 3, 3]
# DecoderLayer@trg_mask
# [1, 1, 4, 4]
# DecoderLayer@trg_mask
# [1, 1, 5, 5]
# decodertrg_masks 0
# tensor([[[[True]]]])
# decodertrg_masks 1
# tensor([[[[ True, False],
#           [ True,  True]]]])
# decodertrg_masks 2
# tensor([[[[ True, False, False],
#           [ True,  True, False],
#           [ True,  True,  True]]]])
# decodertrg_masks 3
# tensor([[[[ True, False, False, False],
#           [ True,  True, False, False],
#           [ True,  True,  True, False],
#           [ True,  True,  True,  True]]]])
# decodertrg_masks 4
# tensor([[[[ True, False, False, False, False],
#           [ True,  True, False, False, False],
#           [ True,  True,  True, False, False],
#           [ True,  True,  True,  True, False],
#           [ True,  True,  True,  True,  True]]]])
# <style  type="text/css" >
# #T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col0,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col3{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col1{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col2,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col3,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col1,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col4,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col0,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col6,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col3,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col6,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col6,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col4{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col5,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col0{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col6{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col1,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col2{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col3{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col5{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col0,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col3{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col1{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col4,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col5{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col5,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col6,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col3,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col2,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col0,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col1,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col4,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col2{
#             background-color:  #4f4ffb;
#             color:  #f1f1f1;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row3_col6,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col5{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col0{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col1{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col4,#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row4_col5{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row5_col4{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_3ee83af0_3893_11eb_867b_c49ded8dff66row6_col3{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }</style><table id="T_3ee83af0_3893_11eb_867b_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >eat</th>        <th class="col_heading level0 col5" >bread</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ee83af0_3893_11eb_867b_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col0" class="data row0 col0" >0.034296</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col1" class="data row0 col1" >0.022736</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col2" class="data row0 col2" >0.588869</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col3" class="data row0 col3" >0.080685</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col4" class="data row0 col4" >0.034747</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col5" class="data row0 col5" >0.050313</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row0_col6" class="data row0 col6" >0.188353</td>
#             </tr>
#             <tr>
#                         <th id="T_3ee83af0_3893_11eb_867b_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col0" class="data row1 col0" >0.095289</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col1" class="data row1 col1" >0.008989</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col2" class="data row1 col2" >0.021511</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col3" class="data row1 col3" >0.365728</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col4" class="data row1 col4" >0.045538</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col5" class="data row1 col5" >0.438121</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row1_col6" class="data row1 col6" >0.024824</td>
#             </tr>
#             <tr>
#                         <th id="T_3ee83af0_3893_11eb_867b_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col0" class="data row2 col0" >0.092344</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col1" class="data row2 col1" >0.017648</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col2" class="data row2 col2" >0.037594</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col3" class="data row2 col3" >0.831976</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col4" class="data row2 col4" >0.012347</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col5" class="data row2 col5" >0.005322</td>
#                         <td id="T_3ee83af0_3893_11eb_867b_c49ded8dff66row2_col6" class="data row2 col6" >0.002770</td>
#             </tr>
#             <tr>
# <style  type="text/css" >
# #T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col0{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col1{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col2{
#             background-color:  #d0d0f4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col3{
#             background-color:  #9898f7;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col4,#T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col6,#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col0,#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col3,#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col1,#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col2,#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col5{
#             background-color:  #8585f8;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col1,#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col3,#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col3{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col2{
#             background-color:  #8282f8;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col3{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col4{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col5,#T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col6,#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col2,#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col0,#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col1,#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col2,#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col3,#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col0{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col1{
#             background-color:  #7373f9;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col2{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col4{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col5,#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col2{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col6{
#             background-color:  #2b2bfd;
#             color:  #f1f1f1;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col0,#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col5{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col3{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col4{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col5{
#             background-color:  #d1d1f4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row3_col6{
#             background-color:  #bcbcf5;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col0{
#             background-color:  #b4b4f6;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col1{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col4{
#             background-color:  #4e4efb;
#             color:  #f1f1f1;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row4_col6{
#             background-color:  #2a2afd;
#             color:  #f1f1f1;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row5_col6{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col0,#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col1{
#             background-color:  #6363fa;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col4{
#             background-color:  #cbcbf5;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col5{
#             background-color:  #dfdff4;
#             color:  #000000;
#         }#T_3eee071c_3893_11eb_9962_c49ded8dff66row6_col6{
#             background-color:  #2828fd;
#             color:  #f1f1f1;
#         }</style><table id="T_3eee071c_3893_11eb_9962_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >eat</th>        <th class="col_heading level0 col5" >bread</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3eee071c_3893_11eb_9962_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col0" class="data row0 col0" >0.090073</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col1" class="data row0 col1" >0.048946</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col2" class="data row0 col2" >0.058244</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col3" class="data row0 col3" >0.096331</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col4" class="data row0 col4" >0.180288</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col5" class="data row0 col5" >0.432964</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row0_col6" class="data row0 col6" >0.093154</td>
#             </tr>
#             <tr>
#                         <th id="T_3eee071c_3893_11eb_9962_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col0" class="data row1 col0" >0.569088</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col1" class="data row1 col1" >0.157484</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col2" class="data row1 col2" >0.193103</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col3" class="data row1 col3" >0.028445</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col4" class="data row1 col4" >0.047949</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col5" class="data row1 col5" >0.003360</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row1_col6" class="data row1 col6" >0.000570</td>
#             </tr>
#             <tr>
#                         <th id="T_3eee071c_3893_11eb_9962_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col0" class="data row2 col0" >0.023103</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col1" class="data row2 col1" >0.375528</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col2" class="data row2 col2" >0.130666</td>
#                         <td id="T_3eee071c_3893_11eb_9962_c49ded8dff66row2_col3" class="data row2 col3" >0.251670</td>

# %%
loggers.keys()
# Out:
# dict_keys(['training', 'test_loss', 'iwanttoeatbread115536', 'iwanttoeatapple30632', 'iwanttodrinkwater1964', 'iwanttodrinkbeer23762', 'iwanttoreadbook152628', 'iwanttoreadnewspaper9156', 'icaneatbread176047', 'icaneatapple22004', 'icandrinkwater25801', 'icandrinkbeer92966', 'icanreadbook62079', 'icanreadnewspaper4569', 'wewanttoeatbread8078', 'wewanttoeatapple4153', 'wewanttodrinkwater90726', 'wewanttodrinkbeer169953', 'wewanttoreadbook163390', 'wewanttoreadnewspaper126943', 'wecaneatbread161433', 'wecaneatapple121517', 'wecandrinkwater38943', 'wecandrinkbeer23931', 'wecanreadbook47997', 'wecanreadnewspaper29993', 'ieatbread3833', 'ieatapple131881', 'idrinkwater127599', 'idrinkbeer65491', 'ireadbook16925', 'ireadnewspaper174918', 'weeatbread141844', 'weeatapple122133', 'wedrinkwater17976', 'wedrinkbeer157671', 'wereadbook176981', 'wereadnewspaper23313', 'iwanttoeatbread135016', 'iwanttoeatapple151783', 'iwanttodrinkwater12050', 'iwanttodrinkbeer70671', 'iwanttoreadbook145866', 'iwanttoreadnewspaper16536', 'icaneatbread168987', 'icaneatapple79280', 'icandrinkwater126101', 'icandrinkbeer93124', 'icanreadbook69850', 'icanreadnewspaper65314', 'wewanttoeatbread171831', 'wewanttoeatapple52438', 'wewanttodrinkwater118853', 'wewanttodrinkbeer138979', 'wewanttoreadbook174434', 'wewanttoreadnewspaper5060', 'wecaneatbread133196', 'wecaneatapple18505', 'wecandrinkwater1516', 'wecandrinkbeer87428', 'wecanreadbook37689', 'wecanreadnewspaper123949', 'ieatbread172322', 'ieatapple98920', 'idrinkwater43808', 'idrinkbeer14202', 'ireadbook19985', 'ireadnewspaper154018', 'weeatbread130176', 'weeatapple42993', 'wedrinkwater19746', 'wedrinkbeer146101', 'wereadbook56386', 'wereadnewspaper37814', 'icaneatbread7112', 'icaneatbread90763', 'iwanttoeatbread29069', 'iwanttoeatapple138854', 'iwanttodrinkwater37023', 'iwanttodrinkbeer175769', 'iwanttoreadbook80057', 'iwanttoreadnewspaper119051', 'icaneatbread10379', 'icaneatapple109118', 'icandrinkwater72558', 'icandrinkbeer173641', 'icanreadbook10540', 'icanreadnewspaper46490', 'wewanttoeatbread71217', 'wewanttoeatapple40520', 'wewanttodrinkwater78715', 'wewanttodrinkbeer40515', 'wewanttoreadbook121767', 'wewanttoreadnewspaper10765', 'wecaneatbread147615', 'wecaneatapple101236', 'wecandrinkwater91644', 'wecandrinkbeer129986', 'wecanreadbook89577', 'wecanreadnewspaper152794', 'ieatbread122715', 'ieatapple124764', 'idrinkwater11883', 'idrinkbeer123428', 'ireadbook155954', 'ireadnewspaper44557', 'weeatbread115238', 'weeatapple136109', 'wedrinkwater114786', 'wedrinkbeer77511', 'wereadbook72101', 'wereadnewspaper32474', 'wedrinkwater48660', 'iwanttoeatbread109138', 'iwanttoeatbread114311', 'iwanttoeatapple31318', 'iwanttodrinkwater138884', 'iwanttodrinkbeer27026', 'iwanttoreadbook127193', 'iwanttoreadnewspaper98782', 'icaneatbread172070', 'icaneatapple66972', 'icandrinkwater168046', 'icandrinkbeer50178', 'icanreadbook90532', 'icanreadnewspaper28353', 'wewanttoeatbread41202', 'wewanttoeatapple152153', 'wewanttodrinkwater70604', 'wewanttodrinkbeer40593', 'wewanttoreadbook84801', 'wewanttoreadnewspaper117093', 'wecaneatbread18553', 'wecaneatapple20577', 'wecandrinkwater103611', 'wecandrinkbeer56139', 'wecanreadbook12514', 'wecanreadnewspaper75009', 'ieatbread9961', 'ieatapple57513', 'idrinkwater132833', 'idrinkbeer22982', 'ireadbook83096', 'ireadnewspaper80118', 'weeatbread120805', 'weeatapple17362', 'wedrinkwater153349', 'wedrinkbeer67484', 'wereadbook19137', 'wereadnewspaper111754', 'sample1', 'iwanttoeatbread52927'])

# %%
loggers["training"].get_default_summary()
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [8, 7]
# Encoder@src
# [8, 7]
# Encoder@pos
# [8, 7]
# encoder@Q
# [8, 2, 7, 32]
# encoder@K
# [8, 2, 7, 32]
# encoder@V
# [8, 2, 7, 32]
# encoder@energy
# [8, 2, 7, 7]
# encoder@mask
# [8, 1, 1, 7]
# encoder@attention
# [8, 2, 7, 7]
# encoder@x1
# [8, 2, 7, 32]
# encoder@x2
# [8, 7, 2, 32]
# encoder@x3
# [8, 7, 64]
# encoder@x4
# [8, 7, 64]
# PositionwiseFeedforwardLayer@x1
# [8, 7, 128]
# PositionwiseFeedforwardLayer@x2
# [8, 7, 64]
# EncoderLayer@_src
# [8, 7, 64]
# EncoderLayer@src2
# [8, 7, 64]
# EncoderLayer@_src2
# [8, 7, 64]
# EncoderLayer@src3
# [8, 7, 64]
# EncoderLayer@src_mask
# [8, 1, 1, 7]
# EncoderLayer@sattention
# [8, 2, 7, 7]
# Encoder@src_final
# [8, 7, 64]
# decoder_self@Q
# [8, 2, 5, 32]
# decoder_self@K
# [8, 2, 5, 32]
# decoder_self@V
# [8, 2, 5, 32]
# decoder_self@energy
# [8, 2, 5, 5]
# decoder_self@mask
# [8, 1, 5, 5]
# decoder_self@attention
# [8, 2, 5, 5]
# decoder_self@x1
# [8, 2, 5, 32]
# decoder_self@x2
# [8, 5, 2, 32]
# decoder_self@x3
# [8, 5, 64]
# decoder_self@x4
# [8, 5, 64]
# decoder_encoder_attention@Q
# [8, 2, 5, 32]
# decoder_encoder_attention@K
# [8, 2, 7, 32]
# decoder_encoder_attention@V
# [8, 2, 7, 32]
# decoder_encoder_attention@energy
# [8, 2, 5, 7]
# decoder_encoder_attention@mask
# [8, 1, 1, 7]
# decoder_encoder_attention@attention
# [8, 2, 5, 7]
# decoder_encoder_attention@x1
# [8, 2, 5, 32]
# decoder_encoder_attention@x2
# [8, 5, 2, 32]
# decoder_encoder_attention@x3
# [8, 5, 64]
# decoder_encoder_attention@x4
# [8, 5, 64]
# DecoderLayer@_trg1
# [8, 5, 64]
# DecoderLayer@trg2
# [8, 5, 64]
# DecoderLayer@_trg2
# [8, 5, 64]
# DecoderLayer@trg3
# [8, 5, 64]
# DecoderLayer@_trg3
# [8, 5, 64]
# DecoderLayer@trg4
# [8, 5, 64]
# DecoderLayer@attention
# [8, 2, 5, 7]
# DecoderLayer@trg_mask
# [8, 1, 5, 5]
# DecoderLayer@src_mask
# [8, 1, 1, 7]
# Decoder@pos
# [8, 5]
# Decoder@trg
# [8, 5, 64]
# Decoder@output
# [8, 5, 17]
# Decoder@attention
# [8, 2, 5, 7]
# Seq2Seq@src_mask
# [8, 1, 1, 7]
# Seq2Seq@trg_mask
# [8, 1, 5, 5]
# Seq2Seq@enc_src
# [8, 7, 64]
# Seq2Seq@output
# [8, 5, 17]
# Seq2Seq@attention
# [8, 2, 5, 7]

# %%
loggers["test_loss"].get_default_summary()
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [8, 5]
# Encoder@src
# [8, 5]
# Encoder@pos
# [8, 5]
# encoder@Q
# [8, 2, 5, 32]
# encoder@K
# [8, 2, 5, 32]
# encoder@V
# [8, 2, 5, 32]
# encoder@energy
# [8, 2, 5, 5]
# encoder@mask
# [8, 1, 1, 5]
# encoder@attention
# [8, 2, 5, 5]
# encoder@x1
# [8, 2, 5, 32]
# encoder@x2
# [8, 5, 2, 32]
# encoder@x3
# [8, 5, 64]
# encoder@x4
# [8, 5, 64]
# PositionwiseFeedforwardLayer@x1
# [8, 5, 128]
# PositionwiseFeedforwardLayer@x2
# [8, 5, 64]
# EncoderLayer@_src
# [8, 5, 64]
# EncoderLayer@src2
# [8, 5, 64]
# EncoderLayer@_src2
# [8, 5, 64]
# EncoderLayer@src3
# [8, 5, 64]
# EncoderLayer@src_mask
# [8, 1, 1, 5]
# EncoderLayer@sattention
# [8, 2, 5, 5]
# Encoder@src_final
# [8, 5, 64]
# decoder_self@Q
# [8, 2, 4, 32]
# decoder_self@K
# [8, 2, 4, 32]
# decoder_self@V
# [8, 2, 4, 32]
# decoder_self@energy
# [8, 2, 4, 4]
# decoder_self@mask
# [8, 1, 4, 4]
# decoder_self@attention
# [8, 2, 4, 4]
# decoder_self@x1
# [8, 2, 4, 32]
# decoder_self@x2
# [8, 4, 2, 32]
# decoder_self@x3
# [8, 4, 64]
# decoder_self@x4
# [8, 4, 64]
# decoder_encoder_attention@Q
# [8, 2, 4, 32]
# decoder_encoder_attention@K
# [8, 2, 5, 32]
# decoder_encoder_attention@V
# [8, 2, 5, 32]
# decoder_encoder_attention@energy
# [8, 2, 4, 5]
# decoder_encoder_attention@mask
# [8, 1, 1, 5]
# decoder_encoder_attention@attention
# [8, 2, 4, 5]
# decoder_encoder_attention@x1
# [8, 2, 4, 32]
# decoder_encoder_attention@x2
# [8, 4, 2, 32]
# decoder_encoder_attention@x3
# [8, 4, 64]
# decoder_encoder_attention@x4
# [8, 4, 64]
# DecoderLayer@_trg1
# [8, 4, 64]
# DecoderLayer@trg2
# [8, 4, 64]
# DecoderLayer@_trg2
# [8, 4, 64]
# DecoderLayer@trg3
# [8, 4, 64]
# DecoderLayer@_trg3
# [8, 4, 64]
# DecoderLayer@trg4
# [8, 4, 64]
# DecoderLayer@attention
# [8, 2, 4, 5]
# DecoderLayer@trg_mask
# [8, 1, 4, 4]
# DecoderLayer@src_mask
# [8, 1, 1, 5]
# Decoder@pos
# [8, 4]
# Decoder@trg
# [8, 4, 64]
# Decoder@output
# [8, 4, 17]
# Decoder@attention
# [8, 2, 4, 5]
# Seq2Seq@src_mask
# [8, 1, 1, 5]
# Seq2Seq@trg_mask
# [8, 1, 4, 4]
# Seq2Seq@enc_src
# [8, 5, 64]
# Seq2Seq@output
# [8, 4, 17]
# Seq2Seq@attention
# [8, 2, 4, 5]

# %%
loggers["sample1"].get_default_summary()
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# Encoder@src
# [1, 6]
# Encoder@pos
# [1, 6]
# encoder@Q
# [1, 2, 6, 32]
# encoder@K
# [1, 2, 6, 32]
# encoder@V
# [1, 2, 6, 32]
# encoder@energy
# [1, 2, 6, 6]
# encoder@mask
# [1, 1, 1, 6]
# encoder@attention
# [1, 2, 6, 6]
# encoder@x1
# [1, 2, 6, 32]
# encoder@x2
# [1, 6, 2, 32]
# encoder@x3
# [1, 6, 64]
# encoder@x4
# [1, 6, 64]
# PositionwiseFeedforwardLayer@x1
# [1, 6, 128]
# PositionwiseFeedforwardLayer@x2
# [1, 6, 64]
# EncoderLayer@_src
# [1, 6, 64]
# EncoderLayer@src2
# [1, 6, 64]
# EncoderLayer@_src2
# [1, 6, 64]
# EncoderLayer@src3
# [1, 6, 64]
# EncoderLayer@src_mask
# [1, 1, 1, 6]
# EncoderLayer@sattention
# [1, 2, 6, 6]
# Encoder@src_final
# [1, 6, 64]
# decoder_self@Q
# [1, 2, 1, 32]
# decoder_self@K
# [1, 2, 1, 32]
# decoder_self@V
# [1, 2, 1, 32]
# decoder_self@energy
# [1, 2, 1, 1]
# decoder_self@mask
# [1, 1, 1, 1]
# decoder_self@attention
# [1, 2, 1, 1]
# decoder_self@x1
# [1, 2, 1, 32]
# decoder_self@x2
# [1, 1, 2, 32]
# decoder_self@x3
# [1, 1, 64]
# decoder_self@x4
# [1, 1, 64]
# decoder_encoder_attention@Q
# [1, 2, 1, 32]
# decoder_encoder_attention@K
# [1, 2, 6, 32]
# decoder_encoder_attention@V
# [1, 2, 6, 32]
# decoder_encoder_attention@energy
# [1, 2, 1, 6]
# decoder_encoder_attention@mask
# [1, 1, 1, 6]
# decoder_encoder_attention@attention
# [1, 2, 1, 6]
# decoder_encoder_attention@x1
# [1, 2, 1, 32]
# decoder_encoder_attention@x2
# [1, 1, 2, 32]
# decoder_encoder_attention@x3
# [1, 1, 64]
# decoder_encoder_attention@x4
# [1, 1, 64]
# DecoderLayer@_trg1
# [1, 1, 64]
# DecoderLayer@trg2
# [1, 1, 64]
# DecoderLayer@_trg2
# [1, 1, 64]
# DecoderLayer@trg3
# [1, 1, 64]
# DecoderLayer@_trg3
# [1, 1, 64]
# DecoderLayer@trg4
# [1, 1, 64]
# DecoderLayer@attention
# [1, 2, 1, 6]
# DecoderLayer@trg_mask
# [1, 1, 1, 1]
# DecoderLayer@src_mask
# [1, 1, 1, 6]
# Decoder@pos
# [1, 1]
# Decoder@trg
# [1, 1, 64]
# Decoder@output
# [1, 1, 17]
# Decoder@attention
# [1, 2, 1, 6]

# %%
current_logger.get_default_summary(show_data=False)
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 7]
# Encoder@src
# [1, 7]
# Encoder@pos
# [1, 7]
# encoder@Q
# [1, 2, 7, 32]
# encoder@K
# [1, 2, 7, 32]
# encoder@V
# [1, 2, 7, 32]
# encoder@energy
# [1, 2, 7, 7]
# encoder@mask
# [1, 1, 1, 7]
# encoder@attention
# [1, 2, 7, 7]
# encoder@x1
# [1, 2, 7, 32]
# encoder@x2
# [1, 7, 2, 32]
# encoder@x3
# [1, 7, 64]
# encoder@x4
# [1, 7, 64]
# PositionwiseFeedforwardLayer@x1
# [1, 7, 128]
# PositionwiseFeedforwardLayer@x2
# [1, 7, 64]
# EncoderLayer@_src
# [1, 7, 64]
# EncoderLayer@src2
# [1, 7, 64]
# EncoderLayer@_src2
# [1, 7, 64]
# EncoderLayer@src3
# [1, 7, 64]
# EncoderLayer@src_mask
# [1, 1, 1, 7]
# EncoderLayer@sattention
# [1, 2, 7, 7]
# Encoder@src_final
# [1, 7, 64]
# decoder_self@Q
# [1, 2, 1, 32]
# decoder_self@K
# [1, 2, 1, 32]
# decoder_self@V
# [1, 2, 1, 32]
# decoder_self@energy
# [1, 2, 1, 1]
# decoder_self@mask
# [1, 1, 1, 1]
# decoder_self@attention
# [1, 2, 1, 1]
# decoder_self@x1
# [1, 2, 1, 32]
# decoder_self@x2
# [1, 1, 2, 32]
# decoder_self@x3
# [1, 1, 64]
# decoder_self@x4
# [1, 1, 64]
# decoder_encoder_attention@Q
# [1, 2, 1, 32]
# decoder_encoder_attention@K
# [1, 2, 7, 32]
# decoder_encoder_attention@V
# [1, 2, 7, 32]
# decoder_encoder_attention@energy
# [1, 2, 1, 7]
# decoder_encoder_attention@mask
# [1, 1, 1, 7]
# decoder_encoder_attention@attention
# [1, 2, 1, 7]
# decoder_encoder_attention@x1
# [1, 2, 1, 32]
# decoder_encoder_attention@x2
# [1, 1, 2, 32]
# decoder_encoder_attention@x3
# [1, 1, 64]
# decoder_encoder_attention@x4
# [1, 1, 64]
# DecoderLayer@_trg1
# [1, 1, 64]
# DecoderLayer@trg2
# [1, 1, 64]
# DecoderLayer@_trg2
# [1, 1, 64]
# DecoderLayer@trg3
# [1, 1, 64]
# DecoderLayer@_trg3
# [1, 1, 64]
# DecoderLayer@trg4
# [1, 1, 64]
# DecoderLayer@attention
# [1, 2, 1, 7]
# DecoderLayer@trg_mask
# [1, 1, 1, 1]
# DecoderLayer@src_mask
# [1, 1, 1, 7]
# Decoder@pos
# [1, 1]
# Decoder@trg
# [1, 1, 64]
# Decoder@output
# [1, 1, 17]
# Decoder@attention
# [1, 2, 1, 7]

# %%
#currentLogger.get_default_summary(show_data=False)

# %%
#currentLogger.get_summary(labels=["Q"],show_data=True)

# %%
loggers.keys()
# Out:
# dict_keys(['training', 'test_loss', 'iwanttoeatbread115536', 'iwanttoeatapple30632', 'iwanttodrinkwater1964', 'iwanttodrinkbeer23762', 'iwanttoreadbook152628', 'iwanttoreadnewspaper9156', 'icaneatbread176047', 'icaneatapple22004', 'icandrinkwater25801', 'icandrinkbeer92966', 'icanreadbook62079', 'icanreadnewspaper4569', 'wewanttoeatbread8078', 'wewanttoeatapple4153', 'wewanttodrinkwater90726', 'wewanttodrinkbeer169953', 'wewanttoreadbook163390', 'wewanttoreadnewspaper126943', 'wecaneatbread161433', 'wecaneatapple121517', 'wecandrinkwater38943', 'wecandrinkbeer23931', 'wecanreadbook47997', 'wecanreadnewspaper29993', 'ieatbread3833', 'ieatapple131881', 'idrinkwater127599', 'idrinkbeer65491', 'ireadbook16925', 'ireadnewspaper174918', 'weeatbread141844', 'weeatapple122133', 'wedrinkwater17976', 'wedrinkbeer157671', 'wereadbook176981', 'wereadnewspaper23313', 'iwanttoeatbread135016', 'iwanttoeatapple151783', 'iwanttodrinkwater12050', 'iwanttodrinkbeer70671', 'iwanttoreadbook145866', 'iwanttoreadnewspaper16536', 'icaneatbread168987', 'icaneatapple79280', 'icandrinkwater126101', 'icandrinkbeer93124', 'icanreadbook69850', 'icanreadnewspaper65314', 'wewanttoeatbread171831', 'wewanttoeatapple52438', 'wewanttodrinkwater118853', 'wewanttodrinkbeer138979', 'wewanttoreadbook174434', 'wewanttoreadnewspaper5060', 'wecaneatbread133196', 'wecaneatapple18505', 'wecandrinkwater1516', 'wecandrinkbeer87428', 'wecanreadbook37689', 'wecanreadnewspaper123949', 'ieatbread172322', 'ieatapple98920', 'idrinkwater43808', 'idrinkbeer14202', 'ireadbook19985', 'ireadnewspaper154018', 'weeatbread130176', 'weeatapple42993', 'wedrinkwater19746', 'wedrinkbeer146101', 'wereadbook56386', 'wereadnewspaper37814', 'icaneatbread7112', 'icaneatbread90763', 'iwanttoeatbread29069', 'iwanttoeatapple138854', 'iwanttodrinkwater37023', 'iwanttodrinkbeer175769', 'iwanttoreadbook80057', 'iwanttoreadnewspaper119051', 'icaneatbread10379', 'icaneatapple109118', 'icandrinkwater72558', 'icandrinkbeer173641', 'icanreadbook10540', 'icanreadnewspaper46490', 'wewanttoeatbread71217', 'wewanttoeatapple40520', 'wewanttodrinkwater78715', 'wewanttodrinkbeer40515', 'wewanttoreadbook121767', 'wewanttoreadnewspaper10765', 'wecaneatbread147615', 'wecaneatapple101236', 'wecandrinkwater91644', 'wecandrinkbeer129986', 'wecanreadbook89577', 'wecanreadnewspaper152794', 'ieatbread122715', 'ieatapple124764', 'idrinkwater11883', 'idrinkbeer123428', 'ireadbook155954', 'ireadnewspaper44557', 'weeatbread115238', 'weeatapple136109', 'wedrinkwater114786', 'wedrinkbeer77511', 'wereadbook72101', 'wereadnewspaper32474', 'wedrinkwater48660', 'iwanttoeatbread109138', 'iwanttoeatbread114311', 'iwanttoeatapple31318', 'iwanttodrinkwater138884', 'iwanttodrinkbeer27026', 'iwanttoreadbook127193', 'iwanttoreadnewspaper98782', 'icaneatbread172070', 'icaneatapple66972', 'icandrinkwater168046', 'icandrinkbeer50178', 'icanreadbook90532', 'icanreadnewspaper28353', 'wewanttoeatbread41202', 'wewanttoeatapple152153', 'wewanttodrinkwater70604', 'wewanttodrinkbeer40593', 'wewanttoreadbook84801', 'wewanttoreadnewspaper117093', 'wecaneatbread18553', 'wecaneatapple20577', 'wecandrinkwater103611', 'wecandrinkbeer56139', 'wecanreadbook12514', 'wecanreadnewspaper75009', 'ieatbread9961', 'ieatapple57513', 'idrinkwater132833', 'idrinkbeer22982', 'ireadbook83096', 'ireadnewspaper80118', 'weeatbread120805', 'weeatapple17362', 'wedrinkwater153349', 'wedrinkbeer67484', 'wereadbook19137', 'wereadnewspaper111754', 'sample1', 'iwanttoeatbread52927'])

# %%
loggers["sample1"].get_default_summary(show_data=False)
# Out:
# summary_count 1    self.capacity  20
# Encoder@src_source
# [1, 6]
# Encoder@src
# [1, 6]
# Encoder@pos
# [1, 6]
# encoder@Q
# [1, 2, 6, 32]
# encoder@K
# [1, 2, 6, 32]
# encoder@V
# [1, 2, 6, 32]
# encoder@energy
# [1, 2, 6, 6]
# encoder@mask
# [1, 1, 1, 6]
# encoder@attention
# [1, 2, 6, 6]
# encoder@x1
# [1, 2, 6, 32]
# encoder@x2
# [1, 6, 2, 32]
# encoder@x3
# [1, 6, 64]
# encoder@x4
# [1, 6, 64]
# PositionwiseFeedforwardLayer@x1
# [1, 6, 128]
# PositionwiseFeedforwardLayer@x2
# [1, 6, 64]
# EncoderLayer@_src
# [1, 6, 64]
# EncoderLayer@src2
# [1, 6, 64]
# EncoderLayer@_src2
# [1, 6, 64]
# EncoderLayer@src3
# [1, 6, 64]
# EncoderLayer@src_mask
# [1, 1, 1, 6]
# EncoderLayer@sattention
# [1, 2, 6, 6]
# Encoder@src_final
# [1, 6, 64]
# decoder_self@Q
# [1, 2, 1, 32]
# decoder_self@K
# [1, 2, 1, 32]
# decoder_self@V
# [1, 2, 1, 32]
# decoder_self@energy
# [1, 2, 1, 1]
# decoder_self@mask
# [1, 1, 1, 1]
# decoder_self@attention
# [1, 2, 1, 1]
# decoder_self@x1
# [1, 2, 1, 32]
# decoder_self@x2
# [1, 1, 2, 32]
# decoder_self@x3
# [1, 1, 64]
# decoder_self@x4
# [1, 1, 64]
# decoder_encoder_attention@Q
# [1, 2, 1, 32]
# decoder_encoder_attention@K
# [1, 2, 6, 32]
# decoder_encoder_attention@V
# [1, 2, 6, 32]
# decoder_encoder_attention@energy
# [1, 2, 1, 6]
# decoder_encoder_attention@mask
# [1, 1, 1, 6]
# decoder_encoder_attention@attention
# [1, 2, 1, 6]
# decoder_encoder_attention@x1
# [1, 2, 1, 32]
# decoder_encoder_attention@x2
# [1, 1, 2, 32]
# decoder_encoder_attention@x3
# [1, 1, 64]
# decoder_encoder_attention@x4
# [1, 1, 64]
# DecoderLayer@_trg1
# [1, 1, 64]
# DecoderLayer@trg2
# [1, 1, 64]
# DecoderLayer@_trg2
# [1, 1, 64]
# DecoderLayer@trg3
# [1, 1, 64]
# DecoderLayer@_trg3
# [1, 1, 64]
# DecoderLayer@trg4
# [1, 1, 64]
# DecoderLayer@attention
# [1, 2, 1, 6]
# DecoderLayer@trg_mask
# [1, 1, 1, 1]
# DecoderLayer@src_mask
# [1, 1, 1, 6]
# Decoder@pos
# [1, 1]
# Decoder@trg
# [1, 1, 64]
# Decoder@output
# [1, 1, 17]
# Decoder@attention
# [1, 2, 1, 6]

# %%
attention_orig = loggers["sample1"].get_summary(labels=["decoder_encoder_attention@attention"],show_data=True)
trg4 = loggers["sample1"].get_summary(labels=["DecoderLayer@trg4"],show_data=True)
# Out:
# summary_count 1    self.capacity  20
# decoder_encoder_attention@attention
# [1, 2, 1, 6]
# tensor([[[[2.1161e-02, 7.2476e-01, 4.0099e-02, 1.4065e-01, 7.4529e-03,
#            6.5882e-02]],
#
#          [[8.0389e-04, 9.4855e-01, 7.7486e-03, 1.4607e-02, 2.1380e-02,
#            6.9088e-03]]]])
# summary_count 1    self.capacity  20
# DecoderLayer@trg4
# [1, 1, 64]
# tensor([[[ 0.3603,  1.7626, -0.3586,  0.6935,  1.2651, -0.2925, -0.0436,
#           -0.5562, -0.3115,  0.9064, -0.4742,  1.4936, -0.3818, -0.3678,
#            0.7862,  0.4679,  0.7060, -1.4455,  0.5322,  0.9467, -0.4730,
#            0.8733,  0.5838, -1.0657,  0.0359, -0.9213, -0.3241, -1.3886,
#            0.1344,  0.5917, -0.6518, -0.2827,  0.2336,  0.9715, -0.5938,
#           -2.3789,  0.5107, -1.0930,  0.9688, -0.0181, -0.5705,  1.5010,
#            0.4801, -0.5064, -1.6631,  0.7991,  3.3436,  0.9685,  0.2027,
#            0.4749, -0.5149,  1.0987, -2.2158, -1.3794, -0.6082,  0.2563,
#            1.1131, -0.6004, -0.7500, -0.3463,  0.5589, -1.0145,  0.3855,
#           -2.1967]]])

# %%
add_new_logger("sample3")
example_idx = 18

src = vars(train_data.examples[example_idx])['src']
trg = vars(train_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')

currentLogger = StepLogger(100)  
translation, attention, all_outputs = translate_sentence(src, SRC, TRG, model, device,is_appy_attention=False)

print(f'predicted trg = {translation}')
 
display_attention(src, translation, attention,n_heads=get_head_count(),n_rows = get_row_count(), n_cols = get_col_count())
# Out:
# src = ['we', 'can', 'eat', 'bread']
# trg = ['wir', 'konnen', 'brot', 'essen']
# predicted trg = ['wir', 'konnen', 'essen', '<eos>']

# %%
for i in range( len(tabular_set)):
    print(" ".join(tabular_set[i].src))
# Out:
# i want to eat bread
# i want to eat apple
# i want to drink water
# i want to drink beer
# i want to read book
# i want to read newspaper
# i can eat bread
# i can eat apple
# i can drink water
# i can drink beer
# i can read book
# i can read newspaper
# we want to eat bread
# we want to eat apple
# we want to drink water
# we want to drink beer
# we want to read book
# we want to read newspaper
# we can eat bread
# we can eat apple
# we can drink water
# we can drink beer
# we can read book
# we can read newspaper
# i eat bread
# i eat apple
# i drink water
# i drink beer
# i read book
# i read newspaper
# we eat bread
# we eat apple
# we drink water
# we drink beer
# we read book
# we read newspaper

# %%
tabular_set[i].src
# Out:
# ['we', 'read', 'newspaper']

# %%
tt = torch.tensor(np.full((1, 2, 1, 6), 1/6) )

att1 = torch.tensor(np.full((tt.shape[0], tt.shape[1], tt.shape[2], 3), 1/3) )
att2 = torch.tensor(np.full((tt.shape[0], tt.shape[1], tt.shape[2], tt.shape[3] - 3), 1/7) )
att3 = torch.cat( (att1,att2),3 )
att4 = torch.softmax(att3, dim = -1)
att4
# Out:
# tensor([[[[0.1825, 0.1825, 0.1825, 0.1508, 0.1508, 0.1508]],
#
#          [[0.1825, 0.1825, 0.1825, 0.1508, 0.1508, 0.1508]]]],
#        dtype=torch.float64)
