# %%
# %matplotlib inline

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import pandas as pd
import seaborn as sns

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open('D:/data6/deu-eng/%s-%s.txt' % (lang1, lang2), encoding='utf-8').\
        read().strip().split('\n')
    print("len",len(lines))
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %%
MAX_LENGTH = 6




def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH and \
        p[0].startswith(eng_prefixes)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
dic_subjects ={ "i" : "ich", "we" : "wir"}
dic_aux  ={ "want to" : "mochten", "can" : "konnen"}
dic_verbs  ={ "eat" : "essen", "drink" : "trinken","read":"lesen"}
dic_object_en  ={ "eat" : ["bread","apple"], "drink" : ["water","beer"],"read":["book","newspaper"]}
dic_object_ge  ={ "essen" : ["brot","apfel"], "trinken" : ["wasser","bier"],"lesen":["buch","zeitung"]}

# %%
import itertools

iterables_en = [ dic_subjects.keys(), dic_verbs.keys(), ["placeholder"]]

raw_english_simple = []
for t in itertools.product(*iterables_en):
    print( t ,"--",t[2])
    raw_english_simple.append(t)
# Out:
# ('i', 'eat', 'placeholder') -- placeholder
# ('i', 'drink', 'placeholder') -- placeholder
# ('i', 'read', 'placeholder') -- placeholder
# ('we', 'eat', 'placeholder') -- placeholder
# ('we', 'drink', 'placeholder') -- placeholder
# ('we', 'read', 'placeholder') -- placeholder

# %%
import itertools

iterables_en = [ dic_subjects.keys(),  dic_aux.keys() ,dic_verbs.keys(), ["placeholder"]]

raw_english_aux = []
for t in itertools.product(*iterables_en):
    print( t ,"--",t[3])
    raw_english_aux.append(t)
# Out:
# ('i', 'want to', 'eat', 'placeholder') -- placeholder
# ('i', 'want to', 'drink', 'placeholder') -- placeholder
# ('i', 'want to', 'read', 'placeholder') -- placeholder
# ('i', 'can', 'eat', 'placeholder') -- placeholder
# ('i', 'can', 'drink', 'placeholder') -- placeholder
# ('i', 'can', 'read', 'placeholder') -- placeholder
# ('we', 'want to', 'eat', 'placeholder') -- placeholder
# ('we', 'want to', 'drink', 'placeholder') -- placeholder
# ('we', 'want to', 'read', 'placeholder') -- placeholder
# ('we', 'can', 'eat', 'placeholder') -- placeholder
# ('we', 'can', 'drink', 'placeholder') -- placeholder
# ('we', 'can', 'read', 'placeholder') -- placeholder

# %%
final_sentences = []
for raw in raw_english_aux:
    verb = raw[2]
    verb_objects = dic_object_en[verb]
    for index,verb_object_en in enumerate(verb_objects):
        eng_sentence = [raw[0],raw[1],raw[2],verb_object_en]
        german_verb = dic_verbs[verb]
        verb_object_ge = dic_object_ge[german_verb][index]
        #word order is different in german
        german_sentence = [dic_subjects[raw[0]],dic_aux[raw[1]],verb_object_ge,german_verb]
        final_sentences.append([eng_sentence,german_sentence])

for raw in raw_english_simple:
    verb = raw[1]
    verb_objects = dic_object_en[verb]
    for verb_object in verb_objects:        
        eng_sentence = [raw[0],raw[1],verb_object]
        german_verb = dic_verbs[verb]
        verb_object_ge = dic_object_ge[german_verb][index]
        german_sentence = [dic_subjects[raw[0]],german_verb,verb_object_ge]
        final_sentences.append([eng_sentence,german_sentence])
        
final_sentences_pairs = []
for sentence_pair in final_sentences:
    en_sentence,ge_sentence = sentence_pair[0],sentence_pair[1]
    final_sentences_pairs.append([ " ".join(en_sentence)," ".join(ge_sentence) ])
final_sentences_pairs
# Out:
# [['i want to eat bread', 'ich mochten brot essen'],
#  ['i want to eat apple', 'ich mochten apfel essen'],
#  ['i want to drink water', 'ich mochten wasser trinken'],
#  ['i want to drink beer', 'ich mochten bier trinken'],
#  ['i want to read book', 'ich mochten buch lesen'],
#  ['i want to read newspaper', 'ich mochten zeitung lesen'],
#  ['i can eat bread', 'ich konnen brot essen'],
#  ['i can eat apple', 'ich konnen apfel essen'],
#  ['i can drink water', 'ich konnen wasser trinken'],
#  ['i can drink beer', 'ich konnen bier trinken'],
#  ['i can read book', 'ich konnen buch lesen'],
#  ['i can read newspaper', 'ich konnen zeitung lesen'],
#  ['we want to eat bread', 'wir mochten brot essen'],
#  ['we want to eat apple', 'wir mochten apfel essen'],
#  ['we want to drink water', 'wir mochten wasser trinken'],
#  ['we want to drink beer', 'wir mochten bier trinken'],
#  ['we want to read book', 'wir mochten buch lesen'],
#  ['we want to read newspaper', 'wir mochten zeitung lesen'],
#  ['we can eat bread', 'wir konnen brot essen'],
#  ['we can eat apple', 'wir konnen apfel essen'],
#  ['we can drink water', 'wir konnen wasser trinken'],
#  ['we can drink beer', 'wir konnen bier trinken'],
#  ['we can read book', 'wir konnen buch lesen'],
#  ['we can read newspaper', 'wir konnen zeitung lesen'],
#  ['i eat bread', 'ich essen apfel'],
#  ['i eat apple', 'ich essen apfel'],
#  ['i drink water', 'ich trinken bier'],
#  ['i drink beer', 'ich trinken bier'],
#  ['i read book', 'ich lesen zeitung'],
#  ['i read newspaper', 'ich lesen zeitung'],
#  ['we eat bread', 'wir essen apfel'],
#  ['we eat apple', 'wir essen apfel'],
#  ['we drink water', 'wir trinken bier'],
#  ['we drink beer', 'wir trinken bier'],
#  ['we read book', 'wir lesen zeitung'],
#  ['we read newspaper', 'wir lesen zeitung']]

# %%
def readLangs(lang1, lang2,pair_sentences, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = pair_sentences
    print("len",len(lines))
    print("lines",lines[0])
    # Split every line into pairs and normalize
    pairs = [[normalizeString(l[0]),normalizeString(l[1])] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

def prepareData(lang1, lang2,pair_sentences, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2,pair_sentences, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = pairs
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs


input_lang, output_lang, pairs = prepareData('eng', 'deu',final_sentences_pairs, False)
print(random.choice(pairs))
# Out:
# Reading lines...
# len 36
# lines ['i want to eat bread', 'ich mochten brot essen']
# Read 36 sentence pairs
# Trimmed to 36 sentence pairs
# Counting words...
# Counted words:
# eng 16
# deu 15
# ['we drink beer', 'wir trinken bier']

# %%
pairs
# Out:
# [['i want to eat bread', 'ich mochten brot essen'],
#  ['i want to eat apple', 'ich mochten apfel essen'],
#  ['i want to drink water', 'ich mochten wasser trinken'],
#  ['i want to drink beer', 'ich mochten bier trinken'],
#  ['i want to read book', 'ich mochten buch lesen'],
#  ['i want to read newspaper', 'ich mochten zeitung lesen'],
#  ['i can eat bread', 'ich konnen brot essen'],
#  ['i can eat apple', 'ich konnen apfel essen'],
#  ['i can drink water', 'ich konnen wasser trinken'],
#  ['i can drink beer', 'ich konnen bier trinken'],
#  ['i can read book', 'ich konnen buch lesen'],
#  ['i can read newspaper', 'ich konnen zeitung lesen'],
#  ['we want to eat bread', 'wir mochten brot essen'],
#  ['we want to eat apple', 'wir mochten apfel essen'],
#  ['we want to drink water', 'wir mochten wasser trinken'],
#  ['we want to drink beer', 'wir mochten bier trinken'],
#  ['we want to read book', 'wir mochten buch lesen'],
#  ['we want to read newspaper', 'wir mochten zeitung lesen'],
#  ['we can eat bread', 'wir konnen brot essen'],
#  ['we can eat apple', 'wir konnen apfel essen'],
#  ['we can drink water', 'wir konnen wasser trinken'],
#  ['we can drink beer', 'wir konnen bier trinken'],
#  ['we can read book', 'wir konnen buch lesen'],
#  ['we can read newspaper', 'wir konnen zeitung lesen'],
#  ['i eat bread', 'ich essen apfel'],
#  ['i eat apple', 'ich essen apfel'],
#  ['i drink water', 'ich trinken bier'],
#  ['i drink beer', 'ich trinken bier'],
#  ['i read book', 'ich lesen zeitung'],
#  ['i read newspaper', 'ich lesen zeitung'],
#  ['we eat bread', 'wir essen apfel'],
#  ['we eat apple', 'wir essen apfel'],
#  ['we drink water', 'wir trinken bier'],
#  ['we drink beer', 'wir trinken bier'],
#  ['we read book', 'wir lesen zeitung'],
#  ['we read newspaper', 'wir lesen zeitung']]

# %%
print(random.choice(pairs))
# Out:
# ['we want to drink beer', 'wir mochten bier trinken']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
temp_map = {}
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    #input : decoder_input (input obtained at each step)    
    #hidden : decoder_hidden, value returned from this function is passed again
    #encoder_outputs : all outputs steps of encode,static in this function    
    def forward(self, input, hidden, encoder_outputs,is_appy_weight=True):
        temp_map["hidden_"] = hidden
        temp_map["input"] = input
        temp_map["encoder_outputs"] = encoder_outputs
        
        embedded = self.embedding(input).view(1, 1, -1)
        temp_map["embedded"] = embedded
        
        embedded = self.dropout(embedded)
        temp_map["embedded_dropout"] = embedded
        
        
        tensor_cat = torch.cat((embedded[0], hidden[0]), 1)
        temp_map["tensor_cat"] = tensor_cat
        
        attn_vector = self.attn(tensor_cat)
        temp_map["attn_vector"] = attn_vector
        
        attn_weights = F.softmax(attn_vector, dim=1)
        temp_map["attn_weights"] = attn_weights
        
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),encoder_outputs.unsqueeze(0))
        temp_map["attn_applied"] = attn_applied

        if is_appy_weight:
            output = torch.cat((embedded[0], attn_applied[0]), 1)
            temp_map["output"] = output
        else:
            last_encoder_output = encoder_outputs[len(encoder_outputs)-1].view(1,-1)
            print("embedded[0]",embedded[0].shape)
            print("encoder_outputs",last_encoder_output.shape)
            output = torch.cat((embedded[0], last_encoder_output), 1)
            temp_map["output"] = output
        
        output = self.attn_combine(output).unsqueeze(0)
        temp_map["output attn_combine"] = output

        output = F.relu(output)
        temp_map["output relu"] = output
        
        output_step, hidden_step = self.gru(output, hidden)
        temp_map["output_step"] = output_step
        temp_map["hidden_step"] = hidden_step

        output_softmax = F.log_softmax(self.out(output_step[0]), dim=1)
        temp_map["output_softmax"] = output_softmax
        
        return output_softmax, hidden_step, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if 3 < 2:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
import gc

def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    gc.collect()
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %%
evaluate_queue = []

def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH,is_appy_weight=True):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()
        
        #evaluate_queue.append(["input_tensor",input_tensor])
        #evaluate_queue.append(["encoder_hidden",encoder_hidden])

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        #evaluate_queue.append(["encoder_outputs",encoder_outputs])

        for ei in range(input_length):
            #evaluate_queue.append(["input_tensor[ei]",input_tensor[ei]])
            #evaluate_queue.append(["encoder_hidden",encoder_hidden])
            encoder_output, encoder_hidden = encoder(input_tensor[ei],encoder_hidden)
            #evaluate_queue.append(["encoder_output",encoder_output])
            #evaluate_queue.append(["encoder_hidden",encoder_hidden])
            
            encoder_outputs[ei] += encoder_output[0, 0]
            #evaluate_queue.append(["encoder_outputs[ei]",encoder_outputs[ei]])

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS
        evaluate_queue.append(["decoder_input",decoder_input])

        decoder_hidden = encoder_hidden
        evaluate_queue.append(["encoder_hidden_decoder_hidden",decoder_hidden])

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            #print("di:",di)
            #return output_softmax, hidden_step, attn_weights
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs,is_appy_weight)
            evaluate_queue.append(["decoder_output",decoder_output])
            evaluate_queue.append(["decoder_hidden",decoder_hidden])
            evaluate_queue.append(["decoder_attention",decoder_attention])                        
            
            decoder_attentions[di] = decoder_attention.data
            evaluate_queue.append(["decoder_attentions[di]",decoder_attentions[di]])
            
            topv, topi = decoder_output.data.topk(1)
            evaluate_queue.append(["topv",topv])
            evaluate_queue.append(["topi",topi])
            
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                evaluate_queue.append(["output_lang.index2word[topi.item()]",output_lang.index2word[topi.item()]])
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()
            evaluate_queue.append(["decoder_input",decoder_input])

        #print("returnin attention",decoder_attentions[:di + 1].shape)    
        evaluate_queue.append(["decoded_words",decoded_words])    
        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %%
hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)

#trainIters(encoder1, attn_decoder1, 1000, print_every=500)

# %%
print( encoder1)
# Out:
# EncoderRNN(
#   (embedding): Embedding(16, 256)
#   (gru): GRU(256, 256)
# )

# %%
print( attn_decoder1)
# Out:
# AttnDecoderRNN(
#   (embedding): Embedding(15, 256)
#   (attn): Linear(in_features=512, out_features=6, bias=True)
#   (attn_combine): Linear(in_features=512, out_features=256, bias=True)
#   (dropout): Dropout(p=0.1)
#   (gru): GRU(256, 256)
#   (out): Linear(in_features=256, out_features=15, bias=True)
# )

# %%
#1.3408
import os.path
decoder_path = "D:/data6/40iter_decoder"
encoder_path = "D:/data6/40iter_encoder"

for i in range(1):
    gc.collect()
    encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
    attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
    
    if os.path.isfile(decoder_path) :
        encoder1.load_state_dict(torch.load(encoder_path))
        attn_decoder1.load_state_dict(torch.load(decoder_path))
        
    trainIters(encoder1, attn_decoder1, 1000, print_every=500)
    torch.save(attn_decoder1.state_dict(), decoder_path)
    torch.save(encoder1.state_dict(), encoder_path)
# Out:
# 0m 10s (- 0m 10s) (500 50%) 0.0005
# 0m 20s (- 0m 0s) (1000 100%) 0.0005

# %%
#torch.save(attn_decoder1.state_dict(), "D:/data6/10iter_decoder")
#torch.save(encoder1.state_dict(), "D:/data6/10iter_encoder")
#model = TheModelClass(*args, **kwargs)
#model.load_state_dict(torch.load(PATH))
#model.eval() 3.2

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > i want to eat bread
# = ich mochten brot essen
# < ich mochten brot essen <EOS>
#
# > i want to eat bread
# = ich mochten brot essen
# < ich mochten brot essen <EOS>
#
# > i want to drink beer
# = ich mochten bier trinken
# < ich mochten bier trinken <EOS>
#
# > we can drink beer
# = wir konnen bier trinken
# < wir konnen bier trinken <EOS>
#
# > we can read newspaper
# = wir konnen zeitung lesen
# < wir konnen zeitung lesen <EOS>
#
# > i read book
# = ich lesen zeitung
# < ich lesen zeitung <EOS>
#
# > i drink beer
# = ich trinken bier
# < ich trinken bier <EOS>
#
# > i want to eat apple
# = ich mochten apfel essen
# < ich mochten apfel essen <EOS>
#
# > i want to drink beer
# = ich mochten bier trinken
# < ich mochten bier trinken <EOS>
#
# > i eat apple
# = ich essen apfel
# < ich essen apfel <EOS>

# %%
output_words, attentions = evaluate(
    encoder1, attn_decoder1, "we can drink beer")
plt.matshow(attentions.numpy())
display(plt.figure())
plt.figure().show()
# Out:
# C:\Users\mcelikkaya\Anaconda3\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()


def evaluateAndShowAttention(input_sentence,is_appy_weight=True,dump_display=True):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence,is_appy_weight=is_appy_weight)
    
    if dump_display:
        print("Apply weight :",is_appy_weight)
        print('input =', input_sentence)
        print('output =', ' '.join(output_words))
        showAttention(input_sentence, output_words, attentions)
    return attentions,output_words

def get_eval_value(evaluate_queue,key):
    key_items = []
    for queue_item in evaluate_queue:
        if queue_item[0] == key:
            key_items.append( queue_item[1] )
    return key_items    

def draw_attention_map(key_items,output_words):
    key_values = [ np.exp( valcel ) for krow in key_items for valcel in krow.data.numpy().flatten()]
    key_values = [ np.exp( krow.data.numpy().flatten() ) for krow in key_items ]

    output_words[len(output_words)-1] = "EOS"
    output_words = [ str(index+1)+")"+ word for index,word in enumerate(output_words)]
    df2 = pd.DataFrame(key_values,columns=[i for i in output_lang.index2word.values()],index=output_words)
    cm = sns.light_palette("blue", as_cmap=True)

    s = df2.style.background_gradient(cmap=cm)
    return s

# %%
all_valid_inputs = [p[0] for p in pairs]
all_encoder_states = []
for valid_input in all_valid_inputs:
    print("-------------------------------------------")
    evaluate_queue = []
    
    attentions,output_words = evaluateAndShowAttention(valid_input,is_appy_weight=True,dump_display=True)
    key_items = get_eval_value(evaluate_queue,"decoder_output")
    display(draw_attention_map(key_items,output_words))    
    
    key_items_encoder_stated = get_eval_value(evaluate_queue,"encoder_hidden_decoder_hidden")    
    all_encoder_states.append( key_items_encoder_stated[0].data.numpy().flatten() )
    
    evaluate_queue = []
    attentions,output_words = evaluateAndShowAttention(valid_input,is_appy_weight=False,dump_display=True)
    key_items = get_eval_value(evaluate_queue,"decoder_output")
    display(draw_attention_map(key_items,output_words))
    
    
valid_sentences_embeddings,valid_sentences = [],[]    
for index,valid_input in enumerate(all_valid_inputs):    
    valid_sentences.append(valid_input)
    valid_sentences_embeddings.append(all_encoder_states[index])
# Out:
# -------------------------------------------
# Apply weight : True
# input = i want to eat bread
# output = ich mochten brot essen <EOS>
# <style  type="text/css" >
#     #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col13 {
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col0 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col7 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col9 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col11 {
#             background-color:  #adadff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col13 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col0 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col6 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col8 {
#             background-color:  #acacff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col9 {
#             background-color:  #e2e2ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col12 {
#             background-color:  #dadaff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0167e842_34a9_11eb_9164_c49ded8dff66row3_col14 {
#             background-color:  #e4e4ff;
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# Apply weight : False
# input = i want to eat bread
# output = ich essen <EOS>
# <style  type="text/css" >
#     #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col3 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col4 {
#             background-color:  #4444ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col7 {
#             background-color:  #d4d4ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col10 {
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col13 {
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col0 {
#             background-color:  #bfbfff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col12 {
#             background-color:  #e1e1ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_019fde9c_34a9_11eb_89c0_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }</style><table id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOS</th>        <th class="col_heading level0 col1" >EOS</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >mochten</th>        <th class="col_heading level0 col4" >brot</th>        <th class="col_heading level0 col5" >essen</th>        <th class="col_heading level0 col6" >apfel</th>        <th class="col_heading level0 col7" >wasser</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >bier</th>        <th class="col_heading level0 col10" >buch</th>        <th class="col_heading level0 col11" >lesen</th>        <th class="col_heading level0 col12" >zeitung</th>        <th class="col_heading level0 col13" >konnen</th>        <th class="col_heading level0 col14" >wir</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)ich</th>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col0" class="data row0 col0" >0.000003</td>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col1" class="data row0 col1" >0.000000</td>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col2" class="data row0 col2" >0.950740</td>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col4" class="data row0 col4" >0.000022</td>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col5" class="data row0 col5" >0.000734</td>
#                         <td id="T_019fde9c_34a9_11eb_89c0_c49ded8dff66row0_col6" class="data row0 col6" >0.000020</td>
#                         <td
# -------------------------------------------
# Apply weight : True
# input = i want to eat apple
# output = ich mochten apfel essen <EOS>
# <style  type="text/css" >
#     #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col0 {
#             background-color:  #dedeff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col10 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col13 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col0 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col4 {
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col7 {
#             background-color:  #cacaff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col9 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col10 {
#             background-color:  #ddddff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col12 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row1_col14 {
#             background-color:  #e3e3ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col0 {
#             background-color:  #c5c5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col8 {
#             background-color:  #ababff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col11 {
#             background-color:  #5a5aff;
#             color:  #f1f1f1;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_01da9e0a_34a9_11eb_8988_c49ded8dff66row3_col14 {
#             background-color:  #e5e5ff;
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# Apply weight : False
# input = i want to eat apple
# output = ich essen <EOS>
# <style  type="text/css" >
#     #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col3 {
#             background-color:  #c9c9ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col13 {
#             background-color:  #cbcbff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col0 {
#             background-color:  #9e9eff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col4 {
#             background-color:  #8b8bff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col6 {
#             background-color:  #d9d9ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col7 {
#             background-color:  #9898ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col10 {
#             background-color:  #ddddff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col9 {
#             background-color:  #9292ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col12 {
#             background-color:  #9090ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_020c3d10_34a9_11eb_a55c_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }</style><table id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOS</th>        <th class="col_heading level0 col1" >EOS</th>        <th class="col_heading level0 col2" >ich</th>        <th class="col_heading level0 col3" >mochten</th>        <th class="col_heading level0 col4" >brot</th>        <th class="col_heading level0 col5" >essen</th>        <th class="col_heading level0 col6" >apfel</th>        <th class="col_heading level0 col7" >wasser</th>        <th class="col_heading level0 col8" >trinken</th>        <th class="col_heading level0 col9" >bier</th>        <th class="col_heading level0 col10" >buch</th>        <th class="col_heading level0 col11" >lesen</th>        <th class="col_heading level0 col12" >zeitung</th>        <th class="col_heading level0 col13" >konnen</th>        <th class="col_heading level0 col14" >wir</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66level0_row0" class="row_heading level0 row0" >1)ich</th>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col0" class="data row0 col0" >0.000007</td>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col1" class="data row0 col1" >0.000008</td>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col2" class="data row0 col2" >0.945860</td>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col3" class="data row0 col3" >0.000000</td>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col4" class="data row0 col4" >0.000002</td>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col5" class="data row0 col5" >0.002908</td>
#                         <td id="T_020c3d10_34a9_11eb_a55c_c49ded8dff66row0_col6" class="data row0 col6" >0.008281</td>
#                         <td
# -------------------------------------------
# Apply weight : True
# input = i want to drink water
# output = ich mochten wasser trinken <EOS>
# <style  type="text/css" >
#     #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col0 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col13 {
#             background-color:  #e1e1ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col0 {
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col4 {
#             background-color:  #dadaff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col11 {
#             background-color:  #e3e3ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col13 {
#             background-color:  #e2e2ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col0 {
#             background-color:  #cdcdff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col5 {
#             background-color:  #7f7fff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col11 {
#             background-color:  #1313ff;
#             color:  #f1f1f1;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0240d4d4_34a9_11eb_8ed3_c49ded8dff66row3_col14 {
#             background-color:  #e5e5ff;
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# Apply weight : False
# input = i want to drink water
# output = ich trinken <EOS>
# <style  type="text/css" >
#     #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col3 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col13 {
#             background-color:  #c4c4ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col7 {
#             background-color:  #5353ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col12 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col0 {
#             background-color:  #4a4aff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col4 {
#             background-color:  #5555ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col10 {
#             background-color:  #d7d7ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_026a0e12_34a9_11eb_a4bc_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
# ...
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col4 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col7 {
#             background-color:  #e3e3ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col10 {
#             background-color:  #d0d0ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col0 {
#             background-color:  #7575ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col4 {
#             background-color:  #7b7bff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col7 {
#             background-color:  #c2c2ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col9 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col8 {
#             background-color:  #d8d8ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col10 {
#             background-color:  #5c5cff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col8 {
#             background-color:  #e2e2ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b26ec74_34a9_11eb_a4c5_c49ded8dff66row3_col14 {
#             background-color:  #e5e5ff;
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# Apply weight : False
# input = we read newspaper
# output = wir mochten zeitung lesen <EOS>
# <style  type="text/css" >
#     #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col0 {
#             background-color:  #9b9bff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col2 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col5 {
#             background-color:  #8282ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col11 {
#             background-color:  #c8c8ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row1_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col0 {
#             background-color:  #9090ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col1 {
#             background-color:  #e4e4ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col8 {
#             background-color:  #bbbbff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_0b4c608a_34a9_11eb_8f8a_c49ded8dff66row3_col14 {
#             background-color:  #e5e5ff;

# %%
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
    
#all_encoder_states[0].shape
from yellowbrick.text import TSNEVisualizer
print(np.array(valid_sentences_embeddings).shape )
print(np.array(valid_sentences).shape )

Xs = valid_sentences_embeddings
Ys = valid_sentences
tsne = TSNEVisualizer(labels=all_valid_inputs,title="How output of encoder looks",random_state=42)

fitted = tsne.fit(np.array(Xs), Ys)
tsne.show()
# Out:
# (36, 256)
# (36,)

# %%
result = fitted.transformer_.fit_transform(np.array(valid_sentences_embeddings))

import matplotlib
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)

#scatter result words
plt.scatter(result[:, 0], result[:, 1])
words = list(valid_sentences)
#put an annotation on x,y cordinates for words
for i, word in enumerate(words):
    if "eat" in word:
        plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#0000ff')
    elif "drink" in word:
        plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#00ff00')    
    else:
        plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff0000')
plt.show()

# %%
def show_on_vis(new_input_embedding,input_sentence,valid_sentences_embeddings,valid_sentences):
    
    input_sentence = "["+input_sentence+"]"
    Xs = valid_sentences_embeddings + [new_input_embedding[0].data.numpy().flatten()]
    Ys = valid_sentences + [input_sentence ]
    result = fitted.transformer_.fit_transform(np.array(Xs))

    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 10.5)

    #scatter result words
    plt.scatter(result[:, 0], result[:, 1])
    words = list(Ys)
    #put an annotation on x,y cordinates for words
    for i, word in enumerate(words):
        if input_sentence == word:
            print("input_sentence",input_sentence)
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00ff')
        elif "eat" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#00ff00')    
        else:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff0000')
    plt.show()

# %%
evaluate_queue = []
#evaluateAndShowAttention("i can drink beer",False)
input_sentence = "i can drink beer"
attentions,output_words = evaluateAndShowAttention(input_sentence,is_appy_weight=False,dump_display=True)
key_items = get_eval_value(evaluate_queue,"decoder_output")
display(draw_attention_map(key_items,output_words)) 

key_items_encoder_stated = get_eval_value(evaluate_queue,"encoder_hidden_decoder_hidden")    

show_on_vis(key_items_encoder_stated,input_sentence,valid_sentences_embeddings,valid_sentences)
# Out:
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# embedded[0] torch.Size([1, 256])
# encoder_outputs torch.Size([1, 256])
# Apply weight : False
# input = i can drink beer
# output = ich mochten bier trinken <EOS>
# <style  type="text/css" >
#     #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row0_col14 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col0 {
#             background-color:  #c5c5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col8 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col11 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col13 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row1_col14 {
#             background-color:  #e0e0ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col5 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col6 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col7 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col8 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col9 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col10 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col11 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col12 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row2_col14 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col0 {
#             background-color:  #cdcdff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col1 {
#             background-color:  #dadaff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col4 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col5 {
#             background-color:  #c7c7ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col6 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col7 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col8 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col9 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col10 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col11 {
#             background-color:  #afafff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col13 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_5752f0fa_34a9_11eb_836c_c49ded8dff66row3_col14 {
#             background-color:  #e5e5ff;
# input_sentence [i can drink beer]

# %%
def highlight_last_max(data, colormax='antiquewhite', colormaxlast='lightgreen'):
    colormax_attr = f'background-color: {colormax}'
    colormaxlast_attr = f'background-color: {colormaxlast}'
    #print("yy",data)
    print("yy",type(data.nlargest(2)))
    
    max_value = data.max()
    is_max = [colormax_attr if v == max_value else '' for v in data]
    is_max[len(data) - list(reversed(data)).index(max_value) -  1] = colormaxlast_attr
    return is_max


def highlight_max(s):
    is_large = s.nlargest(2).values
    return ['background-color: yellow' if v in is_large else '' for v in s]

df = pd.DataFrame({"id":[1,22,3],"age":[10,20,39],"salary":[110,120,139]})

df2 = df.style.apply(highlight_max,axis=1)
#df3 = df2.apply(highlight_last_max,axis=1).render()
#df3

from IPython.display import display, HTML
display(HTML(df2.apply(highlight_last_max,axis=1).render()))
# Out:
# yy <class 'pandas.core.series.Series'>
# yy <class 'pandas.core.series.Series'>
# yy <class 'pandas.core.series.Series'>
# <style  type="text/css" >
#     #T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row0_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#         }    #T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row1_col0 {
#             background-color:  yellow;
#             : ;
#         }    #T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row1_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#         }    #T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row2_col2 {
#             background-color:  yellow;
#             background-color:  lightgreen;
#         }</style><table id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >id</th>        <th class="col_heading level0 col1" >age</th>        <th class="col_heading level0 col2" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row0_col2" class="data row0 col2" >110</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row1_col0" class="data row1 col0" >22</td>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row1_col1" class="data row1 col1" >20</td>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row1_col2" class="data row1 col2" >120</td>
#             </tr>
#             <tr>
#                         <th id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row2_col1" class="data row2 col1" >39</td>
#                         <td id="T_45b5f6c0_34af_11eb_8c86_c49ded8dff66row2_col2" class="data row2 col2" >139</td>
#             </tr>
#     </tbody></table>

# %%
evaluate_queue = []
evaluateAndShowAttention("i can drink beer")
key_items = get_eval_value(evaluate_queue,"decoder_output")
display(draw_attention_map(key_items))

evaluate_queue = []
evaluateAndShowAttention("i can drink beer",False)
#at 2nd sample 
#1st step since no attention, after "wir" "guess is "trinken"

key_items = get_eval_value(evaluate_queue,"decoder_output")
display(draw_attention_map(key_items))

# %%
evaluate_queue = []
evaluateAndShowAttention("we can drink beer")
key_items = get_eval_value(evaluate_queue,"decoder_output")
display(draw_attention_map(key_items))

evaluate_queue = []
evaluateAndShowAttention("we can drink beer",False)
#at 2nd sample 
#1st step since no attention, after "wir" "guess is "trinken"

key_items = get_eval_value(evaluate_queue,"decoder_output")
display(draw_attention_map(key_items))

# %%
#evaluate_queue
F.log_softmax(torch.tensor([-11.1]) )

# %%
key_values = [ np.exp( valcel ) for krow in key_items for valcel in krow.data.numpy().flatten()]
key_values = [ np.exp( krow.data.numpy().flatten() ) for krow in key_items ]

df2 = pd.DataFrame(key_values,columns=[i for i in output_lang.index2word.values()])

#df3 =df2.style.apply(highlight_max)
#df3


cm = sns.light_palette("blue", as_cmap=True)

s = df2.style.background_gradient(cmap=cm)
s

# %%
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[3, 3] = np.nan
df.iloc[0, 2] = np.nan

def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
evaluateAndShowAttention("i want to eat apple")

# %%
evaluateAndShowAttention("i want to read book")

# %%
evaluateAndShowAttention("i want to read apple")

# %%
import math

def myround(n):
    if n == 0:
        return 0
    sgn = -1 if n < 0 else 1
    scale = int(-math.floor(math.log10(abs(n))))
    if scale <= 0:
        scale = 1
    factor = 10**scale
    return sgn*math.floor(abs(n)*factor)/factor

def format_float(num):
    return np.format_float_positional(num, trim='-')

def format_floats(attentions):
    
    pretty_printed = []
    for attention_list in attentions:
        pretty_printed.append( [ myround(num) for num in attention_list] )
    
    return pretty_printed

# %%
attentions = evaluateAndShowAttention("i want to book read")
print("attentions",attentions.shape)
print(attentions)

format_floats(attentions.data.numpy())
attentions = evaluateAndShowAttention("i book book")

# %%
attentions = evaluateAndShowAttention("i apple apple")
format_floats(attentions.data.numpy())

# %%
attentions = evaluateAndShowAttention("i book apple")
print(format_floats(attentions.data.numpy()))
attentions = evaluateAndShowAttention("i apple book")
print(format_floats(attentions.data.numpy()))

# %%
evaluateAndShowAttention("we")

output_words, attentions = evaluate(encoder1, attn_decoder1, "we book")
print("attentions",attentions.shape)
attentions
