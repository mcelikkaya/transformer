# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchtext
from torchtext.datasets import Multi30k
from torchtext.data import Field, BucketIterator

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy
import numpy as np
import matplotlib

import random
import math
import time
import random
from yellowbrick.text import TSNEVisualizer
from sklearn.decomposition import PCA

#TODO try TSNE instead of PCA

# %%
class StepLogger():
    def __init__(self,capacity):
        self.tensor_datas = {}        
        self.capacity = capacity
        self.added_labels = []
        
    
    def add_info(self,tensor_data,tensor_label):
        if tensor_label not in self.added_labels:
            self.added_labels.append( tensor_label )
        
        if tensor_label in self.tensor_datas.keys():
            current_arr = self.tensor_datas.get(tensor_label)
            if len(current_arr) < self.capacity:
                current_arr = self.tensor_datas.get(tensor_label, [])
                current_arr.append(tensor_data)
        else:
            self.tensor_datas[tensor_label] = [tensor_data]
    
    def get_default_summary(self,show_data=False,summary_count=1):
        self.get_summary(self.added_labels,show_data,summary_count)
        
    def get_summary(self,labels,show_data=False,summary_count=1):
        print("summary_count",summary_count,"   self.capacity ",self.capacity)
        count = 0
        values = []
        for i in range(summary_count):
            #print(i," ------------------------------------------------")
            for l in labels:
                label_data = self.tensor_datas.get(l)[i]
                values.append(label_data)
                print(l)
                if torch.is_tensor(label_data):
                    print( list(label_data.size() ) )
                if not show_data and not torch.is_tensor(label_data):
                    print(label_data)
                if show_data:    
                    print(label_data)
        return values              
                    
loggers = {}                    
current_logger = StepLogger(100)   
def add_new_logger(logger_label):
    global current_logger
    if logger_label in loggers.keys() :
        print("using existing logger")
        current_logger = loggers[logger_label]
    else:    
        loggers[logger_label]  = StepLogger(20)
        current_logger = loggers[logger_label]
    

def add_infos(datas,labels,labels_prefix=""):
    #print( id(current_logger))
    for i in range(len(datas)):
        final_label = labels_prefix+"@"+labels[i]
        current_logger.add_info(datas[i],final_label.strip())
    
#add_info   tensor_data,tensor_label                  currentLogger.get_default_summary(show_data=False)

data_pipeline = []
pipeline_enabled = True
def disable_pipeline():
    global pipeline_enabled
    pipeline_enabled = False

def enable_pipeline():
    global pipeline_enabled
    pipeline_enabled = True
    
def add_pipeline_info(label,data):
    if pipeline_enabled:
        data_pipeline.append( (label,data) )

# %%
a = 2
def seta():
    global a
    a = 3
print(a)
seta()
print(a)
# Out:
# 2
# 3

# %%
#!pip install torchtext
#!pip install spacy

# %%
SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
#spacy_en = spacy.load('en')
spacy_en = spacy.load("en_core_web_sm")

# %%
#tok = spacy.load("en_core_web_sm")
#tokde = spacy.load("de_core_news_sm")
import de_core_news_sm
spacy_de = de_core_news_sm.load()

# %%
spacy_de.tokenizer("i mochte lesen")
# Out:
# i mochte lesen

# %%
#!python -m spacy download de

# %%
#spacy_de = spacy.load('de')

# %%
def tokenize_de(text):
    """
    Tokenizes German text from a string into a list of strings
    """
    return [tok.text for tok in spacy_de.tokenizer(text)]

def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]

# %%
SRC = Field(tokenize = tokenize_de, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

TRG = Field(tokenize = tokenize_en, 
            init_token = '<sos>', 
            eos_token = '<eos>', 
            lower = True, 
            batch_first = True)

# %%
tabular_set = torchtext.data.TabularDataset(
path='D:/data8/eng_de3.csv', format='csv',
fields=[('src', SRC),
        ('trg', TRG)])

# %%
#dump a sample
print(tabular_set[0].src)
print(tabular_set[0].trg)
# Out:
# ['i', 'want', 'to', 'eat', 'bread']
# ['ich', 'mochten', 'brot', 'essen']

# %%
#TODO can generate different items for each
#Real line in tutorial
#train_data, valid_data, test_data = Multi30k.splits(exts = ('.de', '.en'), fields = (SRC, TRG))
train_data, valid_data, test_data = tabular_set ,tabular_set, tabular_set

# %%
#all of our vocublary is used at least 2 times
SRC.build_vocab(train_data, min_freq = 2)
TRG.build_vocab(train_data, min_freq = 2)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
#our tranining size is so small so batch size will also be small
BATCH_SIZE = 8

# %%
train_iterator, valid_iterator, test_iterator = BucketIterator.splits(
    (train_data, valid_data, test_data), 
     batch_size = BATCH_SIZE,
     sort_key = lambda x:  len(x.src),
     device = device)

# %%
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim,
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()

        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim,
                                                  dropout, 
                                                  device) 
                                     for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, src, src_mask,is_appy_attention):
    
        add_infos([src],["src_source"],"Encoder")
        add_pipeline_info(label="Encoder->attention",data=src)
        #src = [batch size, src len]
        #src_mask = [batch size, src len]
        #print("Encoder src",src)
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        
        #pos = [batch size, src len]
        add_infos([src,pos],["src","pos"],"Encoder")   
        src = self.dropout((self.tok_embedding(src) * self.scale) + self.pos_embedding(pos))
        
        #src = [batch size, src len, hid dim]
        
        for layer in self.layers:
            src = layer(src, src_mask,is_appy_attention)
            
        
        add_infos([src],["src_final"],"Encoder")    
        #src = [batch size, src len, hid dim]
            
        return src

# %%
class EncoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim,  
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"encoder")
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask,is_appy_attention):
        
        #src = [batch size, src len, hid dim]
        #src_mask = [batch size, src len]
                
           
        #self attention
        _src, sattention = self.self_attention(src, src, src,is_appy_attention, src_mask) #return x, attention
        
        #dropout, residual connection and layer norm
        src2 = self.self_attn_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        #positionwise feedforward
        _src2 = self.positionwise_feedforward(src2)
        
        #dropout, residual and layer norm
        src3 = self.ff_layer_norm(src + self.dropout(_src2))
        
        add_infos([_src,src2,_src2,src3,src_mask,sattention],["_src","src2","_src2","src3","src_mask","sattention"],"EncoderLayer")
        #src = [batch size, src len, hid dim]
        
        return src3

# %%
class MultiHeadAttentionLayer(nn.Module):
    #since this layer is common while logging there must be a label to differantiate labels
    def __init__(self, hid_dim, n_heads, dropout, device,layer_label):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        #TODO head_dim is encoding per head so ,hid_dim must divide n_heads
        self.head_dim = hid_dim // n_heads
        self.layer_label = layer_label
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        add_infos([self.hid_dim,self.n_heads,self.head_dim],["hid_dim","n_heads","head_dim"],self.layer_label)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value,is_appy_attention, mask = None):
        
        batch_size = query.shape[0]
        
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        
        add_pipeline_info(label=self.layer_label+"@QKV",data=[Q,K,V])   
        add_infos([Q,K,V],["Q","K","V"],self.layer_label)
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
        
        ### attention is a weight over dimensions
        if not is_appy_attention:
            #print("old attention",attention.shape)
            #print("old attention",attention)
        
            #normally distributed literally means no attention
            #attention = torch.tensor(np.full(attention.shape, 1/attention.shape[3]),dtype=torch.float32 )
            #just pay attention to beginning
            #at last dimension shape is flat 1, 2, 1, 1
            if attention.shape[3] > 2: 
                real_shape = attention.shape
                att1 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], 3), 1/3) ,dtype=torch.float32 )
                att2 = torch.tensor(np.full((real_shape[0], real_shape[1], real_shape[2], real_shape[3] - 3), 1/7) ,dtype=torch.float32 )
                att3 = torch.cat( (att1,att2),3 )
                attention = torch.softmax(att3, dim = -1)
            
            
            #print("new attention",attention)
                
        #attention = [batch size, n heads, query len, key len]
                
        x1 = torch.matmul(self.dropout(attention), V)
        
        #x = [batch size, n heads, query len, head dim]
        
        x2 = x1.permute(0, 2, 1, 3).contiguous()
        
        #x = [batch size, query len, n heads, head dim]
        
        x3 = x2.view(batch_size, -1, self.hid_dim)
        
        #x = [batch size, query len, hid dim]
        
        x4 = self.fc_o(x3)
        
        #x = [batch size, query len, hid dim]
        
        add_infos([energy,mask,attention],["energy","mask","attention"],self.layer_label)
        add_infos([x1,x2,x3,x4],["x1","x2","x3","x4"],self.layer_label)
        
        return x4, attention

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x1 = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x2 = self.fc_2(x1)
        
        #x = [batch size, seq len, hid dim]
        add_infos([x1,x2],["x1","x2"],"PositionwiseFeedforwardLayer")
        
        return x2

# %%
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask,is_appy_attention=False):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, trg len]
        #src_mask = [batch size, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                            
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
                
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask,is_appy_attention)
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        
        add_infos([pos,trg,output,attention],["pos","trg","output","attention"],"Decoder")
        #output = [batch size, trg len, output dim]
            
        return output, attention

# %%
class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"decoder_self")
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device,"decoder_encoder_attention")
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask,is_appy_attention):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, trg len]
        #src_mask = [batch size, src len]
        
        #self attention
        _trg1, _ = self.self_attention(trg, trg, trg,is_appy_attention, trg_mask)
        
        #dropout, residual connection and layer norm
        trg2 = self.self_attn_layer_norm(trg + self.dropout(_trg1))
            
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        _trg2, attention = self.encoder_attention(trg2, enc_src, enc_src,is_appy_attention, src_mask)
        
        #dropout, residual connection and layer norm
        trg3 = self.enc_attn_layer_norm(trg2 + self.dropout(_trg2))
                    
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg3 = self.positionwise_feedforward(trg3)
        
        #dropout, residual and layer norm
        trg4 = self.ff_layer_norm(trg3 + self.dropout(_trg3))
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        add_infos([_trg1,trg2,_trg2,trg3,_trg3,trg4,attention],["_trg1","trg2","_trg2","trg3","_trg3","trg4","attention"],"DecoderLayer")
        
        return trg4, attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, 
                 encoder, 
                 decoder, 
                 src_pad_idx, 
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device
        
    def make_src_mask(self, src):
        
        #src = [batch size, src len]
        
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)

        #src_mask = [batch size, 1, 1, src len]

        return src_mask
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = self.device)).bool()
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        return trg_mask

    def forward(self, src, trg,is_appy_attention):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len]
                
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]
        #print("Seq2Seq src",src)
        enc_src = self.encoder(src, src_mask,is_appy_attention)
        
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask,is_appy_attention)
        
        add_infos([src_mask,trg_mask,enc_src,output,attention],["src_mask","trg_mask","enc_src","output","attention"],"Seq2Seq")
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return output, attention

# %%
INPUT_DIM = len(SRC.vocab)
OUTPUT_DIM = len(TRG.vocab)
HID_DIM = 64
ENC_LAYERS = 1
DEC_LAYERS = 1
ENC_HEADS = 2
DEC_HEADS = 2
ENC_PF_DIM = 128
DEC_PF_DIM = 128
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1

enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)

# %%
SRC_PAD_IDX = SRC.vocab.stoi[SRC.pad_token]
TRG_PAD_IDX = TRG.vocab.stoi[TRG.pad_token]

model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

# %%
print("SRC_PAD_IDX",SRC_PAD_IDX)
print("TRG_PAD_IDX",TRG_PAD_IDX)
print(SRC.vocab.itos[10])
print(SRC.vocab.stoi[SRC.vocab.itos[10]])
# Out:
# SRC_PAD_IDX 1
# TRG_PAD_IDX 1
# to
# 10

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 99,857 trainable parameters

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

# %%
model.apply(initialize_weights)
# Out:
# Seq2Seq(
#   (encoder): Encoder(
#     (tok_embedding): Embedding(18, 64)
#     (pos_embedding): Embedding(100, 64)
#     (layers): ModuleList(
#       (0): EncoderLayer(
#         (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=64, out_features=128, bias=True)
#           (fc_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): Decoder(
#     (tok_embedding): Embedding(17, 64)
#     (pos_embedding): Embedding(100, 64)
#     (layers): ModuleList(
#       (0): DecoderLayer(
#         (self_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (enc_attn_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (ff_layer_norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#         (self_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (encoder_attention): MultiHeadAttentionLayer(
#           (fc_q): Linear(in_features=64, out_features=64, bias=True)
#           (fc_k): Linear(in_features=64, out_features=64, bias=True)
#           (fc_v): Linear(in_features=64, out_features=64, bias=True)
#           (fc_o): Linear(in_features=64, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (positionwise_feedforward): PositionwiseFeedforwardLayer(
#           (fc_1): Linear(in_features=64, out_features=128, bias=True)
#           (fc_2): Linear(in_features=128, out_features=64, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (fc_out): Linear(in_features=64, out_features=17, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
# )

# %%
LEARNING_RATE = 0.0005

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

# %%
criterion = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)

# %%
def train(model, iterator, optimizer, criterion, clip,is_appy_attention):
    
    model.train()
    
    epoch_loss = 0
    
    print("train1")
    
    for i, batch in enumerate(iterator):
        #print("train2",i,batch)
        
        
        src = batch.src
        trg = batch.trg
        
        #print("train src",src)
        
        optimizer.zero_grad()
        
        output, _ = model(src, trg[:,:-1],is_appy_attention)
        
        
                
        #output = [batch size, trg len - 1, output dim]
        #trg = [batch size, trg len]
            
        output_dim = output.shape[-1]
        
        
            
        output = output.contiguous().view(-1, output_dim)
        trg = trg[:,1:].contiguous().view(-1)
                
        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
            
        loss = criterion(output, trg)
        
        loss.backward()
        
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        
        epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def evaluate(model, iterator, criterion,is_appy_attention):
    
    model.eval()
    
    epoch_loss = 0
    
    with torch.no_grad():
    
        for i, batch in enumerate(iterator):

            src = batch.src
            trg = batch.trg

            output, _ = model(src, trg[:,:-1],is_appy_attention)
            
            #output = [batch size, trg len - 1, output dim]
            #trg = [batch size, trg len]
            
            output_dim = output.shape[-1]
            
            output = output.contiguous().view(-1, output_dim)
            trg = trg[:,1:].contiguous().view(-1)
            
            #output = [batch size * trg len - 1, output dim]
            #trg = [batch size * trg len - 1]
            
            loss = criterion(output, trg)

            epoch_loss += loss.item()
        
    return epoch_loss / len(iterator)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import os
import gc
N_EPOCHS = 20
CLIP = 1
best_valid_loss = float('inf')

add_new_logger("training")


model_save_path = "D:/data8/tut6-model_en_de.pt"
model_to_train = model
for epoch in range(N_EPOCHS):
    gc.collect()
    if os.path.isfile(model_save_path) :
        print("loading model",model_save_path)
        #TODO
        #model_to_train.load_state_dict(torch.load(model_save_path))
    
    start_time = time.time()
    
    enable_pipeline()
    train_loss = train(model, train_iterator, optimizer, criterion, CLIP,is_appy_attention=True)
    
    disable_pipeline()
    valid_loss = evaluate(model, valid_iterator, criterion,is_appy_attention=True)    
    
    end_time = time.time()
    
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    
    if valid_loss < best_valid_loss:
        print("saving model",model_save_path," with loss ",valid_loss)
        best_valid_loss = valid_loss
        torch.save(model_to_train.state_dict(), model_save_path)
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
# Out:
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  2.7262842655181885
# Epoch: 01 | Time: 0m 0s
# 	Train Loss: 3.354 | Train PPL:  28.631
# 	 Val. Loss: 2.726 |  Val. PPL:  15.276
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  2.2391144275665282
# Epoch: 02 | Time: 0m 0s
# 	Train Loss: 2.727 | Train PPL:  15.286
# 	 Val. Loss: 2.239 |  Val. PPL:   9.385
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.9826491832733155
# Epoch: 03 | Time: 0m 0s
# 	Train Loss: 2.389 | Train PPL:  10.902
# 	 Val. Loss: 1.983 |  Val. PPL:   7.262
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.7823195934295655
# Epoch: 04 | Time: 0m 0s
# 	Train Loss: 2.199 | Train PPL:   9.015
# 	 Val. Loss: 1.782 |  Val. PPL:   5.944
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.5933279275894165
# Epoch: 05 | Time: 0m 0s
# 	Train Loss: 1.895 | Train PPL:   6.650
# 	 Val. Loss: 1.593 |  Val. PPL:   4.920
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.3901340007781982
# Epoch: 06 | Time: 0m 0s
# 	Train Loss: 1.790 | Train PPL:   5.987
# 	 Val. Loss: 1.390 |  Val. PPL:   4.015
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.1984021425247193
# Epoch: 07 | Time: 0m 0s
# 	Train Loss: 1.610 | Train PPL:   5.003
# 	 Val. Loss: 1.198 |  Val. PPL:   3.315
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  1.0253158688545227
# Epoch: 08 | Time: 0m 0s
# 	Train Loss: 1.402 | Train PPL:   4.064
# 	 Val. Loss: 1.025 |  Val. PPL:   2.788
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.872138237953186
# Epoch: 09 | Time: 0m 0s
# 	Train Loss: 1.282 | Train PPL:   3.605
# 	 Val. Loss: 0.872 |  Val. PPL:   2.392
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.7460641860961914
# Epoch: 10 | Time: 0m 0s
# 	Train Loss: 1.080 | Train PPL:   2.946
# 	 Val. Loss: 0.746 |  Val. PPL:   2.109
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.6458744704723358
# Epoch: 11 | Time: 0m 0s
# 	Train Loss: 1.038 | Train PPL:   2.823
# 	 Val. Loss: 0.646 |  Val. PPL:   1.908
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.5616242825984955
# Epoch: 12 | Time: 0m 0s
# 	Train Loss: 0.859 | Train PPL:   2.361
# 	 Val. Loss: 0.562 |  Val. PPL:   1.754
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.4996889352798462
# Epoch: 13 | Time: 0m 0s
# 	Train Loss: 0.840 | Train PPL:   2.316
# 	 Val. Loss: 0.500 |  Val. PPL:   1.648
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.43392428755760193
# Epoch: 14 | Time: 0m 0s
# 	Train Loss: 0.686 | Train PPL:   1.985
# 	 Val. Loss: 0.434 |  Val. PPL:   1.543
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.372295743227005
# Epoch: 15 | Time: 0m 0s
# 	Train Loss: 0.688 | Train PPL:   1.989
# 	 Val. Loss: 0.372 |  Val. PPL:   1.451
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.3157933682203293
# Epoch: 16 | Time: 0m 0s
# 	Train Loss: 0.587 | Train PPL:   1.799
# 	 Val. Loss: 0.316 |  Val. PPL:   1.371
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.27247534692287445
# Epoch: 17 | Time: 0m 0s
# 	Train Loss: 0.602 | Train PPL:   1.826
# 	 Val. Loss: 0.272 |  Val. PPL:   1.313
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.23857665359973906
# Epoch: 18 | Time: 0m 0s
# 	Train Loss: 0.471 | Train PPL:   1.601
# 	 Val. Loss: 0.239 |  Val. PPL:   1.269
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.20981165170669555
# Epoch: 19 | Time: 0m 0s
# 	Train Loss: 0.445 | Train PPL:   1.561
# 	 Val. Loss: 0.210 |  Val. PPL:   1.233
# loading model D:/data8/tut6-model_en_de.pt
# train1
# saving model D:/data8/tut6-model_en_de.pt  with loss  0.18330961167812349
# Epoch: 20 | Time: 0m 0s
# 	Train Loss: 0.384 | Train PPL:   1.467
# 	 Val. Loss: 0.183 |  Val. PPL:   1.201

# %%
cnt = 0
#count is 300 20 iterations so 15 per iteration
#36 items, 8 batchsize = 5 batch
#15 / 5 = 3
#3 is number of AttentionLayer stack
Qs = []
Ks = []
Vs = []
Ss = [] #sentences
for i in range(len(data_pipeline)):
    #print( data_pipeline[i][0] )
    current_label = data_pipeline[i][0]
    if "encoder@QKV" == current_label:
         cnt += 1
         Qs.append(data_pipeline[i][1][0])
         Ks.append(data_pipeline[i][1][1])
         Vs.append(data_pipeline[i][1][2])
    if "Encoder->attention" == current_label:
         
         Ss.append(data_pipeline[i][1])

# %%
print(Qs[0].shape)
print(Ss[0].shape)
print(Qs[0][:,0,:,:].shape)
# Out:
# torch.Size([8, 2, 7, 32])
# torch.Size([8, 7])
# torch.Size([8, 7, 32])

# %%
attention_table = []
for index,subbatch in enumerate(Ss):
    for sub_index ,words in enumerate(subbatch) :
        for word_index, word in enumerate(words):
            #print("index sub_index word_index",index ,sub_index ,word_index)
            #print("qval = Qs[index]",Qs[index][sub_index].shape)
            qval = Qs[index][:,0,:,:][sub_index][word_index]
            kval = Qs[index][:,0,:,:][sub_index][word_index]
            vval = Qs[index][:,0,:,:][sub_index][word_index]
            #qval = Qs[index][sub_index][word_index]
            #print(word.numpy() ,"->",qval.shape)
            attention_table.append( ( word.numpy() ,qval.detach().numpy(),kval.detach().numpy(),vval.detach().numpy() ) )

# %%
SRC.vocab.stoi
# Out:
# defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x0000023D9833C448>>,
#             {'<unk>': 0,
#              '<pad>': 1,
#              '<sos>': 2,
#              '<eos>': 3,
#              'i': 4,
#              'we': 5,
#              'can': 6,
#              'drink': 7,
#              'eat': 8,
#              'read': 9,
#              'to': 10,
#              'want': 11,
#              'apple': 12,
#              'beer': 13,
#              'book': 14,
#              'bread': 15,
#              'newspaper': 16,
#              'water': 17})

# %%
#lesen,trinken
filter_values = [SRC.vocab.stoi["drink"],SRC.vocab.stoi["eat"],SRC.vocab.stoi["read"],SRC.vocab.stoi["apple"]
                ,SRC.vocab.stoi["beer"],SRC.vocab.stoi["book"],SRC.vocab.stoi["bread"],SRC.vocab.stoi["water"]
                ,SRC.vocab.stoi["newspaper"],SRC.vocab.stoi["can"],SRC.vocab.stoi["must"]]
filtered_attention_map = {}
cnt = 1
for row in attention_table:    
    if row[0] in filter_values:
        label = SRC.vocab.itos[row[0]]
        if label in filtered_attention_map.keys():
            filtered_attention_map[label].append(row)
        else:
            filtered_attention_map[label] = [row]        
len(filtered_attention_map)
# Out:
# 10

# %%
Xs = []
Ys = []
for key in filtered_attention_map.keys():
    print(key)
    key_rows = filtered_attention_map[key]
    sample_attention_values = [ row  for index,row in enumerate(key_rows) if (index+1) % 20 == 0]
    Xs.extend( sample_attention_values )
    Ys.extend( [ key+"@"+str(index) for index in range(len(sample_attention_values))])
# Out:
# can
# eat
# apple
# drink
# beer
# water
# read
# book
# newspaper
# bread

# %%
XQs = [row[1] for row in Xs ]
YQs = [row for row in Ys ]

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(np.array(XQs))

map_on_2d(result,YQs)

# %%
add_new_logger("test_loss")

# %%
test_loss = evaluate(model, test_iterator, criterion,is_appy_attention=True)

print(f'| Test Loss: {test_loss:.3f} | Test PPL: {math.exp(test_loss):7.3f} |')

# %%
def translate_sentence(sentence, src_field, trg_field, model, device,is_appy_attention, max_len = 50):
    
    model.eval()
        
    if isinstance(sentence, str):
        nlp = spacy.load('de')
        tokens = [token.text.lower() for token in nlp(sentence)]
    else:
        tokens = [token.lower() for token in sentence]

    tokens = [src_field.init_token] + tokens + [src_field.eos_token]
        
    src_indexes = [src_field.vocab.stoi[token] for token in tokens]

    src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
    
    src_mask = model.make_src_mask(src_tensor)
    
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask,is_appy_attention)

    trg_indexes = [trg_field.vocab.stoi[trg_field.init_token]]

    ### hold output of linear layer at everytime step
    all_outputs = []
    for i in range(max_len):

        trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)

        trg_mask = model.make_trg_mask(trg_tensor)
        
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask,is_appy_attention)
        
        # #print("trg_mask",trg_mask)
        #print("src_mask",src_mask)
        #print("output.argmax(2)->",output.argmax(2))
        #print("output->",output.shape)
        #print("attention->",attention.shape)
        all_outputs.append(output[:, -1:, :].numpy().flatten())
        pred_token = output.argmax(2)[:,-1].item()
        
        trg_indexes.append(pred_token)

        if pred_token == trg_field.vocab.stoi[trg_field.eos_token]:
            break
    
    
    trg_tokens = [trg_field.vocab.itos[i] for i in trg_indexes]
    
    return trg_tokens[1:], attention,all_outputs

# %%
def display_attention(sentence, translation, attention, n_heads = 8, n_rows = 4, n_cols = 2):
    
    assert n_rows * n_cols == n_heads
    
    fig = plt.figure(figsize=(15,25))
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                           rotation=45)
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()

# %%
current_logger.get_default_summary(show_data=False)

# %%
TRG.vocab.itos
# Out:
# ['<unk>',
#  '<pad>',
#  '<sos>',
#  '<eos>',
#  'ich',
#  'wir',
#  'essen',
#  'konnen',
#  'lesen',
#  'mochten',
#  'trinken',
#  'apfel',
#  'bier',
#  'zeitung',
#  'brot',
#  'buch',
#  'wasser']

# %%
["unk","pad","sos","eos"]+TRG.vocab.itos[4:]

# %%
import pandas as pd
import seaborn as sns

def test_sentence(src,draw_charts,is_appy_attention=True):
    
    if isinstance(src,str):
        src = src.split(" ")
    logger_name = "".join(src)+str( random.randint(1,180001) )
    add_new_logger(logger_name)
    print(f'src = {src}')

    translation, attention,all_outputs = translate_sentence(src, SRC, TRG, model, device,is_appy_attention=is_appy_attention)

    print(f'predicted trg = {translation}')
    output_words = translation
    output_words[len(output_words)-1] = "EOS"
    output_words = [ str(index+1)+")"+ word for index,word in enumerate(output_words)]
    df2 = pd.DataFrame(all_outputs,columns=["unk","pad","sos","eos"]+TRG.vocab.itos[4:],index=output_words)
    cm = sns.light_palette("blue", as_cmap=True)

    styled_df = df2.style.background_gradient(cmap=cm)
    if draw_charts:
        display(styled_df)    
        display_attention(src, translation, attention,n_heads=2,n_rows = 1, n_cols = 2)
    return loggers[logger_name],all_outputs




def show_on_vis_multi(new_input_embeddings,input_sentences,valid_sentences_embeddings,valid_sentences):
    #print("new_input_embedding",new_input_embedding)
    Xs = valid_sentences_embeddings
    Ys = valid_sentences
   
    if len(input_sentences)> 0 :
        input_sentences = [ "<<<"+s+">>>" for s in input_sentences]
        Xs = Xs+ [embed for embed in new_input_embeddings]
        Ys = Ys + input_sentences 
        
    #tsne = TSNEVisualizer(labels=Ys,title="How output of encoder looks",random_state=42)
    #result = tsne.fit_transform(np.array(Xs),Ys)
    #tsne = TSNEVisualizer()
    #result =tsne.fit_transform(np.array(Xs),Ys)
    
    pca = PCA(n_components=2)
    result = pca.fit_transform(np.array(Xs))

    #result = fitted.transformer_.fit_transform(np.array(Xs))
    #print("input_sentences",input_sentences)

    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 10.5)

    #scatter result words
    plt.scatter(result[:, 0], result[:, 1])
    words = list(Ys)
    #put an annotation on x,y cordinates for words
    #print("input_sentences",input_sentences)
    for i, word in enumerate(words):
        #print("wordi",word,i,type(word))
        if word in input_sentences:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00ff')
        elif "eat" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff0000')     
        else:
            #print("else",word)
            plt.annotate(word, xy=(result[i, 0], result[i, 1]),color='#ff00dd')
    plt.show()    
    
def map_on_2d(data_2d,words,exceptional_words=[]):
    fig = matplotlib.pyplot.gcf()
    fig.set_size_inches(18.5, 10.5)

    #scatter result words
    plt.scatter(data_2d[:, 0], data_2d[:, 1])
    
    #put an annotation on x,y cordinates for words
    #print("input_sentences",input_sentences)
    for i, word in enumerate(words):
        #print("wordi",word,i,type(word))
        if word in exceptional_words:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00ff')
        elif "eat" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#0000ff')
        elif "drink" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#00ff00')
        elif "read" in word:
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff0000')     
        else:
            #print("else",word)
            #plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00dd')
            plt.annotate(word, xy=(data_2d[i, 0], data_2d[i, 1]),color='#ff00dd')
    plt.show()

# %%
valid_sentences = []
for i in range(len(tabular_set)):
    valid_sentences.append(" ".join( tabular_set[i].src) )
    
valid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs = test_sentence(tabular_set[i].src)
    #train_data.examples[example_idx].src
    #test_logger.get_default_summary()
    trg4 = test_logger.get_summary(labels=["DecoderLayer@trg4"],show_data=True)
    valid_sentences_embeddings.append(trg4[0].numpy().flatten())

# %%
invalid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs = test_sentence(tabular_set[i].src,draw_charts=False,is_appy_attention=False)
    #train_data.examples[example_idx].src
    #test_logger.get_default_summary()
    trg4 = test_logger.get_summary(labels=["DecoderLayer@trg4"],show_data=False)

    invalid_sentences_embeddings.append(trg4[0].numpy().flatten())

# %%
invalid_sentences_embeddings[0].shape

# %%
test_sentence("i can eat bread",is_appy_attention=False)

# %%
Xs = []
Ys = []
for index,sentence in enumerate(valid_sentences):
    logger,all_outputs = test_sentence(sentence,draw_charts=False,is_appy_attention=True)
    labels = logger.get_summary(labels=["Encoder@src_source"],show_data=False)
    datas = logger.get_summary(labels=["Encoder@src_final"],show_data=False)
    words = encoding_to_sentence(labels[0].numpy().flatten(),SRC)
    for index_word,data in enumerate(datas[0].squeeze() ):
        print(data.shape)
        if words[index_word] != "<eos>" and words[index_word] != "<sos>":
            Xs.append( data.numpy() )
            Ys.append( str(index)+"@"+words[index_word] )

# %%
pca = PCA(n_components=2)
result = pca.fit_transform(np.array(Xs))

map_on_2d(result,Ys)

# %%
def encoding_to_sentence(encodings,language):
    return [language.vocab.itos[i] for i in encodings ]

# %%
labels = logger.get_summary(labels=["Encoder@src_source"],show_data=False)
datas = logger.get_summary(labels=["Encoder@src_final"],show_data=False)
words = encoding_to_sentence(labels[0].numpy().flatten(),SRC)
#TRG.vocab.itos
#[SRC.vocab.itos[i] for i in datas[0].numpy().flatten() ]
Xs = []

for data in datas[0].squeeze():
    print(data.shape)
    Xs.append( data.numpy() )

pca = PCA(n_components=2)
result = pca.fit_transform(np.array(Xs))

map_on_2d(result,words)

# %%
logger.get_summary(labels=["Encoder@src_final"],show_data=False)

# %%
show_on_vis_multi(invalid_sentences_embeddings,valid_sentences,valid_sentences_embeddings,valid_sentences)

# %%
show_on_vis_multi([],[],valid_sentences_embeddings,valid_sentences)

# %%
logger,all_outputs,styled_df = test_sentence("we drink water",is_appy_attention=False)

# %%
test_logger,all_outputs = test_sentence(tabular_set[0].src,draw_charts=False,is_appy_attention=True)
print(tabular_set[0])
trg4 = test_logger.get_summary(labels=["EncoderLayer@src3"],show_data=False)
trg4[0].shape

# %%
valid_sentences_embeddings = []
for i in range(len(tabular_set)):
    test_logger,all_outputs = test_sentence(tabular_set[i].src,draw_charts=False,is_appy_attention=True)
    #train_data.examples[example_idx].src
    #test_logger.get_default_summary()
    trg4 = test_logger.get_summary(labels=["EncoderLayer@src3"],show_data=False)
    valid_sentences_embeddings.append(trg4[0].squeeze().numpy())

# %%
show_on_vis_multi([],[],valid_sentences_embeddings,valid_sentences)
print(valid_sentences_embeddings[0].shape)
np.array(valid_sentences_embeddings).shape

# %%
all_outputs[3]

# %%
add_new_logger("sample1")
example_idx = 8

src = vars(train_data.examples[example_idx])['src']
trg = vars(train_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')

currentLogger = StepLogger(100)  
translation, attention = translate_sentence(src, SRC, TRG, model, device,is_appy_attention=True)

print(f'predicted trg = {translation}')
 
display_attention(src, translation, attention,n_heads=2,n_rows = 1, n_cols = 2)

# %%
def draw_df(data,columns,indexes):
    df2 = pd.DataFrame(data,columns=columns,index=indexes)
    cm = sns.light_palette("blue", as_cmap=True)
    styled_df = df2.style.background_gradient(cmap=cm)
    display(styled_df)

# %%
#test_logger.get_default_summary(show_data=True)
for index in range(10):
    
    test_logger,all_outputs = test_sentence(tabular_set[index].src,draw_charts=False,is_appy_attention=True)
    encoded_attention = test_logger.get_summary(["EncoderLayer@sattention"],show_data=False)
    output_words = ["sos"]+tabular_set[index].src  +["eos"]
    all_outputs = encoded_attention[0][:,0,:,:]
    draw_df(all_outputs.squeeze().numpy(),output_words,output_words)
#df2 = pd.DataFrame(all_outputs.squeeze().numpy(),columns=output_words,index=output_words)
#cm = sns.light_palette("blue", as_cmap=True)

#styled_df = df2.style.background_gradient(cmap=cm)
#styled_df
# Out:
# src = ['i', 'want', 'to', 'eat', 'bread']
# predicted trg = ['ich', 'mochten', 'brot', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# <style  type="text/css" >
# #T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col0,#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col3{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col1{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col2,#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col3,#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col1,#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col4,#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col0,#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col6,#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col3,#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col6,#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col6,#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col4{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col5,#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col0{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col6{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col1,#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col2{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col3{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col5{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col0,#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col3{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col1{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col4,#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col5{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col5,#T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col6,#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col3,#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col2,#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col0,#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col1,#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col4,#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col2{
#             background-color:  #4f4ffb;
#             color:  #f1f1f1;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row3_col6,#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col5{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col0{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col1{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col4,#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row4_col5{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row5_col4{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_75d55986_37d4_11eb_a032_c49ded8dff66row6_col3{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }</style><table id="T_75d55986_37d4_11eb_a032_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >eat</th>        <th class="col_heading level0 col5" >bread</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75d55986_37d4_11eb_a032_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col0" class="data row0 col0" >0.034296</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col1" class="data row0 col1" >0.022736</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col2" class="data row0 col2" >0.588869</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col3" class="data row0 col3" >0.080685</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col4" class="data row0 col4" >0.034747</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col5" class="data row0 col5" >0.050313</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row0_col6" class="data row0 col6" >0.188353</td>
#             </tr>
#             <tr>
#                         <th id="T_75d55986_37d4_11eb_a032_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col0" class="data row1 col0" >0.095289</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col1" class="data row1 col1" >0.008989</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col2" class="data row1 col2" >0.021511</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col3" class="data row1 col3" >0.365728</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col4" class="data row1 col4" >0.045538</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col5" class="data row1 col5" >0.438121</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row1_col6" class="data row1 col6" >0.024824</td>
#             </tr>
#             <tr>
#                         <th id="T_75d55986_37d4_11eb_a032_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col0" class="data row2 col0" >0.092344</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col1" class="data row2 col1" >0.017648</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col2" class="data row2 col2" >0.037594</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col3" class="data row2 col3" >0.831976</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col4" class="data row2 col4" >0.012347</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col5" class="data row2 col5" >0.005322</td>
#                         <td id="T_75d55986_37d4_11eb_a032_c49ded8dff66row2_col6" class="data row2 col6" >0.002770</td>
#             </tr>
#             <tr>
# src = ['i', 'want', 'to', 'eat', 'apple']
# predicted trg = ['ich', 'mochten', 'apfel', 'essen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# <style  type="text/css" >
# #T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col0,#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col6{
#             background-color:  #bebef5;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col1{
#             background-color:  #c7c7f5;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col2,#T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col6,#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col0,#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col3,#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col1,#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col4,#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col3,#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col4{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col4{
#             background-color:  #dcdcf4;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col5,#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col5,#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col4{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col1{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col2,#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col2{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col3{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col4,#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col0{
#             background-color:  #bfbff5;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col0{
#             background-color:  #6c6cf9;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col1{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col4{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col5,#T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col6,#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col3,#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col2,#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col0,#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col1,#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col4,#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col2{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col5{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row3_col6{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col0{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col1,#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col0{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col3{
#             background-color:  #8989f8;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col5{
#             background-color:  #7575f9;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row4_col6{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row5_col3{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col1{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col2{
#             background-color:  #adadf6;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col3{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col5{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_75e00088_37d4_11eb_b859_c49ded8dff66row6_col6{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }</style><table id="T_75e00088_37d4_11eb_b859_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >eat</th>        <th class="col_heading level0 col5" >apple</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75e00088_37d4_11eb_b859_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col0" class="data row0 col0" >0.035781</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col1" class="data row0 col1" >0.023721</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col2" class="data row0 col2" >0.614363</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col3" class="data row0 col3" >0.084178</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col4" class="data row0 col4" >0.036252</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col5" class="data row0 col5" >0.009198</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row0_col6" class="data row0 col6" >0.196507</td>
#             </tr>
#             <tr>
#                         <th id="T_75e00088_37d4_11eb_b859_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col0" class="data row1 col0" >0.167922</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col1" class="data row1 col1" >0.015840</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col2" class="data row1 col2" >0.037907</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col3" class="data row1 col3" >0.644498</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col4" class="data row1 col4" >0.080249</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col5" class="data row1 col5" >0.009839</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row1_col6" class="data row1 col6" >0.043746</td>
#             </tr>
#             <tr>
#                         <th id="T_75e00088_37d4_11eb_b859_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col0" class="data row2 col0" >0.092624</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col1" class="data row2 col1" >0.017701</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col2" class="data row2 col2" >0.037708</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col3" class="data row2 col3" >0.834505</td>
#                         <td id="T_75e00088_37d4_11eb_b859_c49ded8dff66row2_col4" class="data row2 col4" >0.012384</td>
#                         <td id="T_75e00088_37d
# src = ['i', 'want', 'to', 'drink', 'water']
# predicted trg = ['ich', 'mochten', 'wasser', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# <style  type="text/css" >
# #T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col0,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col1,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col5,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col2,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col4,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col6,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col3,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col4,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col2{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col3{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col4,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col5,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col3,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col1,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col2,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col0,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col6,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col1{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col0{
#             background-color:  #9393f8;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col1,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col4,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col5{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col3{
#             background-color:  #9696f7;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col6,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col4{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col0{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col1{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col2{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col5{
#             background-color:  #c1c1f5;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col0{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col5,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col0{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row3_col6,#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col2{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col3{
#             background-color:  #4949fb;
#             color:  #f1f1f1;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col5{
#             background-color:  #9a9af7;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row4_col6{
#             background-color:  #d9d9f4;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col1{
#             background-color:  #6060fa;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col2{
#             background-color:  #dadaf4;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col3{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row5_col4{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col0{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col2{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col3{
#             background-color:  #a0a0f7;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col4{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col5{
#             background-color:  #3232fc;
#             color:  #f1f1f1;
#         }#T_75e868f6_37d4_11eb_8421_c49ded8dff66row6_col6{
#             background-color:  #ececf3;
#             color:  #000000;
#         }</style><table id="T_75e868f6_37d4_11eb_8421_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >drink</th>        <th class="col_heading level0 col5" >water</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75e868f6_37d4_11eb_8421_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col0" class="data row0 col0" >0.005615</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col1" class="data row0 col1" >0.003722</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col2" class="data row0 col2" >0.096406</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col3" class="data row0 col3" >0.013209</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col4" class="data row0 col4" >0.838299</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col5" class="data row0 col5" >0.011912</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row0_col6" class="data row0 col6" >0.030836</td>
#             </tr>
#             <tr>
#                         <th id="T_75e868f6_37d4_11eb_8421_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col0" class="data row1 col0" >0.071339</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col1" class="data row1 col1" >0.006729</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col2" class="data row1 col2" >0.016104</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col3" class="data row1 col3" >0.273806</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col4" class="data row1 col4" >0.002215</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col5" class="data row1 col5" >0.611221</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row1_col6" class="data row1 col6" >0.018585</td>
#             </tr>
#             <tr>
#                         <th id="T_75e868f6_37d4_11eb_8421_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col0" class="data row2 col0" >0.079115</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col1" class="data row2 col1" >0.015120</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col2" class="data row2 col2" >0.032208</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col3" class="data row2 col3" >0.712789</td>
#                         <td id="T_75e868f6_37d4_11eb_8421_c49ded8dff66row2_col4" class="data row2 col4" >0.028473</td>
#                         <td id="T_75e868f6_3
# src = ['i', 'want', 'to', 'drink', 'beer']
# predicted trg = ['ich', 'mochten', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# <style  type="text/css" >
# #T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col0,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col1,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col5,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col4,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col6,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col3,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col2,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col2{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col3,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col4,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col1{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col4,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col0,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col6,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col3,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col1,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col2,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col5,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col6{
#             background-color:  #5555fb;
#             color:  #f1f1f1;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col1,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col1{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col2,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col4{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col3{
#             background-color:  #2222fd;
#             color:  #f1f1f1;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col5,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col5{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col0{
#             background-color:  #7d7df9;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col2{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col5,#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col1{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col0{
#             background-color:  #a5a5f7;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row3_col6{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col0{
#             background-color:  #4545fb;
#             color:  #f1f1f1;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col3{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row4_col6{
#             background-color:  #3737fc;
#             color:  #f1f1f1;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col0{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col1{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col2{
#             background-color:  #b1b1f6;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col3{
#             background-color:  #8484f8;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col4{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row5_col5{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col0{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col2{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col3{
#             background-color:  #9292f8;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col4{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col5{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row6_col6{
#             background-color:  #a6a6f7;
#             color:  #000000;
#         }</style><table id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >drink</th>        <th class="col_heading level0 col5" >beer</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col0" class="data row0 col0" >0.005624</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col1" class="data row0 col1" >0.003728</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col2" class="data row0 col2" >0.096561</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col3" class="data row0 col3" >0.013231</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col4" class="data row0 col4" >0.839647</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col5" class="data row0 col5" >0.010324</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row0_col6" class="data row0 col6" >0.030886</td>
#             </tr>
#             <tr>
#                         <th id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col0" class="data row1 col0" >0.177979</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col1" class="data row1 col1" >0.016789</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col2" class="data row1 col2" >0.040177</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col3" class="data row1 col3" >0.683097</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col4" class="data row1 col4" >0.005525</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col5" class="data row1 col5" >0.030067</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row1_col6" class="data row1 col6" >0.046366</td>
#             </tr>
#             <tr>
#                         <th id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col0" class="data row2 col0" >0.088411</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col1" class="data row2 col1" >0.016896</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col2" class="data row2 col2" >0.035993</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col3" class="data row2 col3" >0.796540</td>
#                         <td id="T_75f00bc2_37d4_11eb_a2a1_c49ded8dff66row2_col4" class="data row2 col4" >0.031819</td>
#                         <td id="T_75f00bc2_37
# src = ['i', 'want', 'to', 'read', 'book']
# predicted trg = ['ich', 'mochten', 'buch', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# <style  type="text/css" >
# #T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col0,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col2{
#             background-color:  #b9b9f6;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col1,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col3{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col2{
#             background-color:  #2323fd;
#             color:  #f1f1f1;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col5{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col6{
#             background-color:  #8787f8;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col0,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col3,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col1,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col2,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col6,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col4,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col1,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col1{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col2,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col4{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col3,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col4{
#             background-color:  #6d6df9;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col5,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col0{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col6{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col0{
#             background-color:  #3b3bfc;
#             color:  #f1f1f1;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col1{
#             background-color:  #e1e1f4;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col2{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col4{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col5{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col6,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col3,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col4,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col5,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col0,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col2,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col1,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col0{
#             background-color:  #7b7bf9;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col5{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row3_col6,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col0{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row4_col3{
#             background-color:  #8383f8;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col1{
#             background-color:  #c9c9f5;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col3,#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col5{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row5_col6{
#             background-color:  #3838fc;
#             color:  #f1f1f1;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col2{
#             background-color:  #b8b8f6;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col3{
#             background-color:  #bdbdf5;
#             color:  #000000;
#         }#T_75f866ca_37d4_11eb_8463_c49ded8dff66row6_col6{
#             background-color:  #ededf3;
#             color:  #000000;
#         }</style><table id="T_75f866ca_37d4_11eb_8463_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >read</th>        <th class="col_heading level0 col5" >book</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75f866ca_37d4_11eb_8463_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col0" class="data row0 col0" >0.033434</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col1" class="data row0 col1" >0.022165</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col2" class="data row0 col2" >0.574073</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col3" class="data row0 col3" >0.078658</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col4" class="data row0 col4" >0.064202</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col5" class="data row0 col5" >0.043848</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row0_col6" class="data row0 col6" >0.183620</td>
#             </tr>
#             <tr>
#                         <th id="T_75f866ca_37d4_11eb_8463_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col0" class="data row1 col0" >0.116377</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col1" class="data row1 col1" >0.010978</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col2" class="data row1 col2" >0.026271</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col3" class="data row1 col3" >0.446666</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col4" class="data row1 col4" >0.314331</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col5" class="data row1 col5" >0.055059</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row1_col6" class="data row1 col6" >0.030318</td>
#             </tr>
#             <tr>
#                         <th id="T_75f866ca_37d4_11eb_8463_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col0" class="data row2 col0" >0.089816</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col1" class="data row2 col1" >0.017165</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col2" class="data row2 col2" >0.036565</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col3" class="data row2 col3" >0.809199</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col4" class="data row2 col4" >0.007623</td>
#                         <td id="T_75f866ca_37d4_11eb_8463_c49ded8dff66row2_col5" class="data row2 col5" >0.036939</td>
# src = ['i', 'want', 'to', 'read', 'newspaper']
# predicted trg = ['ich', 'mochten', 'zeitung', 'lesen', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 7, 7]
# <style  type="text/css" >
# #T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col0,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col1,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col1{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col1,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col6{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col2{
#             background-color:  #7a7af9;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col3{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col4{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col5,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col0,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col4,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col3,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col1,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col2,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col6{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col6{
#             background-color:  #b2b2f6;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col3{
#             background-color:  #6b6bfa;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col5{
#             background-color:  #dedef4;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col6{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col0{
#             background-color:  #4242fc;
#             color:  #f1f1f1;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col1,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col2,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col3{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col4,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col6{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col5,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col4{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row2_col6,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col3,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col5,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col0,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col2,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col1,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col4{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col0,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col3{
#             background-color:  #8686f8;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row3_col4,#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col1{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col2{
#             background-color:  #babaf6;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row4_col5{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col0{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col4{
#             background-color:  #4e4efb;
#             color:  #f1f1f1;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col5{
#             background-color:  #0303ff;
#             color:  #f1f1f1;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row5_col6{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col0{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col2{
#             background-color:  #8d8df8;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col3{
#             background-color:  #9494f7;
#             color:  #000000;
#         }#T_7600d498_37d4_11eb_ab35_c49ded8dff66row6_col5{
#             background-color:  #2d2dfd;
#             color:  #f1f1f1;
#         }</style><table id="T_7600d498_37d4_11eb_ab35_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >read</th>        <th class="col_heading level0 col5" >newspaper</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7600d498_37d4_11eb_ab35_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col0" class="data row0 col0" >0.018869</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col1" class="data row0 col1" >0.012509</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col2" class="data row0 col2" >0.323989</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col3" class="data row0 col3" >0.044392</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col4" class="data row0 col4" >0.036234</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col5" class="data row0 col5" >0.460377</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row0_col6" class="data row0 col6" >0.103629</td>
#             </tr>
#             <tr>
#                         <th id="T_7600d498_37d4_11eb_ab35_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col0" class="data row1 col0" >0.114438</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col1" class="data row1 col1" >0.010795</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col2" class="data row1 col2" >0.025833</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col3" class="data row1 col3" >0.439222</td>
#                         <td id="T_7600d498_37d4_11eb_ab35_c49ded8dff66row1_col4" class="data row1 col4" >0.309092</td>
# ...
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col2{
#             background-color:  #2929fd;
#             color:  #f1f1f1;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col3,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col4,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col1,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col0,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col5,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row5_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col0{
#             background-color:  #8c8cf8;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col1,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col0{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col5{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col0{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col2{
#             background-color:  #5757fb;
#             color:  #f1f1f1;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col3{
#             background-color:  #5959fa;
#             color:  #f1f1f1;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col4,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row5_col5{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col5{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col1{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col2{
#             background-color:  #aaaaf6;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col3{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col4{
#             background-color:  #8a8af8;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col5{
#             background-color:  #c6c6f5;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col1{
#             background-color:  #4040fc;
#             color:  #f1f1f1;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col2{
#             background-color:  #dedff4;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col3{
#             background-color:  #a4a4f7;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col4,#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row5_col0{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row5_col1{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row5_col3{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row5_col4{
#             background-color:  #9797f7;
#             color:  #000000;
#         }</style><table id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >drink</th>        <th class="col_heading level0 col4" >water</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col0" class="data row0 col0" >0.003535</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col1" class="data row0 col1" >0.002344</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col2" class="data row0 col2" >0.509575</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col3" class="data row0 col3" >0.461979</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col4" class="data row0 col4" >0.009659</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row0_col5" class="data row0 col5" >0.012909</td>
#             </tr>
#             <tr>
#                         <th id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col0" class="data row1 col0" >0.126141</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col1" class="data row1 col1" >0.011899</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col2" class="data row1 col2" >0.009184</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col3" class="data row1 col3" >0.005224</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col4" class="data row1 col4" >0.819563</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row1_col5" class="data row1 col5" >0.027990</td>
#             </tr>
#             <tr>
#                         <th id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col0" class="data row2 col0" >0.017069</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col1" class="data row2 col1" >0.251279</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col2" class="data row2 col2" >0.394914</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col3" class="data row2 col3" >0.292525</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col4" class="data row2 col4" >0.022133</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row2_col5" class="data row2 col5" >0.022081</td>
#             </tr>
#             <tr>
#                         <th id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66level0_row3" class="row_heading level0 row3" >drink</th>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col0" class="data row3 col0" >0.298790</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col1" class="data row3 col1" >0.033396</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col2" class="data row3 col2" >0.186382</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col3" class="data row3 col3" >0.014597</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col4" class="data row3 col4" >0.357245</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row3_col5" class="data row3 col5" >0.109590</td>
#             </tr>
#             <tr>
#                         <th id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66level0_row4" class="row_heading level0 row4" >water</th>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col0" class="data row4 col0" >0.014258</td>
#                         <td id="T_7619f85c_37d4_11eb_b4c2_c49ded8dff66row4_col1" class="data row4 col1" >0.184207</td>
#                         <td id="T_7619f85c_37d4_11eb
# src = ['i', 'can', 'drink', 'beer']
# predicted trg = ['ich', 'konnen', 'bier', 'trinken', '<eos>']
# summary_count 1    self.capacity  20
# EncoderLayer@sattention
# [1, 2, 6, 6]
# <style  type="text/css" >
# #T_76226836_37d4_11eb_8409_c49ded8dff66row0_col0,#T_76226836_37d4_11eb_8409_c49ded8dff66row0_col1,#T_76226836_37d4_11eb_8409_c49ded8dff66row0_col4,#T_76226836_37d4_11eb_8409_c49ded8dff66row0_col5,#T_76226836_37d4_11eb_8409_c49ded8dff66row1_col2,#T_76226836_37d4_11eb_8409_c49ded8dff66row3_col3,#T_76226836_37d4_11eb_8409_c49ded8dff66row5_col1{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row0_col2{
#             background-color:  #2828fd;
#             color:  #f1f1f1;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row0_col3,#T_76226836_37d4_11eb_8409_c49ded8dff66row1_col0,#T_76226836_37d4_11eb_8409_c49ded8dff66row1_col5,#T_76226836_37d4_11eb_8409_c49ded8dff66row3_col4,#T_76226836_37d4_11eb_8409_c49ded8dff66row4_col1,#T_76226836_37d4_11eb_8409_c49ded8dff66row5_col2{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row1_col1{
#             background-color:  #c5c5f5;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row1_col3{
#             background-color:  #e7e7f3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row1_col4{
#             background-color:  #d5d5f4;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row2_col0{
#             background-color:  #ececf3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row2_col1{
#             background-color:  #3535fc;
#             color:  #f1f1f1;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row2_col2,#T_76226836_37d4_11eb_8409_c49ded8dff66row2_col3{
#             background-color:  #5b5bfa;
#             color:  #f1f1f1;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row2_col4{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row2_col5{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row3_col0{
#             background-color:  #b3b3f6;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row3_col1{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row3_col2{
#             background-color:  #d8d8f4;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row3_col5{
#             background-color:  #9797f7;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row4_col0{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row4_col2{
#             background-color:  #d2d2f4;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row4_col3{
#             background-color:  #3c3cfc;
#             color:  #f1f1f1;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row4_col4{
#             background-color:  #cdcdf5;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row4_col5{
#             background-color:  #5f5ffa;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row5_col0{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row5_col3{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row5_col4{
#             background-color:  #7878f9;
#             color:  #000000;
#         }#T_76226836_37d4_11eb_8409_c49ded8dff66row5_col5{
#             background-color:  #e3e3f3;
#             color:  #000000;
#         }</style><table id="T_76226836_37d4_11eb_8409_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >can</th>        <th class="col_heading level0 col3" >drink</th>        <th class="col_heading level0 col4" >beer</th>        <th class="col_heading level0 col5" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76226836_37d4_11eb_8409_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row0_col0" class="data row0 col0" >0.003540</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row0_col1" class="data row0 col1" >0.002347</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row0_col2" class="data row0 col2" >0.510239</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row0_col3" class="data row0 col3" >0.462581</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row0_col4" class="data row0 col4" >0.008368</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row0_col5" class="data row0 col5" >0.012926</td>
#             </tr>
#             <tr>
#                         <th id="T_76226836_37d4_11eb_8409_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row1_col0" class="data row1 col0" >0.641621</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row1_col1" class="data row1 col1" >0.060524</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row1_col2" class="data row1 col2" >0.046716</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row1_col3" class="data row1 col3" >0.026571</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row1_col4" class="data row1 col4" >0.082198</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row1_col5" class="data row1 col5" >0.142371</td>
#             </tr>
#             <tr>
#                         <th id="T_76226836_37d4_11eb_8409_c49ded8dff66level0_row2" class="row_heading level0 row2" >can</th>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row2_col0" class="data row2 col0" >0.017004</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row2_col1" class="data row2 col1" >0.250324</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row2_col2" class="data row2 col2" >0.393413</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row2_col3" class="data row2 col3" >0.291413</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row2_col4" class="data row2 col4" >0.025848</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row2_col5" class="data row2 col5" >0.021997</td>
#             </tr>
#             <tr>
#                         <th id="T_76226836_37d4_11eb_8409_c49ded8dff66level0_row3" class="row_heading level0 row3" >drink</th>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row3_col0" class="data row3 col0" >0.167161</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row3_col1" class="data row3 col1" >0.018684</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row3_col2" class="data row3 col2" >0.104273</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row3_col3" class="data row3 col3" >0.008166</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row3_col4" class="data row3 col4" >0.640405</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row3_col5" class="data row3 col5" >0.061311</td>
#             </tr>
#             <tr>
#                         <th id="T_76226836_37d4_11eb_8409_c49ded8dff66level0_row4" class="row_heading level0 row4" >beer</th>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row4_col0" class="data row4 col0" >0.019301</td>
#                         <td id="T_76226836_37d4_11eb_8409_c49ded8dff66row4_col1" class="data r

# %%
# Out:
# <style  type="text/css" >
# #T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col0,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col3{
#             background-color:  #e5e5f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col1{
#             background-color:  #cacaf5;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col2,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col3,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col1,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col4,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col0,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col6,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col5{
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col3,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col6,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col6,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col2{
#             background-color:  #dbdbf4;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col4{
#             background-color:  #ddddf4;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col5,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col0{
#             background-color:  #e4e4f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col6{
#             background-color:  #3a3afc;
#             color:  #f1f1f1;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col0{
#             background-color:  #cecef4;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col1,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col2{
#             background-color:  #e2e2f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col2{
#             background-color:  #e9e9f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col3{
#             background-color:  #8888f8;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col4{
#             background-color:  #d6d6f4;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col5{
#             background-color:  #7979f9;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col0,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col3{
#             background-color:  #cfcff4;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col1{
#             background-color:  #d3d3f4;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col4,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col5{
#             background-color:  #ebebf3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col5,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col6,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col3,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col2,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col0,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col1,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col4,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col6{
#             background-color:  #f0f0f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col2{
#             background-color:  #4f4ffb;
#             color:  #f1f1f1;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row3_col6,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col5{
#             background-color:  #eeeef3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col0{
#             background-color:  #efeff3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col1{
#             background-color:  #ededf3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col4,#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col1{
#             background-color:  #eaeaf3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row4_col5{
#             background-color:  #0b0bfe;
#             color:  #f1f1f1;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col2{
#             background-color:  #e8e8f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row5_col4{
#             background-color:  #e6e6f3;
#             color:  #000000;
#         }#T_dbce3328_37d1_11eb_807a_c49ded8dff66row6_col3{
#             background-color:  #e0e0f4;
#             color:  #000000;
#         }</style><table id="T_dbce3328_37d1_11eb_807a_c49ded8dff66" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sos</th>        <th class="col_heading level0 col1" >i</th>        <th class="col_heading level0 col2" >want</th>        <th class="col_heading level0 col3" >to</th>        <th class="col_heading level0 col4" >eat</th>        <th class="col_heading level0 col5" >bread</th>        <th class="col_heading level0 col6" >eos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbce3328_37d1_11eb_807a_c49ded8dff66level0_row0" class="row_heading level0 row0" >sos</th>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col0" class="data row0 col0" >0.034296</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col1" class="data row0 col1" >0.022736</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col2" class="data row0 col2" >0.588869</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col3" class="data row0 col3" >0.080685</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col4" class="data row0 col4" >0.034747</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col5" class="data row0 col5" >0.050313</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row0_col6" class="data row0 col6" >0.188353</td>
#             </tr>
#             <tr>
#                         <th id="T_dbce3328_37d1_11eb_807a_c49ded8dff66level0_row1" class="row_heading level0 row1" >i</th>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col0" class="data row1 col0" >0.095289</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col1" class="data row1 col1" >0.008989</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col2" class="data row1 col2" >0.021511</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col3" class="data row1 col3" >0.365728</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col4" class="data row1 col4" >0.045538</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col5" class="data row1 col5" >0.438121</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row1_col6" class="data row1 col6" >0.024824</td>
#             </tr>
#             <tr>
#                         <th id="T_dbce3328_37d1_11eb_807a_c49ded8dff66level0_row2" class="row_heading level0 row2" >want</th>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col0" class="data row2 col0" >0.092344</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col1" class="data row2 col1" >0.017648</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col2" class="data row2 col2" >0.037594</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col3" class="data row2 col3" >0.831976</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col4" class="data row2 col4" >0.012347</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col5" class="data row2 col5" >0.005322</td>
#                         <td id="T_dbce3328_37d1_11eb_807a_c49ded8dff66row2_col6" class="data row2 col6" >0.002770</td>
#             </tr>
#             <tr>

# %%
loggers.keys()

# %%
loggers["training"].get_default_summary()

# %%
loggers["test_loss"].get_default_summary()

# %%
loggers["sample1"].get_default_summary()

# %%
current_logger.get_default_summary(show_data=False)

# %%
#currentLogger.get_default_summary(show_data=False)

# %%
#currentLogger.get_summary(labels=["Q"],show_data=True)

# %%
loggers.keys()

# %%
loggers["sample1"].get_default_summary(show_data=False)

# %%
attention_orig = loggers["sample1"].get_summary(labels=["decoder_encoder_attention@attention"],show_data=True)
trg4 = loggers["sample1"].get_summary(labels=["DecoderLayer@trg4"],show_data=True)

# %%
add_new_logger("sample3")
example_idx = 18

src = vars(train_data.examples[example_idx])['src']
trg = vars(train_data.examples[example_idx])['trg']

print(f'src = {src}')
print(f'trg = {trg}')

currentLogger = StepLogger(100)  
translation, attention = translate_sentence(src, SRC, TRG, model, device,is_appy_attention=False)

print(f'predicted trg = {translation}')
 
display_attention(src, translation, attention,n_heads=2,n_rows = 1, n_cols = 2)

# %%
for i in range( len(tabular_set)):
    print(" ".join(tabular_set[i].src))

# %%
tabular_set[i].src

# %%
tt = torch.tensor(np.full((1, 2, 1, 6), 1/6) )

att1 = torch.tensor(np.full((tt.shape[0], tt.shape[1], tt.shape[2], 3), 1/3) )
att2 = torch.tensor(np.full((tt.shape[0], tt.shape[1], tt.shape[2], tt.shape[3] - 3), 1/7) )
att3 = torch.cat( (att1,att2),3 )
att4 = torch.softmax(att3, dim = -1)
att4

# %%
tt = torch.tensor(np.random((1, 2, 1, 6)) )
